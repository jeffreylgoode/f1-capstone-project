# %% [markdown]
# # F1 Pit Strategy Optimization
# # 1. Business Understanding
#
# ## Business Problem
#
# Pit stop timing is one of the most critical strategic decisions in Formula 1 (F1). A poorly timed pit stop can cost a team race positions, championship points, and even season titles. In the 2025 Qatar Grand Prix, Team McLaren’s decision not to pit under the lap‑7 Safety Car forced both drivers into an unfavorable two‑stop strategy, ultimately costing the team the race and valuable championship points.
#
# F1 Teams need a systematic, data‑driven method to evaluate pit stop timing strategy prior to the race and in real time, reducing reliance on intuition and minimizing costly strategic errors.

# %% [markdown]
# ## Project Objective
#
# The objective of this project is to answer the question:
# **“As an F1 Team Principal, should we pit now or stay out?”**
#
# To accomplish this, I will build:
#
# * A race simulator that models race strategy (stint performance), tire degradation, fuel burn, pit‑stop loss
# * A pit‑strategy optimizer that evaluates alternative strategies
# * A real-time stint calculator for "pit now or stay out" decisions
# * Predictive models for: fuel consumption,tire degradation, and (optionally) Safety Car probability
#
# A key use case is evaluating the 2025 Qatar lap‑7 decision and determining whether the real-time stint calculator would have correctly recommended "pit-now"!

# %% [markdown]
# ## Success Criteria

# %% [markdown]
# **Business Success Criteria**
#
# * Correctly identifies the optimal pit decision for the 2025 Qatar lap‑7 scenario.
# * Produces strategy recommendations consistent with historical race outcomes
# * Extensible to weather, traffic, undercut, and Safety Car modeling

# %% [markdown]
# **Analytic Success Criteria**
# * Tire degradation and fuel models achieve reasonable lap time error bounds
# * Optimizer ranks strategies in alignment with known race results

# %% [markdown]
# **Technical Success Criteria**
#
# A reproducible notebook containing:
# * Data exploration
# * Cleaned datasets
# * Predictive models
# * Race simulator
# * Pit-strategy optimizer
# * Clear documentation of assumptions and limitations

# %% [markdown]
# # 2. Data Understanding
# ## 2.1 Data Sources
# This project uses publicly available Formula 1 timing and telemetry data from two primary sources:
# - **Formula1.com** — the official provider of race timing, lap charts, stint summaries, pit stop logs, and session classification data. These data form the authoritative basis for lap‑by‑lap performance and race event information.
#   [https://www.formula1.com](https://www.formula1.com)
#
# - **FastF1 API** — an open‑source Python library that provides structured access to Formula 1 timing, telemetry, and session metadata. FastF1 retrieves timing data from publicly available endpoints and organizes it into analysis‑ready formats, including lap times, tire compounds, stint information, pit events, and track status codes.   [https://theoehrly.github.io/Fast-F1/](https://theoehrly.github.io/Fast-F1/)
#
# Together, these sources provide the lap‑level and stint‑level information required to model tire degradation, fuel burn, pit stop loss, and Safety Car effects for pit strategy optimization.  FastF1 serves as the primary data ingestion tool, while Formula1.com provides validation and supplemental race context.
#
#
# ## 2.2 Data Description
# For each race session, the dataset typically includes structured timing, stint, and event-level information.  Key fields include:
#
# * **LapTime**: recorded lap time in seconds
# * **Compound**: tire compound used for the lap (Soft/Medium/Hard)
# * **Stint**: stint number for each driver
# * **PitIn/PitOut**: indicators for pit stop events
# * **TrackStatus**: Formula 1 governing body (FIA) status codes indicating Safety Car (SC), Virtual Safety Car (VSC), yellow flags and other race control events.
# * **Driver**: driver identifier (three letter abbreviations for drivers, eg: VER for Max Verstappen)
# * **Team**: team, also called constructor, identifier
# * **LapNumber**: sequential lap index
# * **TireLife**: number of laps on the current tire set (derived when not explicitly provided)
# * **FuelLoad**: estimated fuel mass (derived using standard F1 fuel burn assumptions)
#
# These variables enable modeling of tire degradation, stint performance, pit stop timing, and race day decision scenarios.   Additional columns will be incorporated as deeper inspection of session data continues.

# %% [markdown]
# ## 2.3 Initial Data Exploration
# Early exploration focused on understanding the structure, quality and strategic relevance of the timing and telemetry data.  Using the FastF1 API, I examined multiple races to understand how lap times, tire compounds and stint lengths effected race results.  Here were the key areas of early analysis:
# * Understanding and use of the FastF1 API
# * Exploration of driver position - race start and race end
# * Exploration and understanding of laps, lap compounds and stints as well as F1 (FIA governing body) compound use policy
# * Initial investigation of the McLaren Pit Strategy Error at the 2025 Qatar Grand Prix
# * Visualization of the McLaren Lap 7 Strategy
# * Summary of findings and a proposed strategy optimization approach

# %% [markdown]
# ### 2.3.1 Initial exploration of the FastF1 api

# %%
"""Access the fastf1 package/api"""

import fastf1 #import fastf1 package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set up cache, recommended by fastf1 documentation
fastf1.Cache.enable_cache('/Users/jeffreylgoode/documents/f1-capstone-project')

# Load a race session with year, event/race venue, and session type (Race, Qualifying, etc), use race designator R, versus Q for qualifying
session = fastf1.get_session(2025, 'Qatar Grand Prix', 'R')
session.load()

# Pick a driver (VER = Max Verstappen) for driver specific lap data
laps = session.laps.pick_drivers('VER')

laps.info()
# Out:
# events      WARNING 	Correcting user input 'Qatar Grand Prix' to 'Qatar Grand Prix'
# core           INFO 	Loading data for Qatar Grand Prix - Race [v3.7.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %% [markdown]
# **Missing data.**  From above, and from reading the fastf1.api documentation, this race consisted of 57 laps, hence the Index of 57 entries, 0 to 56.  There are missing rows in PitOutTime, and PitInTime
# indicated for a driver, in this case Max Verstappen.   These columns are the time of day his car entered and exited the pit, and are otherwise null by design.  Use of the other columns, SectorXTime, SectorXSessionTime, SpeedXX are all beyond the scope of initial consideration since our focus is on fuel consumption, tire degradation, safety car deployment and track status.

# %% [markdown]
# **Tires vs tyres**.   F1 has it's roots in Europe, accordingly the European spelling for tire is tyre.  I will use these terms interchangeably in the notes and code.

# %%
laps.head()
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 01:00:10.717000    VER            1 0 days 00:01:28.940000
# 1 0 days 01:01:38.066000    VER            1 0 days 00:01:27.349000
# 2 0 days 01:03:05.577000    VER            1 0 days 00:01:27.511000
# 3 0 days 01:04:32.901000    VER            1 0 days 00:01:27.324000
# 4 0 days 01:05:59.744000    VER            1 0 days 00:01:26.843000
#
#    LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0        NaT       NaT                    NaT
# 1        2.0    1.0        NaT       NaT 0 days 00:00:32.280000
# 2        3.0    1.0        NaT       NaT 0 days 00:00:32.250000
# 3        4.0    1.0        NaT       NaT 0 days 00:00:32.285000
# 4        5.0    1.0        NaT       NaT 0 days 00:00:32.064000
#
#              Sector2Time  ... FreshTyre             Team  \
# 0 0 days 00:00:29.257000  ...      True  Red Bull Racing
# ...

# %%
laps.tail()
# Out:
#                      Time Driver DriverNumber                LapTime  \
# 52 0 days 02:17:41.564000    VER            1 0 days 00:01:24.492000
# 53 0 days 02:19:06.242000    VER            1 0 days 00:01:24.678000
# 54 0 days 02:20:30.647000    VER            1 0 days 00:01:24.405000
# 55 0 days 02:21:55.050000    VER            1 0 days 00:01:24.403000
# 56 0 days 02:23:20.018000    VER            1 0 days 00:01:24.968000
#
#     LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 52       53.0    3.0        NaT       NaT 0 days 00:00:31.203000
# 53       54.0    3.0        NaT       NaT 0 days 00:00:31.444000
# 54       55.0    3.0        NaT       NaT 0 days 00:00:31.193000
# 55       56.0    3.0        NaT       NaT 0 days 00:00:31.098000
# 56       57.0    3.0        NaT       NaT 0 days 00:00:31.585000
#
#               Sector2Time  ... FreshTyre             Team  \
# 52 0 days 00:00:28.870000  ...      True  Red Bull Racing
# ...

# %% [markdown]
# The last entry above in the **LapNumber** column indicates **57**, which is the lap number duration of the race.  This is also indicated by session.toal_laps below.

# %%
#The easiest way to get race length in laps.
session.total_laps
# Out:
# 57

# %%
# Use session results to see driver abbreviation, starting grid position, and finishing position (position).
# The following print out is relevant to our business purpose - Max Verstappen (VER) started 3rd, Oscar Piastri (PIA) started 1st, and Lando Norris (NOR) started 2nd. (See GridPosition column).
# As a result of a McLaren pit strategy error on lap 7, PIA finished 2nd, and NOR finished 3rd, whereas VER finished first. (See Position Column).

session.results[["Abbreviation","GridPosition","Position"]]
# Out:
#    Abbreviation  GridPosition  Position
# 1           VER           3.0       1.0
# 81          PIA           1.0       2.0
# 55          SAI           7.0       3.0
# 4           NOR           2.0       4.0
# 12          ANT           5.0       5.0
# 63          RUS           4.0       6.0
# 14          ALO           8.0       7.0
# 16          LEC          10.0       8.0
# 30          LAW          12.0       9.0
# 22          TSU          15.0      10.0
# 23          ALB          14.0      11.0
# 44          HAM          17.0      12.0
# 5           BOR          19.0      13.0
# 43          COL          20.0      14.0
# 31          OCO          16.0      15.0
# 10          GAS           9.0      16.0
# 18          STR          18.0      17.0
# 6           HAD           6.0      18.0
# 87          BEA          13.0      19.0
# 27          HUL          11.0      20.0

# %% [markdown]
# The following plot graphically displays the finish position (results) for the Qatar 2025 race, specifically showing team colors, **RED** for Ferrari team members LEC and HAM, **PAPAYA** for McLaren.

# %%
plt.style.use("default")

# Team colors (2024–2025)
TEAM_COLORS = {
    "Red Bull Racing": "#3671C6",
    "Ferrari": "#F91536",
    "Mercedes": "#6CD3BF",
    "McLaren": "#FF8000",
    "Aston Martin": "#229971",
    "RB": "#6692FF",
    "Haas F1 Team": "#B6BABD",
    "Williams": "#37BEDD",
    "Alpine": "#0090FF",
    "Sauber": "#52E252"
}

# Normalize FastF1 team names → your dictionary keys
TEAM_NAME_NORMALIZATION = {
    # Red Bull
    "Red Bull": "Red Bull Racing",
    "Oracle Red Bull Racing": "Red Bull Racing",

    # Ferrari
    "Scuderia Ferrari": "Ferrari",

    # Mercedes
    "Mercedes-AMG Petronas Formula One Team": "Mercedes",

    # McLaren
    "McLaren F1 Team": "McLaren",

    # Aston Martin
    "Aston Martin Aramco Cognizant Formula One Team": "Aston Martin",

    # RB / AlphaTauri
    "Visa Cash App RB": "RB",
    "Scuderia AlphaTauri": "RB",

    # Haas
    "MoneyGram Haas F1 Team": "Haas F1 Team",

    # Williams
    "Williams Racing": "Williams",

    # Alpine
    "BWT Alpine F1 Team": "Alpine",

    # Sauber / Alfa Romeo
    "Stake F1 Team Kick Sauber": "Sauber",
    "Alfa Romeo": "Sauber"
}


# Helper to map team names to colors
def get_team_color(team):
    normalized = TEAM_NAME_NORMALIZATION.get(team, team)
    return TEAM_COLORS.get(normalized, "#000000")  # fallback is black, not gray


# --- Build results DataFrame ---
res = session.results

df = pd.DataFrame({
    "Position": res["Position"].astype(int),
    "Driver": res["Abbreviation"],
    "Team": res["TeamName"]
}).sort_values("Position")

# Map colors using normalization
colors = df["Team"].map(get_team_color)

# --- Plot ---
fig, ax = plt.subplots(figsize=(12, 6))

ax.bar(
    df["Driver"],
    df["Position"],
    color=colors,
    edgecolor="black",
    linewidth=1.2
)

ax.invert_yaxis()

ax.set_xlabel("Driver", fontsize=12)
ax.set_ylabel("Finishing Position (1 = Winner)", fontsize=12)
ax.set_title("2025 Qatar Grand Prix – Race Results with Team Colors", fontsize=16, fontweight="bold")

ax.grid(axis="y", linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Below is the Qatar circuit**, note circuit length, number of laps for the race, fastest lap time and race distance.  Also note the course record lap time of **1 minute 22.384 seconds** compared to Max Verstappen's last lap time of **1 minute, 24.968 seconds.**

# %% [markdown]
# ![Race Strategy Screenshot](../images/F1_Qatar_Circuit.png)

# %% [markdown]
# ### 2.3.2 Stints and Tire Compounds

# %% [markdown]
# **Pit Strategy** is defined as when to pit, and what tire compounds to use for each pit to minimize lap time and race elapsed time.

# %% [markdown]
# **Tire compound usage and compound policy are of particular interest**.  For now, our scope will focus on dry weather racing.  During dry weather racing, a F1 team has 3 different tire compounds
# available, **SOFT, MEDIUM and HARD**.  Soft tires are stickier and lead to faster laps, versus the Hard tire compound tires which are less sticky but have better endurance.  Performance wise, the Medium compound
# tire sits in the middle of the Soft and Hard tires.   F1 dictates that during a dry race, a race car **must use 2 different tire compounds** chosen from the available/designated Soft, Medium and Hard compound tires for the specific race.

# %% [markdown]
# **Additional tire policies and regulations.** Some racing venues have additional considerations, for example at Monaco in 2025, the regulations required 2 pit stops during the race.   Only a single pit stop is required to fulfill the two-compound policy, but another pit stop was imposed to provide more variability in race outcome for the fans.   Additionally, for Qatar, the tire supplier, **Pirelli**, required that each tire run for a **maximum of 25 laps**.

# %% [markdown]
# **Stints.**  An important definition and a lap-results column is **Stints**.   The stint refers to a **segment** of the race, stint 1, 2, to n,
# where each stint is defined by the number of laps a tire compound was used.  **Stints are bounded by the race start, pit stops and the race finish**  Drivers start the race on a tire compound, Stint 1, then pit to change the tires ending one stint and beginning another.  Let's explore the Qatar race, and Max Verstappen's tire compound stints.  **Stints are "short-hand" for specifying the pit stop strategy for a specific race and race team.  Stints and Pit Strategy refer to the same thing, the design of how the team will compete.**

# %%
laps = session.laps.pick_drivers('VER') # explicitly choose Max Verstappens's laps
laps['Stint'].value_counts().sort_index()

# %% [markdown]
# From above,  we see that Max Verstappen ran 3 stints, with each stint duration shown as a lap count.   Breaking this down, Max started the race, ran with a set of tires for 7 laps, pitted, then ran with the next set of tires for 25 laps, then pitted and ran 25 more laps on a tire set to finish the race.

# %% [markdown]
# The following is a more complete picture of Max's race indicating stint number(Stint), tire compound (Compound), and sting length (count).

# %%
laps.groupby('Stint')['Compound'].value_counts()

# %% [markdown]
# Since pit strategy and stints are core to our project, it's worth while to elaborate on the information above.  Max Verstappen's race consisted of 3 stints: stint 1 , the race start with **MEDIUM** tire compound then pitstop on lap 7.  Stint 2 consisted of different set of **MEDIUM** compound tires which lasted 25 laps.  Max then pitted on lap 32, and put on **HARD** compound tires to finish the race. Since Max used two different compounds, 25 laps on **HARD**, 32 laps on **MEDIUM**  he meet F1 policy.  Also, his realized pit strategy also adhered to a Qatar-specific tire supplier rule from Pirelli that tire use was limited to a maximum of 25 laps.

# %% [markdown]
# Above, we calculated the pit lap number from the definition of a stint.  However, we can calculate the pitstop directly using the **PitInTime** column where it has a null value except for those laps when a pitstop occurs.  Below the PitInTime info is used to calculate the pitstop lap explicitly.

# %%
# the PitInTime is NaN except for when a pit entry occurs, so identifying the lapnumber for the pitin time is sufficient
# to indicate which lap number were pit laps
pit_laps = laps.loc[laps["PitInTime"].notna(), "LapNumber"].tolist()

pit_info = {
    "Driver": laps["Driver"].iloc[0],
    "PitLaps": pit_laps
}
pit_info

# %% [markdown]
# The code below combins pit stop lap info with the stint information.

# %%
out = (
    laps.groupby("Stint")["Compound"]
        .value_counts()
        .reset_index(name="Count")
)

# Map pit laps
pit_laps = (
    laps.loc[laps["PitInTime"].notna()]
        .groupby("Stint")["LapNumber"]
        .first()
)

out["PitLap"] = out["Stint"].map(pit_laps)

out = out.set_index("Stint").sort_index()

out

# %% [markdown]
# To reiterate, above is the artifact of the pit strategy implemented by Red Bull for the 2025 Qatar race for Max Verstappen.  The term **Pit Strategy** is appropriate for these reasons:
#
# * The two compound per race F1 rule was adhered to - the Medium and Hard compounds were used
# * The Qatar venue max stint length imposed by Perilli was adhered to - no tire shall be run more than 25 laps

# %% [markdown]
# At this point, we can define **Pit Strategy** as "what tire compounds shall we use, and when in light of F1 rules and tire supplier/race venue rules.  Further, we can add that a pit strategy must be active and live during the race such that the strategy can be revised in light of weather, safety cars, and performance of other team drivers.  Further we can add that race teams have multiple strategies at any given time depending on live racing conditions.  This project specifically focuses on providing a team multiple and optimal strategies such that the question is proactively answered each lap, **"Do we pit now, or do we stay out?"**.

# %% [markdown]
# ### 2.3.3 Pit Strategy Comparison between Max Verstappen and Oscar Piastri at 2025 Qatar Race

# %%
# copy driver lap info to laps dataframe for each driver
ver_laps = session.laps.pick_drivers('VER') # Max Verstappen's lap info
pia_laps = session.laps.pick_drivers('PIA') # Oscar Piastri's lap info

# %% [markdown]
# Here is Oscar Piastri's pit strategy for Qatar 2025

# %%
out = (
    pia_laps.groupby("Stint")["Compound"]
    .value_counts()
    .reset_index(name="Count")
)

# Map pit laps
pit_laps = (
    pia_laps.loc[pia_laps["PitInTime"].notna()]
    .groupby("Stint")["LapNumber"]
    .first()
)

out["PitLap"] = out["Stint"].map(pit_laps)

out = out.set_index("Stint").sort_index()

out

# %% [markdown]
# From above, for the Qatar 2025 race, Oscar Piastri started the race on **Medium** tires, pitted on lap 24 putting on a new set of **Medium** tires.
# He pitted again on lap 42, putting on a set of **Hard** tires to finish the race.

# %% [markdown]
# The following code plot compares Max's and Oscar's pit strategy in one plot.  Per the F1 color scheme, **White** is used to denote HARD tires, **Yellow** denotes MEDIUM tires,
# and **RED** denotes Soft tires.   During the race, the colors are visible on the outer wall of the tire so that pit crews can readily identify the tire compound.

# %%
# Convert both drivers' stint/compound data into pivoted tables
pia_df = pia_laps.groupby('Stint')['Compound'].value_counts().unstack(fill_value=0)
ver_df = ver_laps.groupby('Stint')['Compound'].value_counts().unstack(fill_value=0)

colors = {
    'SOFT': 'red',
    'MEDIUM': 'yellow',
    'HARD': 'white'
}

# --- Extract pit laps (only PitInTime, not PitOutTime) ---
pia_pit_laps = pia_laps.loc[pia_laps["PitInTime"].notna(), "LapNumber"].tolist()
ver_pit_laps = ver_laps.loc[ver_laps["PitInTime"].notna(), "LapNumber"].tolist()

plt.figure(figsize=(14, 4))

# -------------------------
# PIASTRI
# -------------------------
left = 0
for stint in pia_df.index:
    compound = pia_df.columns[pia_df.loc[stint] > 0][0]
    width = pia_df.loc[stint, compound]

    plt.barh(
        y=1,
        width=width,
        left=left,
        color=colors.get(compound, 'gray'),
        edgecolor='black'
    )

    # First line: stint number + lap count
    plt.text(
        left + width/2,
        1 + 0.18,
        f"Stint {int(stint)} = {width}",
        va='center',
        ha='center',
        fontsize=9,
        color='black'
    )

    # Second line: compound name
    plt.text(
        left + width/2,
        1 - 0.05,
        compound.upper(),
        va='center',
        ha='center',
        fontsize=9,
        color='black'
    )

    # --- Add pit lap label if this stint ends with a pit ---
    stint_end_lap = left + width
    if stint_end_lap in pia_pit_laps:
        plt.text(
            stint_end_lap - width/2,
            1 - 0.30,
            f"Pit Lap {stint_end_lap}",
            va='center',
            ha='center',
            fontsize=8,
            color='black'
        )

    left += width

# -------------------------
# VERSTAPPEN
# -------------------------
left = 0
for stint in ver_df.index:
    compound = ver_df.columns[ver_df.loc[stint] > 0][0]
    width = ver_df.loc[stint, compound]

    plt.barh(
        y=0,
        width=width,
        left=left,
        color=colors.get(compound, 'gray'),
        edgecolor='black'
    )

    plt.text(
        left + width/2,
        0 + 0.18,
        f"Stint {int(stint)} = {width}",
        va='center',
        ha='center',
        fontsize=9,
        color='black'
    )

    plt.text(
        left + width/2,
        0 - 0.05,
        compound.upper(),
        va='center',
        ha='center',
        fontsize=9,
        color='black'
    )

    # --- Add pit lap label ---
    stint_end_lap = left + width
    if stint_end_lap in ver_pit_laps:
        plt.text(
            stint_end_lap - width/2,
            0 - 0.30,
            f"Pit Lap {stint_end_lap}",
            va='center',
            ha='center',
            fontsize=8,
            color='black'
        )

    left += width

plt.yticks([1, 0], ["Piastri", "Verstappen"])
plt.xlabel("Laps")
plt.title("2025 Qatar Race - Pit Strategy Comparison of Oscar Piastri and Max Verstappen")

output_path = "../images/qatar_race_timeline.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# The graphic above, though for only two drivers, is a compact way of comparing the driver's race team **pit strategy.**

# %% [markdown]
# ### 2.3.4 Investigation of the McLaren Pit Strategy Error at the 2025 Qatar Grand Prix

# %% [markdown]
# Having watched the 2025 Qatar race on a streaming service, and having googled the event online, two cars collided on lap 7 of the race which caused a Safety Car to be deployed. From querying the lap info 'Position' column, we know that Oscar started 1st, and Max started 2nd, yet Oscar finished 2nd, and Max finished 1st.  From the race timeline plot above, both drivers started the race on MEDIUM tires, and adhered to the two-compound F1 policy, and the max-laps-of-25 Pirelli tire supplier policy.   The timeline plot indicates that Max pitted on lap 7 and put on new set of MEDIUM tires, whereas Oscar pitted on lap 24, putting on new set of MEDIUM tires as well.  Two important pit strategy questions are **"why did Red Bull pit Max on lap 7 after the safety car was deployed?"**, and **"why did McLaren chose not to pit on lap 7?"**.

# %% [markdown]
# We can't be sure why McLaren did not pit, but we can be sure why Red Bull and the rest of the racing did pit

# %% [markdown]
# Given the **Pirelli max stint = 25 laps policy** at Qatar meant that all teams would have to pit twice.  Therefore, prior to the race, each team would have developed a strategy that consisted of two pits, max stint of 25 laps, and use of two different tire compounds.   Viable pit stragies for Qatar included this strategy - pit on lap 7, then pit again at lap 32, such that Stint 1 = 7 laps, Stint 2 = 25 laps, and Stint 3 = 25 laps.  For this and each compliant pit strategy, a pitstop requires entering pit lane, changing the tires, and exiting pit lane.   Each team works hard to minimize the time lost, or elapsed time added, since this adds to the overall elapsed time of a race.

# %% [markdown]
# **An additional consideration for optimizing pit strategy.**  When a race accident occurs, the status of the race moves from **"Green"** to **"Yellow"**.  Under Yellow conditions a Virtual Safety car or an actual Safety Car may be deployed while the race accident is cleared.  Pitting during under a Safety Car deployment, or under a Virtual Saftey Car deployment takes less time than pitting under normal or "Green" racing conditions.  At Qatar, under "Green" conditions, a pitstop **adds approximately 27-30 seconds of elapsed time to that particular lap**.   Whereas pitting under "Yellow" conditions **only adds a 12-15 seconds of lap time**.  Each time uses this input to develop pit stragies since pitting under a yellow will minimize the **cost** of a required pit stop.

# %% [markdown]
# When racing conditions merited a Safety Car on lap 7, each team had to make a decision to pit or not pit.  Pitting on lap 7 is just barely a viable pit strategy, since pitting any earlier would have required two more pits for a total of three pit stops.  Since McLaren did not pit on lap 7, they would potentially incur the full cost of pitting under "Green" conditions as shown below.

# %%
data = {
    "Driver": ["Piastri", "Verstappen"],
    "Driver First Pit Loss - Seconds": [30, 15],
    "Driver Second Pit Loss - Second": [30, 30],
}
df = pd.DataFrame(data)

# Swap rows and columns
df = df.set_index("Driver").T
df_sum = df[["Piastri","Verstappen"]].sum().to_frame(name="Total Time (seconds) Lost During Pitstops")
df_sum

# %% [markdown]
# From above, since McLaren's Oscar Piastri did not pit under the Safety Car, he would make up 15 seconds from the two "Green" pit losses to contend for 1st position.  Making up 15 seconds over the course of the remaining 50 laps beginning with lap 8 was not impossible, but extremely difficult and unlikely.  **Ultimately, from below, we see that Oscar finished 7.995 seconds behind Max, losing the race.**

# %%
pia_laps = pia_laps.copy()
ver_laps = ver_laps.copy()

pia_laps.loc[:, "Time"] = pd.to_timedelta(pia_laps["Time"])
ver_laps.loc[:, "Time"] = pd.to_timedelta(ver_laps["Time"])

finish_time_delta = abs(ver_laps["Time"].iloc[-1] - pia_laps["Time"].iloc[-1])
finish_time_delta

# %% [markdown]
# **The calculated result above is consistent with the race results reported on the F1 website.**

# %% [markdown]
# ![Race Strategy Screenshot](../images/F1_2025_Qatar_Results.png)

# %% [markdown]
# ### 2.3.5  Visualization of the McLaren Lap 7 Stategy Error

# %% [markdown]
# The following code with race position plotting was derived from example FastF1 code found here, https://docs.fastf1.dev/gen_modules/examples_gallery/results_strategy/plot_position_changes.html# .

# %% [markdown]
# The plot that follows is a visualization of race position for drivers Max Verstappen and Oscar Piastri.  The race positon information coupled with the tire stint visualization above **completes visual story** of the McLaren lap 7 pit error.  The narrative for the plot is provided below the plot.

# %%
import fastf1.plotting
import matplotlib.pyplot as plt

# Pirelli compound colors
COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

fastf1.plotting.setup_mpl(mpl_timedelta_support=False, color_scheme='fastf1')

session = fastf1.get_session(2025, 'Qatar Grand Prix', 'R')
session.load(telemetry=False, weather=False)

target_drivers = ["VER", "PIA"]

fig = plt.figure(figsize=(16, 8))

# --- TOP AXIS: STINT BARS ---
ax_stints = fig.add_subplot(2, 1, 1)

for i, drv in enumerate(target_drivers):
    drv_laps = session.laps.pick_drivers(drv)

    # Extract pit-in laps
    pit_laps = drv_laps.loc[drv_laps["PitInTime"].notna(), "LapNumber"].tolist()

    for stint_no, stint_laps in drv_laps.groupby("Stint"):
        start = stint_laps["LapNumber"].min()
        end = stint_laps["LapNumber"].max()
        width = end - start + 1

        compound = stint_laps["Compound"].iloc[0].upper()
        color = COMPOUND_COLORS.get(compound, "white")

        # Draw the stint bar
        ax_stints.barh(
            y=i,
            width=width,
            left=start,
            color=color,
            edgecolor="black",
            alpha=0.9
        )

        center_x = start + width / 2

        # --- NEW: Stint number + length in one line ---
        ax_stints.text(
            x=center_x,
            y=i + 0.25,
            s=f"STINT {int(stint_no)} = {int(width)} laps",
            ha="center",
            va="center",
            fontsize=9,
            color="black"
        )

        # --- Compound text (center of bar) ---
        ax_stints.text(
            x=center_x,
            y=i,
            s=compound,
            ha="center",
            va="center",
            fontsize=10,
            fontweight="bold",
            color="black"
        )

        # --- PIT LAP LABEL (below compound) ---
        if end in pit_laps:
            pit_lap = int(end)
            ax_stints.text(
                x=center_x,
                y=i - 0.28,
                s=f"PIT LAP {pit_lap}",
                ha="center",
                va="center",
                fontsize=9,
                color="black"
            )

    # Driver label
    ax_stints.text(-1, i, drv, va="center", ha="right", fontsize=12)

ax_stints.set_yticks([])
ax_stints.set_xlim(0, session.laps["LapNumber"].max())
ax_stints.set_title("Qatar 2025 - Stint Timeline")

# --- BOTTOM AXIS: POSITION VS LAP ---
ax_pos = fig.add_subplot(2, 1, 2, sharex=ax_stints)

for drv in target_drivers:
    drv_laps = session.laps.pick_drivers(drv)

    style = fastf1.plotting.get_driver_style(
        identifier=drv,
        style=['color', 'linestyle'],
        session=session
    )

    ax_pos.plot(
        drv_laps["LapNumber"],
        drv_laps["Position"],
        label=drv,
        **style
    )

ax_pos.set_ylim(6.2, 0.8)
ax_pos.set_yticks([1, 2, 3, 4, 5, 6])
ax_pos.set_xlabel("Lap")
ax_pos.set_ylabel("Race Position")
ax_pos.set_title("Qatar 2025 Position vs Lap")
ax_pos.legend()

plt.tight_layout()

# save file for future reference
plt.savefig("../images/qatar_2025_winning_strategy.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ### 2.3.6 Summary of Findings and a Proposed Strategy Optimization Approach

# %% [markdown]
# The Qatar race results proved costly for McLaren team (Oscar Piastri and Lando Norris).
# Max earned 25 points for the race win, whereas Oscar earned only 18 points for finishing 2nd.

# %% [markdown]
# From above, as mentioned prior, pitting under a Safety Car ("yellow conditions) can minimize the costs associated with required pit stops.  Accordingly,  as race conditions unfold, an F1 race team must evaluate and change the pre-planned strategy for the race. Above, Oscar started in first place, then pitted at lap 24, and again at lap 42 incurring the full costs associated with pitting under "Green".  Max on the other hand pitted on lap 7 under "Yellow", saving the cost of pitting under "Green" conditions.  When Oscar pitted on lap 42, he incurred the full cost of the pit, allowing Max to move into 1st place, and ultimately winning the race.

# %% [markdown]
# The 2025 F1 drivers championship was decided on the last race of the season, with Lando Norris finishing with 423 points, Max Verstappen with 421 points and Oscar Piastri with 410 points.  With just 2 points separating the 1st and 2nd position, the season championship could have come down to this one bad strategy call - the failure to Pit on Lap 7. Fortunately McLaren overcame this strategy error and went on to win the season. **The criticality of pit decisions is evident and getting the pit and tire strategies right merits the proper investment and usage of decision analysis tools enabling pit strategies to be changed and executed in real-time.**

# %% [markdown]
# Pit Strategy Optimization Inputs.  Inputs to consider as part of strategy optimization:
#
# * F1 Rule - 2 tire different tire compounds
# * F1 Venue Rules - pit stops required for venues (2 pit stops at Monaco for example)
# * Tire Supplier Rules - 25 max laps per compound at Qatar
# * Track Status Events - deployment of Safety Car or Virtual Safety Car due to collisions, debris, etc. - model of pit loss during "Green" vs "Yellow" status
# * Fuel Consumption - model of lap time improvement from fuel consumption (as the car gets lighter, lap time improves)
# * Tire Compound Performance - model of lap time degradation for each compound - degredation is not linear has clifts

# %% [markdown]
# Pit Strategy Optimization outputs:
# * Pre-set strategies determined prior to race weekend
# * Pre-race strategy changes due to practice and qualification observation - fuel consumption and tire degredation
# * During-race strategy changes due to track status - deployment of Virtual Safety Cars or Safety Cars

# %% [markdown]
# # 3.0 Data Preparation

# %% [markdown]
# Given the nature of the fastf1.com api, there is no need to webscrape, develop proxies for missing data, or combine other data sources.   The datasets available in FastF1 are complete and robust and ready for analysis as is.

# %% [markdown]
# # 4.0 Modeling

# %% [markdown]
# Answering the business question, "**Should we pit now, or stay out?**" can be answered by building pre-race strategies, and updating those strategies as needed in real-time during the race.
#
# Accordingly, the modeling approach is to build pit strategies, by **iterating** through all valid strategies that adhere to F1 tire and F1 venue policies.  Each valid pit strategy will be simulated.  Finally, the best performing strategies will be chosen that minimize race elapsed time.
#
# Two things are critical toward developing a model - **understanding lap times per lap, and cumulative race time.**

# %% [markdown]
# ## 4.1 Understanding and visualization of lap time and elapsed time

# %%
# ============================================================
#  FASTF1 — MAX VERSTAPPEN LAP TIMES (ACTUAL ONLY)
#  SCATTER PLOT + CUMULATIVE RACE TIME
# ============================================================

import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import fastf1

# Force black background for ALL plots
plt.style.use("dark_background")

# ------------------------------------------------------------
# FASTF1 SETUP
# ------------------------------------------------------------
os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")


# ------------------------------------------------------------
# LOAD ACTUAL FASTF1 LAPS
# ------------------------------------------------------------
def load_actual_laps(year, gp, session_name, driver):
    session = fastf1.get_session(year, gp, session_name)
    session.load()

    laps = session.laps.pick_drivers(driver)
    laps = laps[["LapNumber", "LapTime", "Compound"]].copy()
    laps["LapTime"] = laps["LapTime"].dt.total_seconds()

    return laps


# ------------------------------------------------------------
# SCATTER PLOT OF LAP TIMES
# ------------------------------------------------------------
def plot_lap_scatter(actual_df, driver):
    COMPOUND_COLORS = {
        "SOFT": "#FF3333",
        "MEDIUM": "#FFCC33",
        "HARD": "#FFFFFF",
        "INTERMEDIATE": "#39B54A",
        "WET": "#00AEEF"
    }

    plt.figure(figsize=(14, 6))

    for comp, grp in actual_df.groupby("Compound"):
        plt.scatter(
            grp["LapNumber"],
            grp["LapTime"],
            s=60,
            color=COMPOUND_COLORS.get(comp.upper(), "gray"),
            edgecolor="black",
            marker="o",
            alpha=0.85,
            label=f"{driver} – {comp}"
        )

    plt.xlabel("Lap Number")
    plt.ylabel("Lap Time (seconds)")
    plt.title(f"{driver} — Lap Times by Compound")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


# ------------------------------------------------------------
# BUILD CUMULATIVE TIME
# ------------------------------------------------------------
def build_actual_cumulative(actual_df):
    df = actual_df.copy()
    df = df.sort_values("LapNumber")
    df["cumulative_time"] = df["LapTime"].cumsum()
    return df


# ------------------------------------------------------------
# CUMULATIVE RACE TIME PLOT
# ------------------------------------------------------------
def plot_cumulative(actual_df, driver):
    print("CUMULATIVE FUNCTION RAN — rows:", len(actual_df))

    plt.figure(figsize=(14, 6))

    plt.plot(
        actual_df["LapNumber"],
        actual_df["cumulative_time"],
        label=f"Actual {driver}",
        color="#C77DFF",  # bright purple
        linewidth=3.5,
        marker="o",
        markersize=5,
        alpha=1.0
    )

    final_time = actual_df["cumulative_time"].iloc[-1]

    # Text box inside plot
    text = f"Final Race Time:\n{final_time:.3f} seconds"

    plt.text(
        0.02, 0.98, text,
        transform=plt.gca().transAxes,
        fontsize=12,
        verticalalignment="top",
        color="white",
        bbox=dict(facecolor="black", alpha=0.6, edgecolor="white")
    )

    plt.xlabel("Lap Number")
    plt.ylabel("Cumulative Race Time (seconds)")
    plt.title(f"Cumulative Race Time — {driver}")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


# ------------------------------------------------------------
# MAIN EXECUTION
# ------------------------------------------------------------
if __name__ == "__main__":
    driver = "VER"

    actual = load_actual_laps(2025, "Qatar", "R", driver)

    # Plot 1: Lap-by-lap scatter
    plot_lap_scatter(actual, driver)

    # Plot 2: Cumulative race time
    actual_cum = build_actual_cumulative(actual)
    plot_cumulative(actual_cum, driver)

# %%
import fastf1

# Load the same session you used in the plotting code
session = fastf1.get_session(2025, "Qatar", "R")
session.load()

# Pull Max's laps
drv_laps = session.laps.pick_drivers("VER")

# Total elapsed race time in seconds
finish_time_seconds = drv_laps["LapTime"].dt.total_seconds().sum()

print(f"Max Verstappen official finish time: {finish_time_seconds:.3f} seconds")

# %% [markdown]
# Now we review the two plots above, with the winning strategy for Max Verstappen.

# %% [markdown]
# ![Qatar 2025 Winning Strategy](../images/qatar_2025_winning_strategy.png)

# %% [markdown]
# From above, we see Max's laptime per lap, and the cumulative lap time and the winning pit-strategy, Medium 7 laps, then pit on Safety Car, Medium 25 laps, then pit on lap 32 with Hard tires to finish the race.   Our proposed model for selecting a winning strategy is to choose a strategy from all possible strategies, and evaluate those strategies using a race simulator.   So our next step is to build a race simulator with the simplest of fuel consumption and tire degredation models, then compare our race simulator results with the actual 2025 Qatar race results.  Afterwards we will build an iterator that enumerates all possible strategies.

# %% [markdown]
# Here we are going to build the core code for evaluating pre-race strategies, and real-time strategies.

# %% [markdown]
# Now generate the remaining strategies.

# %% [markdown]
# ## 📌 Strategy Engine Overview & Execution Order
#
# This notebook contains **two independent modeling pipelines**:
#
# ---
#
# ### **1. Modeling Pipeline (Data‑Driven Tire & Fuel Models)**
# This section loads stint data, removes fuel effect, trains SVM‑RBF tire models, and fits a linear fuel‑consumption model.
# It produces:
#
# - `models_M["svm"]` and `models_H["svm"]`
# - `fuel_slope`, `fuel_intercept`
# - `le` (LabelEncoder)
#
# These objects are required for the ML‑powered lap time model.
#
# ---
#
# ### **2. Strategy Engine (Blocks 1–9)**
# This section computes:
#
# - pre‑race strategy predictions
# - race‑day Safety Car stay‑out logic
# - pit‑now vs stay‑out deltas
# - full‑race simulation timing
#
# The strategy engine always calls a unified function:

# %% [markdown]
# This selector controls which lap time model the strategy engine uses.
#
# ---
#
# ## ▶️ **Correct Execution Order**
#
# To run the full notebook successfully:
#
# 1. **Run Strategy Block 1**
#    (defines both lap time models, but not the selector)
#
# 2. **Run all Modeling Blocks (1 → 2.5 → H1)**
#    (trains SVM models and fuel model)
#
# 3. **Run the Model Selector Block**
#    (defines the unified `lap_time()` function)
#
# 4. **Run Strategy Blocks 2–9**
#    (pre‑race strategies, SC logic, pit‑now vs stay‑out)
#
# ---
#
# This structure preserves the full evolution of the project while keeping the strategy engine fully functional.

# %%
# ============================================================
# Strategy BLOCK 1 — Corrected BASE / DEG for Qatar (Max‑Style)
# ============================================================

# These values make:
#   - Medium the best race tire (fastest over long stints)
#   - Hard slightly slower but durable
#   - Soft fast but fragile (short stints only)

BASE = {
    "S": 85.8,  # Soft: fastest but fragile
    "M": 85.65,  # Medium: fast but not dominant
    "H": 85.75  # Hard: slightly slower base pace
}

DEG = {
    "S": 0.022,  # Soft: highest deg
    "M": 0.018,  # Medium: higher deg so it loses long stints
    "H": 0.009  # Hard: lowest deg, wins long stints
}

# Your iterative tuning adjustments
BASE["M"] -= 0.02
DEG["M"] += 0.0005
BASE["M"] += 0.015
DEG["M"] += 0.0003
BASE["H"] -= 0.01
BASE["M"] += 0.005
DEG["M"] += 0.0001
BASE["H"] -= 0.005
BASE["M"] += 0.003
DEG["M"] += 0.00005
BASE["H"] -= 0.003
DEG["M"] += 0.00020


def lap_time_base_deg(compound, lap_in_stint):
    """Original pre-race quadratic-safe degradation model."""
    base = BASE[compound]
    deg = DEG[compound]
    return base + deg * (lap_in_stint ** 1.2)


def lap_time_svm(compound, lap_in_stint, race_lap):
    """Lap time using SVM tire model + optional fuel model."""

    # Build a DataFrame with correct column names
    pred_df = pd.DataFrame({
        "compound": [compound],
        "lap_in_stint": [lap_in_stint]
    })

    # Predict tire-only lap time
    if compound == "M":
        tire = models_M["SVM"].predict(pred_df)[0]
    elif compound == "H":
        tire = models_H["SVM"].predict(pred_df)[0]
    else:
        raise ValueError("Unknown compound")

    # Fuel effect: only apply if race_lap is provided
    if race_lap is None:
        fuel = 0.0
    else:
        fuel = fuel_slope * race_lap + fuel_intercept

    return tire + fuel





def stint_time(compound, stint_length):
    """Total time for a single stint."""
    return sum(lap_time(compound, lap) for lap in range(1, stint_length + 1))


def strategy_time(strategy):
    """Total race time for a full strategy."""
    return sum(stint_time(comp, length) for comp, length in strategy)

# %%
class RaceConfig:
    def __init__(self,
                 track_name,
                 track_length_km,
                 fuel_per_lap,
                 fuel_mass_penalty,
                 start_fuel,
                 min_lap_time):

        self.track_name = track_name
        self.track_length_km = track_length_km
        self.fuel_per_lap = fuel_per_lap
        self.fuel_mass_penalty = fuel_mass_penalty
        self.start_fuel = start_fuel
        self.min_lap_time = min_lap_time

        # REQUIRED for strategy generator
        self.compounds = ["M", "H"]
        self.start_compound = "M"

# %%
USE_MODEL = "SVM"

# %%
USE_MODEL = "BASE"

# %%
config = RaceConfig(
    track_name="Qatar",
    track_length_km=5.419,
    fuel_per_lap=1.7,
    fuel_mass_penalty=0.035,
    start_fuel=110,
    min_lap_time=80.0
)

# %%
# ============================================================
# Strategy BLOCK 2 — Track Rules + Strategy Filtering (Final)
# ============================================================

"""
This block defines:

TRACK_RULES
filter_strategies

Key improvements:
- Pit-loss values are now stored inside TRACK_RULES (no global constants).
- All track-level constraints live in one place.
- No physics, no lap-time logic, no degradation here.
"""

TRACK_RULES = {
    "Qatar": {
        "max_laps_per_set": 25,
        "min_stops": 0,
        "must_use_two_compounds": True,
        "pit_loss_green": 32.0,
        "pit_loss_sc": 8.0,
        "pit_loss_vsc": 10.0,
    },

    "Monaco_2025": {
        "max_laps_per_set": None,  # no max
        "min_stops": 2,  # mandatory 2-stop rule
        "must_use_two_compounds": True,
        "pit_loss_green": 28.0,
        "pit_loss_sc": 7.0,
        "pit_loss_vsc": 9.0,
    },

    "Monaco_2026": {
        "max_laps_per_set": None,
        "min_stops": 0,  # rule removed
        "must_use_two_compounds": True,
        "pit_loss_green": 28.0,
        "pit_loss_sc": 7.0,
        "pit_loss_vsc": 9.0,
    },

    # Add more tracks as needed...
}


def filter_strategies(strategies, rules, config):
    """
    Apply track rules to a list of strategies.
    Each strategy is a list of (compound, laps) tuples.

    This function:
      - enforces compound diversity
      - enforces max laps per set
      - enforces minimum stops
    It does NOT compute lap times or touch physics.
    """

    filtered = []

    for stints in strategies:

        # ------------------------------------------------------------
        # Rule A: Must use at least 2 different compounds
        # ------------------------------------------------------------
        if rules.get("must_use_two_compounds", True):
            compounds = {comp for comp, laps in stints}
            if len(compounds) < 2:
                continue

        # ------------------------------------------------------------
        # Rule B: Max laps per set (if defined)
        # ------------------------------------------------------------
        max_laps = rules.get("max_laps_per_set", None)
        if max_laps is not None:
            if any(laps > max_laps for comp, laps in stints):
                continue

        # ------------------------------------------------------------
        # Rule C: Minimum number of stops
        # ------------------------------------------------------------
        min_stops = rules.get("min_stops", 0)
        num_stops = len(stints) - 1
        if num_stops < min_stops:
            continue

        filtered.append(stints)

    return filtered

# %%
# ============================================================
# Strategy BLOCK 3 — Pre‑Race Top‑3 Strategy Generator (Medium‑Start)
# ============================================================

def pre_race_top_strategies(total_laps, track_name, config, max_laps_per_set):
    """
    Generate realistic pre-race strategies:
      - Always start on Medium (Max-style Qatar baseline)
      - 2-stop (3 stints)
      - 3-stop (4 stints)
    Uses simplified strategy_time(strategy).
    """

    compounds = config.compounds
    strategies = []

    # ------------------------------------------------------------
    # Qatar stint windows (realistic)
    # ------------------------------------------------------------
    stint_min = 15
    stint_max = 27

    # ------------------------------------------------------------
    # Force Medium start (Max-style)
    # ------------------------------------------------------------
    start_compound = "M"

    # ============================================================
    # 1. Generate 2-stop strategies (3 stints)
    # ============================================================
    for c2 in compounds:
        for c3 in compounds:

            # No identical consecutive compounds
            if start_compound == c2 or c2 == c3:
                continue

            for s1 in range(stint_min, stint_max + 1):
                for s2 in range(stint_min, stint_max + 1):

                    s3 = total_laps - (s1 + s2)
                    if s3 < stint_min or s3 > stint_max:
                        continue

                    # Pirelli max-lap rule
                    if (
                            s1 > max_laps_per_set or
                            s2 > max_laps_per_set or
                            s3 > max_laps_per_set
                    ):
                        continue

                    stints = [
                        (start_compound, s1),
                        (c2, s2),
                        (c3, s3)
                    ]

                    t = strategy_time(stints)
                    strategies.append((t, stints))

    # ============================================================
    # 2. Generate 3-stop strategies (4 stints)
    # ============================================================
    for c2 in compounds:
        for c3 in compounds:
            for c4 in compounds:

                if start_compound == c2 or c2 == c3 or c3 == c4:
                    continue

                for s1 in range(stint_min, stint_max + 1):
                    for s2 in range(stint_min, stint_max + 1):
                        for s3 in range(stint_min, stint_max + 1):

                            s4 = total_laps - (s1 + s2 + s3)
                            if s4 < stint_min or s4 > stint_max:
                                continue

                            if (
                                    s1 > max_laps_per_set or
                                    s2 > max_laps_per_set or
                                    s3 > max_laps_per_set or
                                    s4 > max_laps_per_set
                            ):
                                continue

                            stints = [
                                (start_compound, s1),
                                (c2, s2),
                                (c3, s3),
                                (c4, s4)
                            ]

                            t = strategy_time(stints)
                            strategies.append((t, stints))

    # ------------------------------------------------------------
    # Return top‑3 fastest
    # ------------------------------------------------------------
    strategies.sort(key=lambda x: x[0])
    return strategies[:3]

# %%
# ============================================================
# Strategy BLOCK 4 — Stay‑Out Projection (Refactored, Final)
# ============================================================

def continue_existing_strategy(existing_strategy, current_lap):
    """
    Return the remainder of the original strategy if the driver does NOT pit.

    This function is intentionally independent of:
      - BASE pace
      - degradation model
      - compounds
      - max_laps_per_set
      - RaceConfig

    It simply slices the original plan at the current lap and returns
    the remaining stints exactly as planned.
    """
    laps_so_far = 0
    remaining = []

    for idx, (compound, stint_len) in enumerate(existing_strategy):
        next_laps = laps_so_far + stint_len

        if current_lap <= next_laps:
            # We are inside this stint
            laps_into_stint = current_lap - laps_so_far
            laps_left = stint_len - laps_into_stint

            # Add the remainder of the current stint
            remaining.append((compound, laps_left))

            # Add all future stints unchanged
            remaining.extend(existing_strategy[idx + 1:])
            return remaining

        laps_so_far = next_laps

    raise ValueError(
        f"Current lap {current_lap} exceeds total laps in existing strategy "
        f"({laps_so_far})."
    )

# %%
# ============================================================
# Strategy BLOCK 5 — Pit‑Now Strategy Generator (Updated Version)
# Supports both 1‑stop and 2‑stop plans after SC
# ============================================================

def pit_now_strategies_b2(current_lap, total_laps, first_compound,
                          config,
                          max_laps_per_set):
    """
    Generate realistic pit-now strategies after a Safety Car or VSC.

    Supports:
      - 1-stop remaining (2 stints total after SC)  <-- Max-style
      - 2-stop remaining (3 stints total after SC)

    Rules:
      - Medium preferred for mid stints
      - Hard preferred for long stints
      - Soft banned from long stints
      - No triple-same-compound
      - Qatar long-stint windows (15–27 laps)
    """

    compounds = config.compounds

    # *** FIXED OFF-BY-ONE ***
    # Correct laps remaining after SC stop at lap N:
    # laps 8..57 = 50, not 51
    laps_remaining = total_laps - current_lap

    strategies = []

    # ------------------------------------------------------------
    # Qatar long-stint mode
    # ------------------------------------------------------------
    long_stint_mode = (config.track_name.lower() == "qatar")

    # Default quadratic-safe windows
    mid_min, mid_max = 12, 22
    last_min, last_max = 12, 22

    # Qatar override: allow Max-style 20–27 lap stints
    if long_stint_mode:
        mid_min, mid_max = 15, 27
        last_min, last_max = 15, 27

    # ------------------------------------------------------------
    # Compound validity rules
    # ------------------------------------------------------------
    def is_valid_mid(comp):
        return comp != "S"

    def is_valid_last(comp):
        return comp != "S"

    # ============================================================
    # 1-STOP REMAINING (2 stints total after SC)
    # Max-style: (first_compound, long_stint), (last_comp, long_stint)
    # ============================================================

    # Allow the first stint after SC to be long (not forced to 8 laps)
    for first_len in range(mid_min, min(mid_max + 1, laps_remaining)):

        rem = laps_remaining - first_len
        if rem < last_min or rem > last_max:
            continue

        if first_len > max_laps_per_set or rem > max_laps_per_set:
            continue

        for last_comp in compounds:
            if not is_valid_last(last_comp):
                continue

            # Avoid same-compound 2-stint plans if desired
            if last_comp == first_compound:
                continue

            strategies.append([
                (first_compound, first_len),
                (last_comp, rem)
            ])

    # ============================================================
    # 2-STOP REMAINING (3 stints total after SC)
    # Existing logic: (first_compound, 8), (mid_comp, mid_len), (last_comp, last_len)
    # ============================================================

    # Keep your original short first stint for the 3-stint shapes
    first_stint = min(8, laps_remaining)
    rem = laps_remaining - first_stint

    if rem > 0:
        for mid_comp in compounds:
            if not is_valid_mid(mid_comp):
                continue

            for last_comp in compounds:
                if not is_valid_last(last_comp):
                    continue

                # Disallow triple-same-compound (e.g., H-H-H or M-M-M)
                if mid_comp == first_compound and last_comp == first_compound:
                    continue

                # Disallow H-H after SC (prefer M-H or H-M)
                if mid_comp == "H" and last_comp == "H":
                    continue

                for mid_len in range(mid_min, min(mid_max + 1, rem)):
                    last_len = rem - mid_len

                    if last_len < last_min or last_len > last_max:
                        continue

                    if mid_len > max_laps_per_set or last_len > max_laps_per_set:
                        continue

                    strategies.append([
                        (first_compound, first_stint),
                        (mid_comp, mid_len),
                        (last_comp, last_len)
                    ])

    # ------------------------------------------------------------
    # Guarantee at least one strategy
    # ------------------------------------------------------------
    if not strategies:
        last_len = min(laps_remaining, max_laps_per_set)
        last_comp = "H" if "H" in compounds else compounds[-1]

        strategies.append([
            (first_compound, last_len)
        ])

    return strategies

# %%
# ============================================================
# Strategy BLOCK 6 — Race‑Day Decision Logic (Final Corrected Version)
# ============================================================

def race_day_decision(existing_strategy,
                      current_lap,
                      flag,
                      total_laps,
                      config,
                      max_laps_per_set,
                      pit_loss_green,
                      pit_loss_sc,
                      pit_loss_vsc):
    """
    Decide whether to pit now or stay out under GREEN / SC / VSC.
    Uses simplified strategy_time(strategy) and correctly charges
    all remaining pit stops for both stay-out and pit-now paths.
    """

    # ------------------------------------------------------------
    # 1. Stay-out path
    # ------------------------------------------------------------
    stay_out = continue_existing_strategy(existing_strategy, current_lap)

    # Number of remaining stops in the stay-out plan
    stay_out_remaining_stops = max(len(stay_out) - 1, 0)

    # All remaining stops are green-flag stops
    stay_out_time = (
            strategy_time(stay_out)
            + stay_out_remaining_stops * pit_loss_green
    )

    # ------------------------------------------------------------
    # 2. Pit loss based on flag
    # ------------------------------------------------------------
    pit_loss_flag = {
        "GREEN": pit_loss_green,
        "SC": pit_loss_sc,
        "VSC": pit_loss_vsc
    }[flag]

    # ------------------------------------------------------------
    # 3. Generate pit-now strategies
    # ------------------------------------------------------------
    first_compound = existing_strategy[0][0]

    pit_now_strats = pit_now_strategies_b2(
        current_lap=current_lap,
        total_laps=total_laps,
        first_compound=first_compound,
        config=config,
        max_laps_per_set=max_laps_per_set
    )

    # ------------------------------------------------------------
    # 4. Score pit-now strategies
    # ------------------------------------------------------------
    scored = []
    for st in pit_now_strats:
        # Total stops in the pit-now plan
        total_stops = max(len(st) - 1, 0)

        # One stop is the SC/VSC stop; the rest are green
        extra_green_stops = max(total_stops - 1, 0)

        t = (
                strategy_time(st)
                + pit_loss_flag  # SC/VSC stop
                + extra_green_stops * pit_loss_green  # later green stop(s)
        )

        scored.append((t, st))

    scored.sort(key=lambda x: x[0])
    pit_now_top3 = scored[:3]

    # ------------------------------------------------------------
    # 5. Deltas vs stay-out
    # ------------------------------------------------------------
    deltas = [(t - stay_out_time, st) for t, st in pit_now_top3]

    return {
        "stay_out_strategy": stay_out,
        "stay_out_time": stay_out_time,
        "pit_now_top3": pit_now_top3,
        "deltas_vs_stay_out": deltas
    }

# %% [markdown]
# **Strategy Test Harness**

# %%
# ============================================================
# Strategy BLOCK 9 — Unified Test Harness
# ============================================================

# 1. Select track
track = "Qatar"
rules = TRACK_RULES[track]

# 2. Pre-race top-3 strategies
top3 = pre_race_top_strategies(
    total_laps=57,
    track_name=track,
    config=config,
    max_laps_per_set=rules["max_laps_per_set"]
)

print("=== Pre-Race Top 3 Strategies ===")
for t, st in top3:
    print(f"{t:.3f}  {st}")

# 3. Race-day SC decision at lap 7
result = race_day_decision(
    existing_strategy=top3[0][1],
    current_lap=7,
    flag="SC",
    total_laps=57,
    config=config,
    max_laps_per_set=rules["max_laps_per_set"],
    pit_loss_green=rules["pit_loss_green"],
    pit_loss_sc=rules["pit_loss_sc"],
    pit_loss_vsc=rules["pit_loss_vsc"],
)

print("\n=== Race-Day SC Decision ===")
print("Stay-out strategy:", result["stay_out_strategy"])
print("Stay-out time:", result["stay_out_time"])

print("\nPit-now top 3:")
for t, st in result["pit_now_top3"]:
    print(f"{t:.3f}  {st}")

print("\nDeltas vs stay-out:")
for d, st in result["deltas_vs_stay_out"]:
    print(f"{d:.3f}  {st}")
# Out:
# === Pre-Race Top 3 Strategies ===
# 4897.576  [('M', 16), ('H', 25), ('M', 16)]
# 4897.617  [('M', 15), ('H', 25), ('M', 17)]
# 4897.617  [('M', 17), ('H', 25), ('M', 15)]
#
# === Race-Day SC Decision ===
# Stay-out strategy: [('M', 9), ('H', 25), ('M', 16)]
# Stay-out time: 4359.086316358344
#
# Pit-now top 3:
# 4308.522  [('M', 25), ('H', 25)]
# 4335.393  [('M', 8), ('M', 17), ('H', 25)]
# 4335.393  [('M', 8), ('H', 25), ('M', 17)]
#
# Deltas vs stay-out:
# -50.564  [('M', 25), ('H', 25)]
# -23.694  [('M', 8), ('M', 17), ('H', 25)]
# -23.694  [('M', 8), ('H', 25), ('M', 17)]

# %%
print("globals contains models_M:", "models_M" in globals())
print("globals contains models_H:", "models_H" in globals())
print("globals contains fuel_slope:", "fuel_slope" in globals())
print("globals contains fuel_intercept:", "fuel_intercept" in globals())

# If they exist, print their types
if "models_M" in globals():
    print("models_M type:", type(models_M))
if "models_H" in globals():
    print("models_H type:", type(models_H))
if "fuel_slope" in globals():
    print("fuel_slope:", fuel_slope)
if "fuel_intercept" in globals():
    print("fuel_intercept:", fuel_intercept)

# %% [markdown]
# ## Fuel and Tire Modeling

# %%
# ============================================================
# Modeling BLOCK 1 — Qatar Stint Data Loader (Corrected)
# ============================================================

import fastf1
import pandas as pd
import numpy as np


def load_stint_data(year=2025, gp="Qatar"):
    fastf1.Cache.enable_cache("fastf1_cache")

    session = fastf1.get_session(year, gp, "R")
    session.load()

    # Keep full metadata
    laps = session.laps.copy()

    # --- 1. Keep only green-flag laps ---
    if "TrackStatus" in laps.columns:
        laps = laps[laps["TrackStatus"].isin(["1", ""])]
    else:
        print("⚠️ TrackStatus missing — keeping all laps")

    # --- 2. Remove in/out laps ---
    if "PitOutLap" in laps.columns:
        laps = laps[~laps["PitOutLap"]]
    if "PitInLap" in laps.columns:
        laps = laps[~laps["PitInLap"]]

    # --- 3. Require compound + tyre life ---
    laps = laps.dropna(subset=["Compound", "TyreLife"])

    # --- 4. Build clean DataFrame WITH metadata ---
    df = pd.DataFrame({
        "driver": laps["Driver"],
        "lap_number": laps["LapNumber"],  # <-- CRITICAL
        "lap_time": laps["LapTime"].dt.total_seconds(),
        "compound": laps["Compound"],
        "lap_in_stint": laps["TyreLife"].astype(int),
        "track_temp": laps.get("TrackTemp", pd.Series([np.nan] * len(laps))).astype(float),
        "air_temp": laps.get("AirTemp", pd.Series([np.nan] * len(laps))).astype(float)
    })

    # --- 5. Remove extreme outliers ---
    df = df[df["lap_time"] < df["lap_time"].quantile(0.99)]
    df = df[df["lap_time"] > df["lap_time"].quantile(0.01)]

    return df


# Create df
df = load_stint_data()
print(df.head())
print(df.shape)
# Out:
# events      WARNING 	Correcting user input 'Qatar' to 'Qatar Grand Prix'
# core           INFO 	Loading data for Qatar Grand Prix - Race [v3.7.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
# ============================================================
# Modeling BLOCK 1.5 — Clean Qatar 2025 Stint Data (NO plotting)
# ============================================================

import numpy as np
import pandas as pd


def clean_stint_data(df):
    df = df.copy()

    # --- 0. Map compounds to S/M/H ---
    compound_map = {"SOFT": "S", "MEDIUM": "M", "HARD": "H"}
    df["compound"] = df["compound"].map(compound_map)

    # --- 1. Remove lap 1 of every stint ---
    df = df[df["lap_in_stint"] > 1]

    # --- 2. Remove pit-entry laps (very slow laps) ---
    median = df["lap_time"].median()
    df = df[df["lap_time"] < median + 4]  # Qatar-safe threshold

    # --- 3. Remove statistical outliers ---
    q1 = df["lap_time"].quantile(0.25)
    q3 = df["lap_time"].quantile(0.75)
    iqr = q3 - q1
    upper = q3 + 1.2 * iqr  # conservative, avoids over-filtering

    df = df[df["lap_time"] < upper]

    return df

# %%
# Clean the data (NO PLOT)
df_clean = clean_stint_data(df)

# %%
# ============================================================
# Modeling BLOCK 1.55 — Create Race Lap Number (Correct)
# ============================================================

# Filter to the target driver BEFORE numbering laps
driver = "VER"  # <-- change to your driver code if needed

df_driver = df_clean[df_clean["driver"] == driver].copy()

# Sort by actual chronological order
df_driver = df_driver.sort_values("lap_in_stint").reset_index(drop=True)

# Assign race lap numbers sequentially
df_driver["lap_number"] = df_driver.index + 1

# %%
df_clean.columns
# Out:
# Index(['driver', 'lap_number', 'lap_time', 'compound', 'lap_in_stint',
#        'track_temp', 'air_temp'],
#       dtype='object')

# %%
# ============================================================
# Modeling BLOCK 1.6 — Plot Actual Cleaned Degradation (NO models)
# ============================================================

import matplotlib.pyplot as plt


def plot_actual_degradation(df_clean, compound="M"):
    df_c = df_clean[df_clean["compound"] == compound].copy()
    df_c = df_c.sort_values("lap_in_stint")

    plt.figure(figsize=(12, 7))
    plt.scatter(
        df_c["lap_in_stint"],
        df_c["lap_time"],
        s=20,
        alpha=0.6,
        label=f"Actual Qatar 2025 — {compound}"
    )

    plt.title(f"Actual Cleaned Degradation — Compound {compound}")
    plt.xlabel("Lap in Stint")
    plt.ylabel("Lap Time (s)")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_actual_degradation(df_clean, compound="M")

# %%
# ============================================================
# Modeling BLOCK 1.7 — Fuel Correction Using Race Lap (lap_number)
# ============================================================

from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd


def remove_fuel_effect_all(df_clean, plot_compound="M"):
    corrected_frames = []
    fuel_models = {}

    for compound in df_clean["compound"].unique():
        df_c = df_clean[df_clean["compound"] == compound].copy()
        df_c = df_c.sort_values("lap_number")

        # Fit linear fuel model
        X = df_c[["lap_number"]]
        y = df_c["lap_time"]

        fuel_model = LinearRegression()
        fuel_model.fit(X, y)
        fuel_pred = fuel_model.predict(X)

        # Save model
        fuel_models[compound] = fuel_model

        # Fuel-corrected lap times
        df_c["lap_time_tire_only"] = df_c["lap_time"] - fuel_pred

        corrected_frames.append(df_c)

    df_corrected = pd.concat(corrected_frames, ignore_index=True)

    return df_corrected, fuel_models


# RUN IT
df_corrected, fuel_models = remove_fuel_effect_all(df_clean)

# Extract global fuel slope/intercept (use Medium as reference)
fuel_slope = fuel_models["M"].coef_[0]
fuel_intercept = fuel_models["M"].intercept_

# %%
df_corrected, fuel_models = remove_fuel_effect_all(df_clean)

# %%
def plot_fuel_trend(df_clean, compound="M"):
    df_c = df_clean[df_clean["compound"] == compound].copy()
    df_c = df_c.sort_values("lap_number")  # correct race-lap axis

    # Actual lap times
    laps = df_c["lap_number"].values
    actual = df_c["lap_time"].values

    # Linear fuel model: lap_time_fuel = slope * lap + intercept
    fuel_line = fuel_slope * laps + fuel_intercept
    print(f"fuel_slope     = {fuel_slope:.6f}")
    print(f"fuel_intercept = {fuel_intercept:.6f}")

    plt.figure(figsize=(12, 7))

    # Actual cleaned lap times
    plt.scatter(
        laps,
        actual,
        s=20,
        alpha=0.6,
        label=f"Actual Cleaned — {compound}"
    )

    # Fuel trend line
    plt.plot(
        laps,
        fuel_line,
        color="red",
        linewidth=2,
        label="Linear Fuel Trend"
    )

    plt.title(f"Fuel Trend Fit — Compound {compound}")
    plt.xlabel("Race Lap")
    plt.ylabel("Lap Time (s)")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_fuel_trend(df_clean, "M")
# Out:
# fuel_slope     = -0.059156
# fuel_intercept = 88.374194

# %%
df_corrected.columns
"lap_time_tire_only" in df_corrected.columns
df_corrected.head()
# Out:
#   driver  lap_number  lap_time compound  lap_in_stint  track_temp  air_temp  \
# 0    VER         2.0    87.349        M           2.0         NaN       NaN
# 1    SAI         2.0    88.123        M           2.0         NaN       NaN
# 2    NOR         2.0    87.713        M           2.0         NaN       NaN
# 3    HAD         2.0    88.632        M           2.0         NaN       NaN
# 4    OCO         2.0    89.487        M           2.0         NaN       NaN
#
#    lap_time_tire_only
# 0           -0.906882
# 1           -0.132882
# 2           -0.542882
# 3            0.376118
# 4            1.231118

# %%
# ============================================================
# Modeling BLOCK 2 — Train 4 ML Models (Linear, Tree, KNN, SVM)
# ============================================================

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
import numpy as np


def train_models(df):
    X = df[["compound", "lap_in_stint"]].copy()
    y = df["lap_time_tire_only"]

    pre = ColumnTransformer([
        ("cat", OneHotEncoder(), ["compound"]),
        ("num", StandardScaler(), ["lap_in_stint"])
    ])

    model_defs = {
        "Linear": LinearRegression(),
        "Tree": DecisionTreeRegressor(max_depth=5),
        "KNN": KNeighborsRegressor(n_neighbors=8),
        "SVM": SVR(kernel="rbf", C=10, gamma=0.1)
    }

    models = {}
    metrics = {}

    for name, model in model_defs.items():
        pipe = Pipeline([("pre", pre), ("model", model)])
        pipe.fit(X, y)
        preds = pipe.predict(X)
        rmse = np.sqrt(mean_squared_error(y, preds))
        models[name] = pipe
        metrics[name] = rmse

    return models, metrics


# Train Medium models
df_M = df_corrected[df_corrected["compound"] == "M"].copy()
models_M, metrics_M = train_models(df_M)

# Train Hard models
df_H = df_corrected[df_corrected["compound"] == "H"].copy()
models_H, metrics_H = train_models(df_H)

print("Medium RMSE:")
print(metrics_M)
print("\nHard RMSE:")
print(metrics_H)
# Out:
# Medium RMSE:
# {'Linear': np.float64(0.8062391910712092), 'Tree': np.float64(0.7753311746919099), 'KNN': np.float64(0.8135001564672878), 'SVM': np.float64(0.8142640768056955)}
#
# Hard RMSE:
# {'Linear': np.float64(0.7231024781355464), 'Tree': np.float64(0.7004443156780481), 'KNN': np.float64(0.7149492585768268), 'SVM': np.float64(0.7217209756922739)}

# %%
# ============================================================
# Modeling BLOCK 2.5 — Plot Tire-Only Actual vs Model Predictions
# ============================================================

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


def plot_tire_only_degradation(models, df_corrected, compound="M"):
    # Filter to the chosen compound
    df_c = df_corrected[df_corrected["compound"] == compound].copy()
    df_c = df_c.sort_values("lap_in_stint")

    # Smooth lap range for model curves
    laps = np.linspace(df_c["lap_in_stint"].min(),
                       df_c["lap_in_stint"].max(),
                       200)

    # Build a DataFrame for prediction
    pred_df = pd.DataFrame({
        "compound": [compound] * len(laps),
        "lap_in_stint": laps
    })

    # --- Plot actual tire-only data ---
    plt.figure(figsize=(12, 7))
    plt.scatter(
        df_c["lap_in_stint"],
        df_c["lap_time_tire_only"],
        s=20,
        alpha=0.6,
        label=f"Actual Tire-Only — {compound}"
    )

    # --- Plot each model's tire-only prediction ---
    for name, model in models.items():
        preds = model.predict(pred_df)
        plt.plot(laps, preds, linewidth=2, label=name)

    plt.title(f"Tire-Only Degradation — Actual vs Models — Compound {compound}")
    plt.xlabel("Lap in Stint")
    plt.ylabel("Tire-Only Lap Time (s, fuel-corrected)")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_tire_only_degradation(models_M, df_corrected, compound="M")

# %%
plot_tire_only_degradation(models_H, df_corrected, compound="H")

# %%
# ============================================================
# Unified Lap-Time Selector (Run AFTER all modeling blocks)
# ============================================================

# Choose which lap-time model the strategy engine should use.
# Options:
#   "BASE" — uses lap_time_base_deg (pre-race model)
#   "SVM"  — uses lap_time_svm (ML + fuel model)

USE_MODEL = "BASE"  # <-- set this AFTER running this block


def lap_time(compound, lap_in_stint, race_lap=None):
    if USE_MODEL == "BASE":
        return lap_time_base_deg(compound, lap_in_stint)
    elif USE_MODEL == "SVM":
        return lap_time_svm(compound, lap_in_stint, race_lap)
    else:
        raise ValueError("Unknown model selector")

# %%
USE_MODEL = "SVM"

# %% [markdown]
# ## 4.2 Build a Race Simulator

# %% [markdown]
# Next we will build a race simulator, with the simplest of fuel consumption and tire degredation models, then compare the simulator output to the actual Qatar 2025 results.

# %%
# ============================================================
#  FASTF1 ACTUAL DATA vs SIMULATOR (USER-PROVIDED STINTS)
#  + SCATTER COMPARISON
#  + CUMULATIVE RACE TIME COMPARISON
# ============================================================

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import fastf1

# Force black background for ALL plots
plt.style.use("dark_background")

# ------------------------------------------------------------
# FASTF1 SETUP
# ------------------------------------------------------------
os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")

# ------------------------------------------------------------
# SIMULATOR CONSTANTS
# ------------------------------------------------------------
TOTAL_LAPS = 57
PIT_LOSS = 16
BASE_LAP_TIME = 87.0  # baseline at race start, heavy fuel

# Tire effects (relative to Medium)
TIRE_COMPOUND_OFFSETS = {"S": -0.8, "M": 0.0, "H": +0.7}

# Linear tire degradation per lap of age
TIRE_DEGRADATION_RATES = {"S": 0.06, "M": 0.04, "H": 0.03}

# Simple fuel model: how much lap time you gain per lap as fuel burns off
FUEL_EFFECT_PER_LAP = -0.03  # seconds per lap (negative = faster as fuel goes down)

def lap_time(tire, tire_age, lap_number):
    """
    tire: 'S', 'M', or 'H'
    tire_age: laps since this tire was fitted (0 on out-lap)
    lap_number: 1-based race lap number
    """
    # Fuel term: assume car is heaviest on lap 1 and gets ~0.03s faster per lap
    fuel_term = FUEL_EFFECT_PER_LAP * (lap_number - 1)

    return (
        BASE_LAP_TIME
        + TIRE_COMPOUND_OFFSETS[tire]                 # compound performance
        + TIRE_DEGRADATION_RATES[tire] * tire_age     # wear penalty
        + fuel_term                                   # fuel burn-off benefit
    )


# ------------------------------------------------------------
# 2. EXPAND USER-PROVIDED STINTS
# ------------------------------------------------------------
def expand_stints(stints, total_laps):
    expanded = []
    current_lap = 1

    for stint in stints:
        tire = stint["tire"]
        laps = stint["laps"]

        end_lap = total_laps if laps is None else current_lap + laps - 1

        expanded.append({
            "tire": tire,
            "start": current_lap,
            "end": end_lap
        })

        current_lap = end_lap + 1

    return expanded


# ------------------------------------------------------------
# 3. SIMULATE LAP-BY-LAP
# ------------------------------------------------------------
def simulate_laps(stints, total_laps, pit_loss=PIT_LOSS):
    expanded = expand_stints(stints, total_laps)
    total = 0.0
    lap_records = []

    for stint in expanded:
        tire = stint["tire"]
        start, end = stint["start"], stint["end"]

        for lap in range(start, end + 1):
            tire_age = lap - start
            lap_t = lap_time(tire, tire_age, lap_number=lap)

            if lap == end and end != total_laps:
                lap_t += pit_loss

            total += lap_t

            lap_records.append({
                "lap": lap,
                "tire": tire,
                "lap_time": lap_t
            })

    return pd.DataFrame(lap_records)


# ------------------------------------------------------------
# 4. LOAD ACTUAL FASTF1 LAPS
# ------------------------------------------------------------
def load_actual_laps(year, gp, session_name, driver):
    session = fastf1.get_session(year, gp, session_name)
    session.load()

    laps = session.laps.pick_drivers(driver)
    laps = laps[["LapNumber", "LapTime", "Compound"]].copy()
    laps["LapTime"] = laps["LapTime"].dt.total_seconds()

    return laps


# ------------------------------------------------------------
# 5. SCATTER COMPARISON
# ------------------------------------------------------------
def compare_scatter(actual_df, sim_df, driver):
    COMPOUND_COLORS = {
        "SOFT": "#FF3333",
        "MEDIUM": "#FFCC33",
        "HARD": "#FFFFFF",
        "S": "#FF3333",
        "M": "#FFCC33",
        "H": "#FFFFFF"
    }

    plt.figure(figsize=(14, 6))

    # --- Actual (circles, black outline) ---
    for comp, grp in actual_df.groupby("Compound"):
        plt.scatter(
            grp["LapNumber"],
            grp["LapTime"],
            s=60,
            color=COMPOUND_COLORS.get(comp.upper(), "gray"),
            edgecolor="black",
            marker="o",
            alpha=0.85,
            label=f"Actual {driver} – {comp}"
        )

    # --- Simulator (squares, NO outline) ---
    for comp, grp in sim_df.groupby("tire"):
        plt.scatter(
            grp["lap"],
            grp["lap_time"],
            s=60,
            color=COMPOUND_COLORS.get(comp.upper(), "gray"),
            edgecolor="none",  # <-- no outline
            marker="s",
            alpha=0.85,
            label=f"Sim – {comp}"
        )

    plt.xlabel("Lap Number")
    plt.ylabel("Lap Time (seconds)")
    plt.title(f"Actual vs Simulator Lap Times — {driver}")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


# ------------------------------------------------------------
# 6. CUMULATIVE TIME HELPERS
# ------------------------------------------------------------
def build_actual_cumulative(actual_df):
    df = actual_df.copy()
    df = df.sort_values("LapNumber")
    df["cumulative_time"] = df["LapTime"].cumsum()
    return df


def build_sim_cumulative(sim_df):
    df = sim_df.copy()
    df = df.sort_values("lap")
    df["cumulative_time"] = df["lap_time"].cumsum()
    return df


# ------------------------------------------------------------
# 7. CUMULATIVE COMPARISON PLOT
# ------------------------------------------------------------
def compare_cumulative(actual_df, sim_df, driver):
    plt.figure(figsize=(14, 6))

    # --- Actual (bright yellow) ---
    plt.plot(
        actual_df["LapNumber"],
        actual_df["cumulative_time"],
        label=f"Actual {driver}",
        color="#C77DFF",
        linewidth=3.5,
        marker="o",
        markersize=5,
        alpha=1.0
    )

    # --- Simulator (cyan dashed) ---
    plt.plot(
        sim_df["lap"],
        sim_df["cumulative_time"],
        label="Simulator",
        color="#00FFFF",
        linewidth=2.5,
        linestyle="--",
        marker="s",
        markersize=5,
        alpha=0.9
    )

    # Final times
    actual_final = actual_df["cumulative_time"].iloc[-1]
    sim_final = sim_df["cumulative_time"].iloc[-1]
    delta = sim_final - actual_final

    # Text box inside plot
    text = (
        f"Final Times:\n"
        f"Actual {driver}: {actual_final:.3f} s\n"
        f"Simulator: {sim_final:.3f} s\n"
        f"Delta: {delta:+.3f} s"
    )

    plt.text(
        0.02, 0.98, text,
        transform=plt.gca().transAxes,
        fontsize=12,
        verticalalignment="top",
        color="white",
        bbox=dict(facecolor="black", alpha=0.6, edgecolor="white")
    )

    plt.xlabel("Lap Number")
    plt.ylabel("Cumulative Race Time (seconds)")
    plt.title(f"Cumulative Race Time Comparison — {driver}")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


# ------------------------------------------------------------
# 8. MAIN EXECUTION
# ------------------------------------------------------------
if __name__ == "__main__":
    stints = [
        {"tire": "M", "laps": 7},
        {"tire": "M", "laps": 25},
        {"tire": "H", "laps": None}
    ]

    driver = "VER"

    actual = load_actual_laps(2025, "Qatar", "R", driver)
    sim_df = simulate_laps(stints, TOTAL_LAPS)

    compare_scatter(actual, sim_df, driver)

    actual_cum = build_actual_cumulative(actual)
    sim_cum = build_sim_cumulative(sim_df)

    compare_cumulative(actual_cum, sim_cum, driver)

# %% [markdown]
# Let's run the simulator again, but this time for a race that did not have any Safety Cars.   The 2025 US Grandprix.

# %%
import fastf1.plotting
import matplotlib.pyplot as plt

# Pirelli compound colors
COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

fastf1.plotting.setup_mpl(mpl_timedelta_support=False, color_scheme='fastf1')

session = fastf1.get_session(2025, 'US Grand Prix', 'R')
session.load(telemetry=False, weather=False)

target_drivers = ["VER", "NOR"]

fig = plt.figure(figsize=(16, 8))

# --- TOP AXIS: STINT BARS ---
ax_stints = fig.add_subplot(2, 1, 1)

for i, drv in enumerate(target_drivers):
    drv_laps = session.laps.pick_drivers(drv)

    # Extract pit-in laps
    pit_laps = drv_laps.loc[drv_laps["PitInTime"].notna(), "LapNumber"].tolist()

    for stint_no, stint_laps in drv_laps.groupby("Stint"):
        start = stint_laps["LapNumber"].min()
        end = stint_laps["LapNumber"].max()
        width = end - start + 1

        compound = stint_laps["Compound"].iloc[0].upper()
        color = COMPOUND_COLORS.get(compound, "white")

        # Draw the stint bar
        ax_stints.barh(
            y=i,
            width=width,
            left=start,
            color=color,
            edgecolor="black",
            alpha=0.9
        )

        center_x = start + width / 2

        # --- NEW: Stint number + length in one line ---
        ax_stints.text(
            x=center_x,
            y=i + 0.25,
            s=f"STINT {int(stint_no)} = {int(width)} laps",
            ha="center",
            va="center",
            fontsize=9,
            color="black"
        )

        # --- Compound text (center of bar) ---
        ax_stints.text(
            x=center_x,
            y=i,
            s=compound,
            ha="center",
            va="center",
            fontsize=10,
            fontweight="bold",
            color="black"
        )

        # --- PIT LAP LABEL (below compound) ---
        if end in pit_laps:
            pit_lap = int(end)
            ax_stints.text(
                x=center_x,
                y=i - 0.28,
                s=f"PIT LAP {pit_lap}",
                ha="center",
                va="center",
                fontsize=9,
                color="black"
            )

    # Driver label
    ax_stints.text(-1, i, drv, va="center", ha="right", fontsize=12)

ax_stints.set_yticks([])
ax_stints.set_xlim(0, session.laps["LapNumber"].max())
ax_stints.set_title("US Grand Prix 2025 - Stint Timeline")

# --- BOTTOM AXIS: POSITION VS LAP ---
ax_pos = fig.add_subplot(2, 1, 2, sharex=ax_stints)

for drv in target_drivers:
    drv_laps = session.laps.pick_drivers(drv)

    style = fastf1.plotting.get_driver_style(
        identifier=drv,
        style=['color', 'linestyle'],
        session=session
    )

    ax_pos.plot(
        drv_laps["LapNumber"],
        drv_laps["Position"],
        label=drv,
        **style
    )

ax_pos.set_ylim(6.2, 0.8)
ax_pos.set_yticks([1, 2, 3, 4, 5, 6])
ax_pos.set_xlabel("Lap")
ax_pos.set_ylabel("Race Position")
ax_pos.set_title("US Grand Prix 2025 Position vs Lap")
ax_pos.legend()

plt.tight_layout()

# save file for future reference
plt.savefig("../images/usgrandprix_2025_winning_strategy.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# ============================================================
#  FASTF1 ACTUAL DATA vs SIMULATOR (USER-PROVIDED STINTS)
#  + SCATTER COMPARISON
#  + CUMULATIVE RACE TIME COMPARISON
# ============================================================

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import fastf1

# Force black background for ALL plots
plt.style.use("dark_background")

# ------------------------------------------------------------
# FASTF1 SETUP
# ------------------------------------------------------------
os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")

# ------------------------------------------------------------
# SIMULATOR CONSTANTS
# ------------------------------------------------------------
TOTAL_LAPS = 56
PIT_LOSS = 16
BASE_LAP_TIME = 100.0  # baseline at race start, heavy fuel

# Tire effects (relative to Medium)
TIRE_COMPOUND_OFFSETS = {"S": -0.8, "M": 0.0, "H": +0.7}

# Linear tire degradation per lap of age
TIRE_DEGRADATION_RATES = {"S": 0.06, "M": 0.04, "H": 0.03}

# Simple fuel model: how much lap time you gain per lap as fuel burns off
FUEL_EFFECT_PER_LAP = -0.03  # seconds per lap (negative = faster as fuel goes down)


def lap_time(tire, tire_age, lap_number):
    """
    tire: 'S', 'M', or 'H'
    tire_age: laps since this tire was fitted (0 on out-lap)
    lap_number: 1-based race lap number
    """
    # Fuel term: assume car is heaviest on lap 1 and gets ~0.03s faster per lap
    fuel_term = FUEL_EFFECT_PER_LAP * (lap_number - 1)

    return (
            BASE_LAP_TIME
            + TIRE_COMPOUND_OFFSETS[tire]  # compound performance
            + TIRE_DEGRADATION_RATES[tire] * tire_age  # wear penalty
            + fuel_term  # fuel burn-off benefit
    )


# ------------------------------------------------------------
# 2. EXPAND USER-PROVIDED STINTS
# ------------------------------------------------------------
def expand_stints(stints, total_laps):
    expanded = []
    current_lap = 1

    for stint in stints:
        tire = stint["tire"]
        laps = stint["laps"]

        end_lap = total_laps if laps is None else current_lap + laps - 1

        expanded.append({
            "tire": tire,
            "start": current_lap,
            "end": end_lap
        })

        current_lap = end_lap + 1

    return expanded


# ------------------------------------------------------------
# 3. SIMULATE LAP-BY-LAP
# ------------------------------------------------------------
def simulate_laps(stints, total_laps, pit_loss=PIT_LOSS):
    expanded = expand_stints(stints, total_laps)
    total = 0.0
    lap_records = []

    for stint in expanded:
        tire = stint["tire"]
        start, end = stint["start"], stint["end"]

        for lap in range(start, end + 1):
            tire_age = lap - start
            lap_t = lap_time(tire, tire_age, lap_number=lap)

            if lap == end and end != total_laps:
                lap_t += pit_loss

            total += lap_t

            lap_records.append({
                "lap": lap,
                "tire": tire,
                "lap_time": lap_t
            })

    return pd.DataFrame(lap_records)


# ------------------------------------------------------------
# 4. LOAD ACTUAL FASTF1 LAPS
# ------------------------------------------------------------
def load_actual_laps(year, gp, session_name, driver):
    session = fastf1.get_session(year, gp, session_name)
    session.load()

    laps = session.laps.pick_drivers(driver)
    laps = laps[["LapNumber", "LapTime", "Compound"]].copy()
    laps["LapTime"] = laps["LapTime"].dt.total_seconds()

    return laps


# ------------------------------------------------------------
# 5. SCATTER COMPARISON
# ------------------------------------------------------------
def compare_scatter(actual_df, sim_df, driver):
    COMPOUND_COLORS = {
        "SOFT": "#FF3333",
        "MEDIUM": "#FFCC33",
        "HARD": "#FFFFFF",
        "S": "#FF3333",
        "M": "#FFCC33",
        "H": "#FFFFFF"
    }

    plt.figure(figsize=(14, 6))

    # --- Actual (circles, black outline) ---
    for comp, grp in actual_df.groupby("Compound"):
        plt.scatter(
            grp["LapNumber"],
            grp["LapTime"],
            s=60,
            color=COMPOUND_COLORS.get(comp.upper(), "gray"),
            edgecolor="black",
            marker="o",
            alpha=0.85,
            label=f"Actual {driver} – {comp}"
        )

    # --- Simulator (squares, NO outline) ---
    for comp, grp in sim_df.groupby("tire"):
        plt.scatter(
            grp["lap"],
            grp["lap_time"],
            s=60,
            color=COMPOUND_COLORS.get(comp.upper(), "gray"),
            edgecolor="none",  # <-- no outline
            marker="s",
            alpha=0.85,
            label=f"Sim – {comp}"
        )

    plt.xlabel("Lap Number")
    plt.ylabel("Lap Time (seconds)")
    plt.title(f"Actual vs Simulator Lap Times — {driver}")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


# ------------------------------------------------------------
# 6. CUMULATIVE TIME HELPERS
# ------------------------------------------------------------
def build_actual_cumulative(actual_df):
    df = actual_df.copy()
    df = df.sort_values("LapNumber")
    df["cumulative_time"] = df["LapTime"].cumsum()
    return df


def build_sim_cumulative(sim_df):
    df = sim_df.copy()
    df = df.sort_values("lap")
    df["cumulative_time"] = df["lap_time"].cumsum()
    return df


# ------------------------------------------------------------
# 7. CUMULATIVE COMPARISON PLOT
# ------------------------------------------------------------
def compare_cumulative(actual_df, sim_df, driver):
    plt.figure(figsize=(14, 6))

    # --- Actual (bright yellow) ---
    plt.plot(
        actual_df["LapNumber"],
        actual_df["cumulative_time"],
        label=f"Actual {driver}",
        color="#C77DFF",
        linewidth=3.5,
        marker="o",
        markersize=5,
        alpha=1.0
    )

    # --- Simulator (cyan dashed) ---
    plt.plot(
        sim_df["lap"],
        sim_df["cumulative_time"],
        label="Simulator",
        color="#00FFFF",
        linewidth=2.5,
        linestyle="--",
        marker="s",
        markersize=5,
        alpha=0.9
    )

    # Final times
    actual_final = actual_df["cumulative_time"].iloc[-1]
    sim_final = sim_df["cumulative_time"].iloc[-1]
    delta = sim_final - actual_final

    # Text box inside plot
    text = (
        f"Final Times:\n"
        f"Actual {driver}: {actual_final:.3f} s\n"
        f"Simulator: {sim_final:.3f} s\n"
        f"Delta: {delta:+.3f} s"
    )

    plt.text(
        0.02, 0.98, text,
        transform=plt.gca().transAxes,
        fontsize=12,
        verticalalignment="top",
        color="white",
        bbox=dict(facecolor="black", alpha=0.6, edgecolor="white")
    )

    plt.xlabel("Lap Number")
    plt.ylabel("Cumulative Race Time (seconds)")
    plt.title(f"Cumulative Race Time Comparison — {driver}")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


# ------------------------------------------------------------
# 8. MAIN EXECUTION
# ------------------------------------------------------------
if __name__ == "__main__":
    stints = [
        {"tire": "M", "laps": 32},
        {"tire": "S", "laps": 25},
    ]

    driver = "VER"

    actual = load_actual_laps(2025, "US Grand Prix", "R", driver)
    sim_df = simulate_laps(stints, TOTAL_LAPS)

    compare_scatter(actual, sim_df, driver)

    actual_cum = build_actual_cumulative(actual)
    sim_cum = build_sim_cumulative(sim_df)

    compare_cumulative(actual_cum, sim_cum, driver)

# %% [markdown]
# **We now have the basis to improve upon our simulator, fuel consumption and tire mode:
# We need to refactor the code so that for any given race, we ask for the top finishers, stints to load into simulator, race length.   So the call to the code would be the race.   The return would be two top driver pit stategy and position plot, and the plot of top finisher sim vs actual.**

# %%
import fastf1
import fastf1.plotting
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# ============================================================
# USER INPUTS
# ============================================================
YEAR = 2025
RACE = "Qatar Grand Prix"
SESSION_NAME = "R"

# User-provided stints for simulation (winner only)
USER_STINTS = [
    {"tire": "M", "laps": 13},
    {"tire": "H", "laps": None},  # <-- auto-extends to TOTAL_LAPS
]

# ============================================================
# FASTF1 SETUP
# ============================================================
os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")
fastf1.plotting.setup_mpl(mpl_timedelta_support=False, color_scheme='fastf1')

# Load session
session = fastf1.get_session(YEAR, RACE, SESSION_NAME)
session.load(telemetry=False, weather=False)

# Identify top 2 finishers
results = session.results
top2 = results.head(2)["Abbreviation"].tolist()
winner = top2[0]

def print_actual_stints(session, driver):
    """
    Prints actual stint lengths and compounds for a driver
    in a clean, human-readable format.
    """
    laps = session.laps.pick_drivers(driver)

    print(f"\nActual stints for {driver} ({YEAR} {RACE}):")

    for stint_no, stint_laps in laps.groupby("Stint"):
        compound = stint_laps["Compound"].iloc[0]
        length = len(stint_laps)
        start = int(stint_laps["LapNumber"].min())
        end = int(stint_laps["LapNumber"].max())

        print(f"  Stint {int(stint_no)}: {length} laps "
              f"({compound})  —  Laps {start} to {end}")

    print()
print_actual_stints(session, winner)


# ============================================================
# PLOT 1 — STINT TIMELINE + POSITION VS LAP (TOP 2)
# ============================================================

COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

fig = plt.figure(figsize=(16, 8))

# --- TOP AXIS: STINT BARS ---
ax_stints = fig.add_subplot(2, 1, 1)

for i, drv in enumerate(top2):
    drv_laps = session.laps.pick_drivers(drv)
    pit_laps = drv_laps.loc[drv_laps["PitInTime"].notna(), "LapNumber"].tolist()

    for stint_no, stint_laps in drv_laps.groupby("Stint"):
        start = stint_laps["LapNumber"].min()
        end = stint_laps["LapNumber"].max()
        width = end - start + 1

        compound = stint_laps["Compound"].iloc[0].upper()
        color = COMPOUND_COLORS.get(compound, "white")

        ax_stints.barh(
            y=i,
            width=width,
            left=start,
            color=color,
            edgecolor="black",
            alpha=0.9
        )

        center_x = start + width / 2

        ax_stints.text(
            x=center_x,
            y=i + 0.25,
            s=f"STINT {int(stint_no)} = {int(width)} laps",
            ha="center",
            va="center",
            fontsize=9,
            color="black"
        )

        ax_stints.text(
            x=center_x,
            y=i,
            s=compound,
            ha="center",
            va="center",
            fontsize=10,
            fontweight="bold",
            color="black"
        )

        if end in pit_laps:
            pit_lap = int(end)
            ax_stints.text(
                x=center_x,
                y=i - 0.28,
                s=f"PIT LAP {pit_lap}",
                ha="center",
                va="center",
                fontsize=9,
                color="black"
            )

    ax_stints.text(-1, i, drv, va="center", ha="right", fontsize=12)

ax_stints.set_yticks([])
ax_stints.set_xlim(0, session.laps["LapNumber"].max())
ax_stints.set_title(f"{YEAR} {RACE} — Stint Timeline (Top 2)")

# --- BOTTOM AXIS: POSITION VS LAP ---
ax_pos = fig.add_subplot(2, 1, 2, sharex=ax_stints)

for drv in top2:
    drv_laps = session.laps.pick_drivers(drv)

    style = fastf1.plotting.get_driver_style(
        identifier=drv,
        style=['color', 'linestyle'],
        session=session
    )

    ax_pos.plot(
        drv_laps["LapNumber"],
        drv_laps["Position"],
        label=drv,
        **style
    )

ax_pos.set_ylim(6.2, 0.8)
ax_pos.set_yticks([1, 2, 3, 4, 5, 6])
ax_pos.set_xlabel("Lap")
ax_pos.set_ylabel("Race Position")
ax_pos.set_title(f"{YEAR} {RACE} — Position vs Lap (Top 2)")
ax_pos.legend()

plt.tight_layout()
plt.savefig(f"plot1_{YEAR}_{RACE.replace(' ', '_')}.png", dpi=300, bbox_inches="tight")
plt.show()

# ============================================================
# SIMULATOR CONSTANTS
# ============================================================

TOTAL_LAPS = session.laps["LapNumber"].max()
PIT_LOSS = 16
BASE_LAP_TIME = 90.0
FUEL_EFFECT_PER_LAP = -0.03
TIRE_COMPOUND_OFFSETS = {"S": -0.8, "M": 0.0, "H": +0.7}
TIRE_DEGRADATION_RATES = {"S": 0.06, "M": 0.04, "H": 0.03}


# ============================================================
# SAFE EXPAND_STINTS (FIXED)
# ============================================================

def expand_stints(stints, total_laps):
    expanded = []
    current_lap = 1

    for stint in stints:
        tire = stint["tire"]

        # --- FIX: force laps to int, preserve None ---
        laps_raw = stint["laps"]
        if laps_raw is None:
            laps = None
        else:
            try:
                laps = int(laps_raw)
            except Exception:
                raise ValueError(f"Invalid laps value: {laps_raw}")

        end_lap = total_laps if laps is None else current_lap + laps - 1

        # --- FIX: ensure end_lap is an int ---
        end_lap = int(end_lap)

        expanded.append({
            "tire": tire,
            "start": int(current_lap),
            "end": end_lap
        })

        current_lap = end_lap + 1

    return expanded


# ============================================================
# SIMULATE LAPS
# ============================================================

def lap_time(tire, tire_age, lap_number):
    fuel_term = FUEL_EFFECT_PER_LAP * (lap_number - 1)
    return (
            BASE_LAP_TIME
            + TIRE_COMPOUND_OFFSETS[tire]
            + TIRE_DEGRADATION_RATES[tire] * tire_age
            + fuel_term
    )


def simulate_laps(stints, total_laps, pit_loss=PIT_LOSS):
    expanded = expand_stints(stints, total_laps)
    lap_records = []

    for stint in expanded:
        tire = stint["tire"]
        start, end = stint["start"], stint["end"]

        for lap in range(start, end + 1):
            tire_age = lap - start
            lap_t = lap_time(tire, tire_age, lap)
            if lap == end and end != total_laps:
                lap_t += pit_loss
            lap_records.append({"lap": lap, "tire": tire, "lap_time": lap_t})

    return pd.DataFrame(lap_records)


def load_actual_laps(session, driver):
    laps = session.laps.pick_drivers(driver)
    df = laps[["LapNumber", "LapTime", "Compound"]].copy()
    df["LapTime"] = df["LapTime"].dt.total_seconds()
    return df


def build_cumulative(df, lap_col, time_col):
    df = df.sort_values(lap_col)
    df["cumulative"] = df[time_col].cumsum()
    return df


# ============================================================
# PLOT 2 — SCATTER (WINNER ONLY)
# ============================================================

actual = load_actual_laps(session, winner)
sim_df = simulate_laps(USER_STINTS, TOTAL_LAPS)

plt.figure(figsize=(16, 8))

COMPOUND_COLORS_SIM = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "S": "#FF3333",
    "M": "#FFCC33",
    "H": "#FFFFFF"
}

for comp, grp in actual.groupby("Compound"):
    plt.scatter(
        grp["LapNumber"],
        grp["LapTime"],
        s=60,
        color=COMPOUND_COLORS_SIM.get(comp.upper(), "gray"),
        edgecolor="black",
        marker="o",
        alpha=0.85,
        label=f"Actual {winner} – {comp}"
    )

for comp, grp in sim_df.groupby("tire"):
    plt.scatter(
        grp["lap"],
        grp["lap_time"],
        s=60,
        color=COMPOUND_COLORS_SIM.get(comp.upper(), "gray"),
        edgecolor="none",
        marker="s",
        alpha=0.85,
        label=f"Sim – {comp}"
    )

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title(f"{YEAR} {RACE} — Actual vs Simulated Lap Times ({winner})")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.savefig(f"plot2_{YEAR}_{RACE.replace(' ', '_')}.png", dpi=300, bbox_inches="tight")
plt.show()

# ============================================================
# PLOT 3 — CUMULATIVE (WINNER ONLY)
# ============================================================

actual_cum = build_cumulative(actual, "LapNumber", "LapTime")
sim_cum = build_cumulative(sim_df, "lap", "lap_time")

plt.figure(figsize=(16, 8))

plt.plot(
    actual_cum["LapNumber"],
    actual_cum["cumulative"],
    label=f"Actual {winner}",
    color="#C77DFF",
    linewidth=3.5,
    marker="o",
    markersize=5,
    alpha=1.0
)

plt.plot(
    sim_cum["lap"],
    sim_cum["cumulative"],
    label="Simulator",
    color="#00FFFF",
    linewidth=2.5,
    linestyle="--",
    marker="s",
    markersize=5,
    alpha=0.9
)

actual_final = actual_cum["cumulative"].iloc[-1]
sim_final = sim_cum["cumulative"].iloc[-1]
delta = sim_final - actual_final

text = (
    f"Final Times:\n"
    f"Actual {winner}: {actual_final:.3f} s\n"
    f"Simulator: {sim_final:.3f} s\n"
    f"Delta: {delta:+.3f} s"
)

plt.text(
    0.02, 0.98, text,
    transform=plt.gca().transAxes,
    fontsize=12,
    verticalalignment="top",
    color="white",
    bbox=dict(facecolor="black", alpha=0.6, edgecolor="white")
)

plt.xlabel("Lap Number")
plt.ylabel("Cumulative Race Time (seconds)")
plt.title(f"{YEAR} {RACE} — Cumulative Race Time Comparison ({winner})")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.savefig(f"plot3_{YEAR}_{RACE.replace(' ', '_')}.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 4 Fuel Consumption and Tire Degredation Considerations

# %% [markdown]
# ### 4.1 Fuel Consumption

# %% [markdown]
# In F1, prior to the race, each car is fueled to last the entire race, i.e. pit stops are used to change tires, or make minor car repairs, but not for refueling.  Accordingly, the race car gets lighter each lap and the lap time improvement per lap is near linear.  The following scatter plot is a visualization of lap time vs lap number for Max Verstappen in the 2025 Qatar GP.

# %%
# Style for VER only
driver_styles = {
    "VER": {"edgecolor": "black", "marker": "o"}
}

# Compound colors
COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

plt.figure(figsize=(14, 6))

# --- Only VER ---
drv = "VER"
#drv_laps = session.laps.pick_drivers(drv).pick_quicklaps()
drv_laps = session.laps.pick_drivers(drv)
style = driver_styles[drv]

for compound, comp_laps in drv_laps.groupby("Compound"):
    plt.scatter(
        comp_laps["LapNumber"],
        comp_laps["LapTime"].dt.total_seconds(),
        s=60,
        color=COMPOUND_COLORS.get(compound.upper(), "gray"),  # fill color
        edgecolor=style["edgecolor"],                         # outline
        marker=style["marker"],                               # marker shape
        linewidth=1.2,
        alpha=0.85,
        label=f"{drv} – {compound}"
    )

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2025 Qatar GP – Lap Times by Compound (VER)")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# For fuel consumption modeling purposes we are after the relationship between lap time and lap number to estimate lap time gains as the fuel is burned.   The above plot has all laps.  Fortunately, fastf1
# has a method to easily remove slow laps - pick_quicklaps().  Let's plot the time again with the slow (pre and post pit stop) laps removed.

# %%
# Style for VER only
driver_styles = {
    "VER": {"edgecolor": "black", "marker": "o"}
}

# Compound colors
COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

plt.figure(figsize=(14, 6))

# --- Only VER ---
drv = "VER"
drv_laps = session.laps.pick_drivers(drv).pick_quicklaps()

style = driver_styles[drv]

for compound, comp_laps in drv_laps.groupby("Compound"):
    plt.scatter(
        comp_laps["LapNumber"],
        comp_laps["LapTime"].dt.total_seconds(),
        s=60,
        color=COMPOUND_COLORS.get(compound.upper(), "gray"),  # fill color
        edgecolor=style["edgecolor"],  # outline
        marker=style["marker"],  # marker shape
        linewidth=1.2,
        alpha=0.85,
        label=f"{drv} – {compound}"
    )

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2025 Qatar GP – Lap Times by Compound (VER)")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# Prior to regression modeling, we can make design a simple model for the lap time vs lap number relationship.  For a first approximation we'll ignore
# lap 1, and lap 51-57, and approximate the data with a line between these two points (LapNumber, LapTime) - (3, 87.5), (50, 83.5).

# %%
# calculate the slope of the line
m = (83.5-87.5)/(50-3)
m

# %% [markdown]
# The slope indicates that lap time improves by m seconds, or by 0.0851 seconds per lap.   The first pass (simple model) of the fuel consumption model is plotted below, which is
# **lap time gain due to fuel consumption = -0.0851 seconds/lap**

# %%
import numpy as np

# Style for VER only
driver_styles = {
    "VER": {"edgecolor": "black", "marker": "o"}
}

# Compound colors
COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

plt.figure(figsize=(14, 6))

# --- Only VER ---
drv = "VER"
drv_laps = session.laps.pick_drivers(drv).pick_quicklaps()

style = driver_styles[drv]

for compound, comp_laps in drv_laps.groupby("Compound"):
    plt.scatter(
        comp_laps["LapNumber"],
        comp_laps["LapTime"].dt.total_seconds(),
        s=60,
        color=COMPOUND_COLORS.get(compound.upper(), "gray"),
        edgecolor=style["edgecolor"],
        marker=style["marker"],
        linewidth=1.2,
        alpha=0.85,
        label=f"{drv} – {compound}"
    )

# --- Add the line segment between x=3 and x=50 ---
x_line = np.linspace(3, 50, 200)
y_line = (-4 / 47) * x_line + 87.7234

plt.plot(
    x_line,
    y_line,
    color="red",
    linewidth=2.2,
    label="Linear Fit (x=3→50)"
)

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2025 Qatar GP – Lap Times by Compound (VER)")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# From the plot above, we can now state our initial model, LapTime = BaseLapTime - FuelConsumptionEffect.   Further FuelConsumptionEffect can be considered to be of the form Beta1(LapNumber -1) such that for LapNumber = 1, there is no fuel consumption effect.   For LapNumber >= 2, the effect is given by Beta1 (seconds/LapNumber)*(LapNumber).

# %% [markdown]
# For the line above the equation is LapTime = 87.5 - 0.0851(LapNumber) for LapNumber [3,50]

# %% [markdown]
# Now we have the basis to test the accuracy of the model.   To do so we will assume that the model will be unique to race venue (since each venue has a unique lap length), and tire compound.   Further,  for now, we will only consider the first few laps of a stint to ensure that tire degradation effects are negligible.

# %% [markdown]
# For now, use regression analysis to model BaseLapTime and Beta1 for the top four finishers for the Qatar 2025 Grand Prix. First, let's plot the laptimes vs lapnumbers for VER, PIA, SAI, and NOR (the 3 letter abreviations for VERstappen, PIAstri, SAInz, and NORris).

# %%
# Drivers you want to analyze

drivers = ["VER", "PIA", "NOR", "SAI"]
# Unique marker + edgecolor per driver
driver_styles = {
    "VER": {"edgecolor": "black", "marker": "o"},
    "PIA": {"edgecolor": "blue", "marker": "s"},
    "NOR": {"edgecolor": "green", "marker": "D"},
    "SAI": {"edgecolor": "red", "marker": "^"},
}

# Compound colors
COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

plt.figure(figsize=(16, 7))

# --- Loop through each driver ---
for drv in drivers:
    drv_laps = session.laps.pick_drivers(drv).pick_quicklaps()

    style = driver_styles.get(drv, {"edgecolor": "black", "marker": "o"})

    for compound, comp_laps in drv_laps.groupby("Compound"):
        plt.scatter(
            comp_laps["LapNumber"],
            comp_laps["LapTime"].dt.total_seconds(),
            s=60,
            color=COMPOUND_COLORS.get(compound.upper(), "gray"),
            edgecolor=style["edgecolor"],
            marker=style["marker"],
            linewidth=1.2,
            alpha=0.85,
            label=f"{drv} – {compound}"
        )

# --- Optional: keep your linear reference line ---
x_line = np.linspace(3, 50, 200)
y_line = (-4 / 47) * x_line + 87.7234

plt.plot(
    x_line,
    y_line,
    color="red",
    linewidth=2.2,
    label="Linear Fit (x=3→50)"
)

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2025 Qatar GP – Lap Times by Compound (VER, PIA, NOR, SAI)")
plt.grid(alpha=0.3)
plt.legend(ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# From above, our linear fit redline that was developed for Max Verstappen is also a reasonable (moderately accurate) for the other 3 drivers for laps 3-50.  Before we go further, it may be instructive to look at the next slowest group of drivers, (ANT, RUS, ALO, LEC).

# %%
# Drivers you want to analyze

drivers = ["ANT", "RUS", "ALO", "LEC"]
# Unique marker + edgecolor per driver
driver_styles = {
    "VER": {"edgecolor": "black", "marker": "o"},
    "PIA": {"edgecolor": "blue", "marker": "s"},
    "NOR": {"edgecolor": "green", "marker": "D"},
    "SAI": {"edgecolor": "red", "marker": "^"},
}

# Compound colors
COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

plt.figure(figsize=(16, 7))

# --- Loop through each driver ---
for drv in drivers:
    drv_laps = session.laps.pick_drivers(drv).pick_quicklaps()

    style = driver_styles.get(drv, {"edgecolor": "black", "marker": "o"})

    for compound, comp_laps in drv_laps.groupby("Compound"):
        plt.scatter(
            comp_laps["LapNumber"],
            comp_laps["LapTime"].dt.total_seconds(),
            s=60,
            color=COMPOUND_COLORS.get(compound.upper(), "gray"),
            edgecolor=style["edgecolor"],
            marker=style["marker"],
            linewidth=1.2,
            alpha=0.85,
            label=f"{drv} – {compound}"
        )

# --- Optional: keep your linear reference line ---
x_line = np.linspace(3, 50, 200)
y_line = (-4 / 47) * x_line + 87.7234

plt.plot(
    x_line,
    y_line,
    color="red",
    linewidth=2.2,
    label="Linear Fit (x=3→50)"
)

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2025 Qatar GP – Lap Times by Compound (VER, PIA, NOR, SAI)")
plt.grid(alpha=0.3)
plt.legend(ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# From above, other than the base LapTime being slower, we can see that the slope of the line (seconds/LapNumber) is also a reasonable fit for the finishers (5-8).

# %% [markdown]
# Initially we are after a simple model for fuel consumption.   We can build on this model later.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Drivers you want to analyze
drivers = ["VER", "PIA", "NOR", "SAI"]

# Simple driver styles (no team colors)
driver_styles = {
    "VER": {"color": "red", "marker": "o"},
    "PIA": {"color": "blue", "marker": "s"},
    "NOR": {"color": "green", "marker": "D"},
    "SAI": {"color": "orange", "marker": "^"},
}

plt.figure(figsize=(14, 7))

for drv in drivers:
    # --- Get race laps for this driver ---
    drv_laps = session.laps.pick_drivers(drv)

    # --- Filter to laps 3–50 ---
    drv_laps = drv_laps[(drv_laps["LapNumber"] >= 3) & (drv_laps["LapNumber"] <= 50)]

    # --- Remove slow laps (simple outlier filter) ---
    # Convert LapTime to seconds
    lt = drv_laps["LapTime"].dt.total_seconds()
    median = lt.median()
    good_laps = drv_laps[lt < median * 1.10]  # keep laps within +10%

    if len(good_laps) < 5:
        continue

    # --- Prepare regression data ---
    X = good_laps["LapNumber"].values.reshape(-1, 1)
    y = good_laps["LapTime"].dt.total_seconds().values

    model = LinearRegression()
    model.fit(X, y)

    slope = model.coef_[0]
    intercept = model.intercept_

    # --- Plot regression line ---
    x_line = np.linspace(3, 50, 200).reshape(-1, 1)
    y_line = model.predict(x_line)

    style = driver_styles.get(drv, {"color": "black", "marker": "o"})

    plt.plot(
        x_line,
        y_line,
        color=style["color"],
        linewidth=2.0,
        label=f"{drv}  (B1={slope:.4f} s/lap)"
    )

    # --- Plot actual points (optional) ---
    plt.scatter(
        good_laps["LapNumber"],
        good_laps["LapTime"].dt.total_seconds(),
        color=style["color"],
        marker=style["marker"],
        s=40,
        alpha=0.6
    )

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("Fuel Burn Regression Slopes (Laps 3–50) – Qatar 2025 Race")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Drivers to aggregate
drivers = ["VER", "PIA", "NOR", "SAI"]

# Style for all drivers' scatter points
scatter_color = "steelblue"
scatter_marker = "o"

plt.figure(figsize=(14, 7))

# --- Collect all laps for aggregate regression ---
all_X = []
all_y = []

for drv in drivers:
    drv_laps = session.laps.pick_drivers(drv)

    # Filter to laps 3–50
    drv_laps = drv_laps[(drv_laps["LapNumber"] >= 3) & (drv_laps["LapNumber"] <= 50)]

    # Convert LapTime to seconds
    lt = drv_laps["LapTime"].dt.total_seconds()

    # Remove slow laps (simple +10% median filter)
    median = lt.median()
    good_laps = drv_laps[lt < median * 1.10]

    if len(good_laps) < 5:
        continue

    # Add to aggregate dataset
    all_X.extend(good_laps["LapNumber"].values.tolist())
    all_y.extend(good_laps["LapTime"].dt.total_seconds().values.tolist())

    # Plot individual driver points (same color for all)
    plt.scatter(
        good_laps["LapNumber"],
        good_laps["LapTime"].dt.total_seconds(),
        color=scatter_color,
        marker=scatter_marker,
        s=40,
        alpha=0.5
    )

# --- Fit aggregate regression ---
all_X = np.array(all_X).reshape(-1, 1)
all_y = np.array(all_y)

model = LinearRegression()
model.fit(all_X, all_y)

slope = model.coef_[0]
intercept = model.intercept_

# --- Plot aggregate regression line ---
x_line = np.linspace(3, 50, 200).reshape(-1, 1)
y_line = model.predict(x_line)

plt.plot(
    x_line,
    y_line,
    color="red",
    linewidth=3.0,
    label=f"Aggregate Regression (B1 = {slope:.4f} s/lap)"
)

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("Aggregate Fuel Burn Regression – VER, PIA, NOR, SAI (Qatar 2025)")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Now let's compute the B1 fuel consumption coefficient across all 20 drivers**.  The following code performs a train test split, computes the B1 slope for the training data, computes the MSE, the predicts the test data, and computes the MSE.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Drivers to aggregate
#drivers = ["VER", "PIA", "NOR", "SAI"]
# --- Use ALL drivers in the session --- drivers = session.drivers # <-- replaces the hardcoded list
drivers = session.drivers # <-- replaces the hardcoded list

# Style for all scatter points
scatter_color = "steelblue"
scatter_marker = "o"

# --- Collect all laps for aggregate regression ---
all_X = []
all_y = []

for drv in drivers:
    drv_laps = session.laps.pick_drivers(drv)

    # Filter to laps 3–50
    drv_laps = drv_laps[(drv_laps["LapNumber"] >= 3) & (drv_laps["LapNumber"] <= 50)]

    # Convert LapTime to seconds
    lt = drv_laps["LapTime"].dt.total_seconds()

    # Remove slow laps (simple +10% median filter)
    median = lt.median()
    good_laps = drv_laps[lt < median * 1.10]

    if len(good_laps) < 5:
        continue

    # Add to aggregate dataset
    all_X.extend(good_laps["LapNumber"].values.tolist())
    all_y.extend(good_laps["LapTime"].dt.total_seconds().values.tolist())

# Convert to arrays
all_X = np.array(all_X).reshape(-1, 1)
all_y = np.array(all_y)

# --- Train/Test Split ---
X_train, X_test, y_train, y_test = train_test_split(
    all_X, all_y, test_size=0.25, random_state=42
)

# --- Fit regression on training data ---
model = LinearRegression()
model.fit(X_train, y_train)

train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_mse = mean_squared_error(y_train, train_pred)
test_mse = mean_squared_error(y_test, test_pred)

slope = model.coef_[0]
intercept = model.intercept_

print("===== Aggregate Fuel Burn Model =====")
print(f"B1 slope: {slope:.6f} seconds per lap")
print(f"Intercept (base lap time): {intercept:.3f} seconds")
print(f"Training MSE: {train_mse:.6f}")
print(f"Test MSE:     {test_mse:.6f}")

# --- Plot training data + regression line ---
plt.figure(figsize=(14, 7))

# Scatter training points
plt.scatter(
    X_train,
    y_train,
    color=scatter_color,
    marker=scatter_marker,
    s=40,
    alpha=0.6,
    label="Training Data"
)

# Regression line
x_line = np.linspace(3, 50, 200).reshape(-1, 1)
y_line = model.predict(x_line)

plt.plot(
    x_line,
    y_line,
    color="red",
    linewidth=3.0,
    label=f"Regression Line (B1={slope:.4f})"
)

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2025 Qatar - Aggregate Fuel Burn Regression – Training Data Only")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Here's the plot of the test data versus the predicted data - the regression line.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(14, 7))

# --- Scatter plot of test data ---
plt.scatter(
    X_test,
    y_test,
    color="darkorange",
    marker="o",
    s=50,
    alpha=0.7,
    label="Test Data"
)

# --- Regression line (already trained on training data) ---
x_line = np.linspace(3, 50, 200).reshape(-1, 1)
y_line = model.predict(x_line)

plt.plot(
    x_line,
    y_line,
    color="red",
    linewidth=3.0,
    label="Regression Line (trained on training set)"
)

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2025 Qatar - Test Data vs. Trained Regression Line – Fuel Burn Model")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Compute residuals for test data
test_residuals = y_test - test_pred

plt.figure(figsize=(14, 7))

plt.scatter(
    X_test,
    test_residuals,
    color="purple",
    alpha=0.7,
    s=50,
    label="Test Residuals"
)

plt.axhline(0, color="black", linestyle="--", linewidth=1)

plt.xlabel("Lap Number")
plt.ylabel("Residual (Actual - Predicted)")
plt.title("2025 Qatar - Residual Plot – Test Data (Fuel Burn Model)")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Given that we have seen some outliers, let's rerun the test train split and the same plots, but this time removing outliers with a quartile filter.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Drivers to aggregate

drivers = session.drivers # <-- replaces the hardcoded list
# Style for all scatter points
scatter_color = "steelblue"
scatter_marker = "o"

# --- Collect all laps for aggregate regression ---
all_X = []
all_y = []

for drv in drivers:
    drv_laps = session.laps.pick_drivers(drv)

    # Filter to laps 3–50
    drv_laps = drv_laps[(drv_laps["LapNumber"] >= 3) & (drv_laps["LapNumber"] <= 50)]

    # Convert LapTime to seconds
    lt = drv_laps["LapTime"].dt.total_seconds()

    # Remove slow laps (simple +10% median filter)
    #median = lt.median()
    #good_laps = drv_laps[lt < median * 1.10]
    q1 = lt.quantile(0.25)
    q3 = lt.quantile(0.75)
    iqr = q3 - q1

    good_laps = drv_laps[lt < q3 + 1.5 * iqr]

    if len(good_laps) < 5:
        continue

    # Add to aggregate dataset
    all_X.extend(good_laps["LapNumber"].values.tolist())
    all_y.extend(good_laps["LapTime"].dt.total_seconds().values.tolist())

# Convert to arrays
all_X = np.array(all_X).reshape(-1, 1)
all_y = np.array(all_y)

# --- Train/Test Split ---
X_train, X_test, y_train, y_test = train_test_split(
    all_X, all_y, test_size=0.25, random_state=42
)

# --- Fit regression on training data ---
model = LinearRegression()
model.fit(X_train, y_train)

train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_mse = mean_squared_error(y_train, train_pred)
test_mse = mean_squared_error(y_test, test_pred)

slope = model.coef_[0]
intercept = model.intercept_

print("===== Aggregate Fuel Burn Model =====")
print(f"B1 slope: {slope:.6f} seconds per lap")
print(f"Intercept (base lap time): {intercept:.3f} seconds")
print(f"Training MSE: {train_mse:.6f}")
print(f"Test MSE:     {test_mse:.6f}")

# --- Plot training data + regression line ---
plt.figure(figsize=(14, 7))

# Scatter training points
plt.scatter(
    X_train,
    y_train,
    color=scatter_color,
    marker=scatter_marker,
    s=40,
    alpha=0.6,
    label="Training Data"
)

# Regression line
x_line = np.linspace(3, 50, 200).reshape(-1, 1)
y_line = model.predict(x_line)

plt.plot(
    x_line,
    y_line,
    color="red",
    linewidth=3.0,
    label=f"Regression Line (B1={slope:.4f})"
)

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2025 Qatar - Aggregate Fuel Burn Regression – Training Data Only")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(14, 7))

# --- Scatter plot of test data ---
plt.scatter(
    X_test,
    y_test,
    color="darkorange",
    marker="o",
    s=50,
    alpha=0.7,
    label="Test Data"
)

# --- Regression line (already trained on training data) ---
x_line = np.linspace(3, 50, 200).reshape(-1, 1)
y_line = model.predict(x_line)

plt.plot(
    x_line,
    y_line,
    color="red",
    linewidth=3.0,
    label="Regression Line (trained on training set)"
)

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2025 Qatar - Test Data vs. Trained Regression Line – Fuel Burn Model")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Compute residuals for test data
test_residuals = y_test - test_pred

plt.figure(figsize=(14, 7))

plt.scatter(
    X_test,
    test_residuals,
    color="purple",
    alpha=0.7,
    s=50,
    label="Test Residuals"
)

plt.axhline(0, color="black", linestyle="--", linewidth=1)

plt.xlabel("Lap Number")
plt.ylabel("Residual (Actual - Predicted)")
plt.title("2025 Qatar - Residual Plot – Test Data (Fuel Burn Model)")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Let's examine another race**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Drivers to aggregate
session = fastf1.get_session(2025, 'Bahrain', 'R')
session.load(telemetry=False, weather=False)

drivers = session.drivers  # <-- replaces the hardcoded list
# Style for all scatter points
scatter_color = "steelblue"
scatter_marker = "o"

# --- Collect all laps for aggregate regression ---
all_X = []
all_y = []

for drv in drivers:
    drv_laps = session.laps.pick_drivers(drv)

    # Filter to laps 3–50
    drv_laps = drv_laps[(drv_laps["LapNumber"] >= 3) & (drv_laps["LapNumber"] <= 30)]

    # Convert LapTime to seconds
    lt = drv_laps["LapTime"].dt.total_seconds()

    # Remove slow laps (simple +10% median filter)
    #median = lt.median()
    #good_laps = drv_laps[lt < median * 1.10]
    q1 = lt.quantile(0.25)
    q3 = lt.quantile(0.75)
    iqr = q3 - q1

    good_laps = drv_laps[lt < q3 + 1.5 * iqr]

    if len(good_laps) < 5:
        continue

    # Add to aggregate dataset
    all_X.extend(good_laps["LapNumber"].values.tolist())
    all_y.extend(good_laps["LapTime"].dt.total_seconds().values.tolist())

# Convert to arrays
all_X = np.array(all_X).reshape(-1, 1)
all_y = np.array(all_y)

# --- Train/Test Split ---
X_train, X_test, y_train, y_test = train_test_split(
    all_X, all_y, test_size=0.25, random_state=42
)

# --- Fit regression on training data ---
model = LinearRegression()
model.fit(X_train, y_train)

train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_mse = mean_squared_error(y_train, train_pred)
test_mse = mean_squared_error(y_test, test_pred)

slope = model.coef_[0]
intercept = model.intercept_

print("===== Aggregate Fuel Burn Model =====")
print(f"B1 slope: {slope:.6f} seconds per lap")
print(f"Intercept (base lap time): {intercept:.3f} seconds")
print(f"Training MSE: {train_mse:.6f}")
print(f"Test MSE:     {test_mse:.6f}")

# --- Plot training data + regression line ---
plt.figure(figsize=(14, 7))

# Scatter training points
plt.scatter(
    X_train,
    y_train,
    color=scatter_color,
    marker=scatter_marker,
    s=40,
    alpha=0.6,
    label="Training Data"
)

# Regression line
x_line = np.linspace(3, 30, 200).reshape(-1, 1)
y_line = model.predict(x_line)

plt.plot(
    x_line,
    y_line,
    color="red",
    linewidth=3.0,
    label=f"Regression Line (B1={slope:.4f})"
)

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2025 Bahrain - Aggregate Fuel Burn Regression – Training Data Only")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(14, 7))

# --- Scatter plot of test data ---
plt.scatter(
    X_test,
    y_test,
    color="darkorange",
    marker="o",
    s=50,
    alpha=0.7,
    label="Test Data"
)

# --- Regression line (already trained on training data) ---
x_line = np.linspace(3, 30, 200).reshape(-1, 1)
y_line = model.predict(x_line)

plt.plot(
    x_line,
    y_line,
    color="red",
    linewidth=3.0,
    label="Regression Line (trained on training set)"
)

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2025 Bahrain - Test Data vs. Trained Regression Line – Fuel Burn Model")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Compute residuals for test data
test_residuals = y_test - test_pred

plt.figure(figsize=(14, 7))

plt.scatter(
    X_test,
    test_residuals,
    color="purple",
    alpha=0.7,
    s=50,
    label="Test Residuals"
)

plt.axhline(0, color="black", linestyle="--", linewidth=1)

plt.xlabel("Lap Number")
plt.ylabel("Residual (Actual - Predicted)")
plt.title("2025 Bahrain - Residual Plot – Test Data (Fuel Burn Model)")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Given the traffic considerations for those cars running in the rear of the "car train", I think removing the slower drivers from the calculation would be wise.  Let's retun Qatar with the top 8 cars, and also only consider the laps in the first part of the stind.  **We will come back to this as we neeed to get started with tire degredation*.

# %% [markdown]
# For now, we will use the full fild fuel assumption metrics.
#
# ===== Aggregate Fuel Burn Model =====
# * B1 slope: -0.074270 seconds per lap
# * Intercept (base lap time): 88.650 seconds
# * Training MSE: 0.894621
# * Test MSE:     1.062085

# %% [markdown]
# ### 4.2 Tire Degredation

# %% [markdown]
# F1 racing literature indicates that tire degradation is a significant performance detractor and should be factored in to pit strategy. [The Science Behind Tyre Degradation in Formula 1](https://www.raceteq.com/articles/2024/08/the-science-behind-tyre-degradation-in-formula-1).  Accordingly, the following is an initial look at lap time increases due to tire degradation.  The following plots lap time and tire compound for Lewis Hamilton for the 2020 Grand Prix Race.

# %% [markdown]
# Tire degredation will be calculated per this equation:
# laptime = base_lap_time + B1 (LapNumber - 1) + tire_degred

# %%
import fastf1.plotting
import matplotlib.pyplot as plt

# Pirelli compound colors
COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

fastf1.plotting.setup_mpl(mpl_timedelta_support=False, color_scheme='fastf1')

session = fastf1.get_session(2020, 'British Grand Prix', 'R')
session.load(telemetry=False, weather=False)

target_drivers = ["VER", "HAM"]

fig = plt.figure(figsize=(16, 8))

# --- TOP AXIS: STINT BARS ---
ax_stints = fig.add_subplot(2, 1, 1)

for i, drv in enumerate(target_drivers):
    drv_laps = session.laps.pick_drivers(drv)

    # Extract pit-in laps
    pit_laps = drv_laps.loc[drv_laps["PitInTime"].notna(), "LapNumber"].tolist()

    for stint_no, stint_laps in drv_laps.groupby("Stint"):
        start = stint_laps["LapNumber"].min()
        end = stint_laps["LapNumber"].max()
        width = end - start + 1

        compound = stint_laps["Compound"].iloc[0].upper()
        color = COMPOUND_COLORS.get(compound, "white")

        # Draw the stint bar
        ax_stints.barh(
            y=i,
            width=width,
            left=start,
            color=color,
            edgecolor="black",
            alpha=0.9
        )

        center_x = start + width / 2

        # --- NEW: Stint number + length in one line ---
        ax_stints.text(
            x=center_x,
            y=i + 0.25,
            s=f"STINT {int(stint_no)} = {int(width)} laps",
            ha="center",
            va="center",
            fontsize=9,
            color="black"
        )

        # --- Compound text (center of bar) ---
        ax_stints.text(
            x=center_x,
            y=i,
            s=compound,
            ha="center",
            va="center",
            fontsize=10,
            fontweight="bold",
            color="black"
        )

        # --- PIT LAP LABEL (below compound) ---
        if end in pit_laps:
            pit_lap = int(end)
            ax_stints.text(
                x=center_x,
                y=i - 0.28,
                s=f"PIT LAP {pit_lap}",
                ha="center",
                va="center",
                fontsize=9,
                color="black"
            )

    # Driver label
    ax_stints.text(-1, i, drv, va="center", ha="right", fontsize=12)

ax_stints.set_yticks([])
ax_stints.set_xlim(0, session.laps["LapNumber"].max())
ax_stints.set_title("Qatar 2025 - Stint Timeline")

# --- BOTTOM AXIS: POSITION VS LAP ---
ax_pos = fig.add_subplot(2, 1, 2, sharex=ax_stints)

for drv in target_drivers:
    drv_laps = session.laps.pick_drivers(drv)

    style = fastf1.plotting.get_driver_style(
        identifier=drv,
        style=['color', 'linestyle'],
        session=session
    )

    ax_pos.plot(
        drv_laps["LapNumber"],
        drv_laps["Position"],
        label=drv,
        **style
    )

ax_pos.set_ylim(6.2, 0.8)
ax_pos.set_yticks([1, 2, 3, 4, 5, 6])
ax_pos.set_xlabel("Lap")
ax_pos.set_ylabel("Race Position")
ax_pos.set_title("Qatar 2025 Position vs Lap")
ax_pos.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **From the plot above, we can see that Hamilton pitted at lap 13, and stayed on the Hard tires for the rest of the race, 39 laps.**

# %%
## let's plot lewis hamilton 2020 british grandprix

# Load a race session with year, event/race venue, and session type (Race, Qualifying, etc), use race designator R, versus Q for qualifying
session = fastf1.get_session(2020, 'British Grand Prix', 'R')
session.load()
import matplotlib.pyplot as plt

# Style for VER only
driver_styles = {
    "HAM": {"edgecolor": "black", "marker": "o"}
}

# Compound colors
COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

plt.figure(figsize=(14, 6))

# --- Only VER ---
drv = "HAM"
drv_laps = session.laps.pick_drivers(drv).pick_quicklaps()
style = driver_styles[drv]

for compound, comp_laps in drv_laps.groupby("Compound"):
    plt.scatter(
        comp_laps["LapNumber"],
        comp_laps["LapTime"].dt.total_seconds(),
        s=60,
        color=COMPOUND_COLORS.get(compound.upper(), "gray"),  # fill color
        edgecolor=style["edgecolor"],  # outline
        marker=style["marker"],  # marker shape
        linewidth=1.2,
        alpha=0.85,
        label=f"{drv} – {compound}"
    )

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2020 British GP – Lap Times by Compound (HAM Only)")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %%
## let's plot lewis hamilton 2020 british grandprix

session = fastf1.get_session(2020, 'British Grand Prix', 'R')
session.load()
import matplotlib.pyplot as plt
import numpy as np

driver_styles = {
    "HAM": {"edgecolor": "black", "marker": "o"}
}

COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

plt.figure(figsize=(14, 6))

drv = "HAM"
drv_laps = session.laps.pick_drivers(drv).pick_quicklaps()
style = driver_styles[drv]

for compound, comp_laps in drv_laps.groupby("Compound"):
    plt.scatter(
        comp_laps["LapNumber"],
        comp_laps["LapTime"].dt.total_seconds(),
        s=60,
        color=COMPOUND_COLORS.get(compound.upper(), "gray"),
        edgecolor=style["edgecolor"],
        marker=style["marker"],
        linewidth=1.2,
        alpha=0.85,
        label=f"{drv} – {compound}"
    )



x_parabola = np.linspace(45, 51, 200)
# --- Add updated parabola for laps 45–51 ---
a = 0.074
h = 45
k = 89.25

x_parabola = np.linspace(45, 51, 200)
y_parabola = a * (x_parabola - h)**2 + k

plt.plot(x_parabola, y_parabola, color='red', linewidth=2.5, label='Parabola Fit (45–51)')

y_parabola = a * (x_parabola - h) ** 2 + k

plt.plot(x_parabola, y_parabola, color='red', linewidth=2.5, label='Parabola Fit (45–51)')

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2020 British GP – Lap Times by Compound (HAM Only)")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# As seen above, the fuel consumption improvement per lap is greatly washed out by another effect beginning at lap 45.  At lap 45, the HARD tire compound
# begins to degrade with a "cliff" effect.  **Knowing when this cliff occurs for each compound is critical for pit strategy optimization.**

# %% [markdown]
# ### 4.3 Combining Fuel Consumption and Tire Degradation

# %% [markdown]
# As a simplified model, we can combine the fuel consumption effects with the tire degradation effects for a single tire compound.

# %%
## let's plot lewis hamilton 2020 british grandprix

session = fastf1.get_session(2020, 'British Grand Prix', 'R')
session.load()
import matplotlib.pyplot as plt
import numpy as np

driver_styles = {
    "HAM": {"edgecolor": "black", "marker": "o"}
}

COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

plt.figure(figsize=(14, 6))

drv = "HAM"
ham_drv_laps = session.laps.pick_drivers("HAM")
#drv_laps = session.laps.pick_drivers(drv)
drv_laps = session.laps.pick_drivers(drv).pick_quicklaps()
style = driver_styles[drv]

for compound, comp_laps in drv_laps.groupby("Compound"):
    plt.scatter(
        comp_laps["LapNumber"],
        comp_laps["LapTime"].dt.total_seconds(),
        s=60,
        color=COMPOUND_COLORS.get(compound.upper(), "gray"),
        edgecolor=style["edgecolor"],
        marker=style["marker"],
        linewidth=1.2,
        alpha=0.85,
        label=f"{drv} – {compound}"
    )

# --- Add green line between (19, 90.5) and (45, 89.25) ---
x_line = np.linspace(19, 45, 200)

m = (89.25 - 90.5) / (45 - 19)   # slope
b = 90.5 - m * 19                # intercept

y_line = m * x_line + b

plt.plot(x_line, y_line, color='lime', linewidth=2.5, label='Fuel Consumption - Linear Fit (19–45)')

x_parabola = np.linspace(45, 51, 200)
# --- Add updated parabola for laps 45–51 ---
a = 0.074
h = 45
k = 89.25

x_parabola = np.linspace(45, 51, 200)
y_parabola = a * (x_parabola - h) ** 2 + k

plt.plot(x_parabola, y_parabola, color='red', linewidth=2.5, label='Tire Degredation - Parabola Fit (45–51)')



plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2020 British GP – Lap Times by Compound (HAM Only)")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# With the plot above, we are now in a position to further understand the proper design of stints for optimal pit strategy.   Lewis Hamilton and Mercedes adhered to the two-different compound F1 policy, however as shown at the end of stint 2 (Hard compound), the tire's performance hit a cliff beginning with lap 45, or certainly at lap 48.  When Red Bull observed the slow down of Hamilton's car, they quickly pitted and put on SOFT tires in an effort to overtake Hamilton.  Unfortunately, they were a lap too late to overtake Hamilton, and Hamilton won the race.  See below.

# %% [markdown]
# **let's look at fitting a regression for the fuel consumption and tire degredation curve

# %%
for compound, comp_laps in drv_laps.groupby("Compound"):
    plt.scatter(
        comp_laps["LapNumber"],
        comp_laps["LapTime"].dt.total_seconds(),
        s=60,
        color=COMPOUND_COLORS.get(compound.upper(), "gray"),
        edgecolor=style["edgecolor"],
        marker=style["marker"],
        linewidth=1.2,
        alpha=0.85,
        label=f"{drv} – {compound}"
    )

# %% [markdown]
# Let's see if we can fit a polynomial to the HARD stint data.

# %%
hard_df = drv_laps[drv_laps["Compound"] == "HARD"].copy()

hard_df = hard_df.assign(
    LapTimeSeconds = hard_df["LapTime"].dt.total_seconds()
)[["LapNumber", "LapTimeSeconds"]]
hard_df[["LapNumber","LapTimeSeconds"]]

# %%
LapNumber_X = hard_df[['LapNumber']]          # 2‑D feature matrix
LapTimeSeconds_y = hard_df['LapTimeSeconds']  # 1‑D target vector

# %% [markdown]
# Here's the package we need per the Berkeley colab_activity9_2

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn import set_config
set_config(display="diagram")

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Here's a specific plot of the data

# %%
plt.scatter(LapNumber_X, LapTimeSeconds_y)
plt.title('Synthetic Polynomial Data')
plt.grid();

plt.scatter(LapNumber_X, LapTimeSeconds_y, color='white', edgecolor='black')
plt.title('2020 British Grand Prix - Lewis Hamilton')
plt.grid();
plt.grid()

# %% [markdown]
# Let's set up the pipeline also per the colab_activity9_2 notebook.

# %%
ols_pipe = Pipeline([
    ('poly_features', PolynomialFeatures(degree = 5, include_bias = False)),
    ('linreg', LinearRegression())
])
ols_pipe.fit(LapNumber_X, LapTimeSeconds_y)
ols_preds = ols_pipe.predict(LapNumber_X)
ols_pipe

# %% [markdown]
# Now Visualize the prediction

# %%
Xnp = LapNumber_X.to_numpy()

plt.scatter(
    Xnp,
    LapTimeSeconds_y,
    color='white',
    edgecolor='black',
    label='Race data'
)

plt.plot(
    Xnp,
    ols_preds,
    color='red',
    linestyle='--',
    linewidth=2,
    label='Linear regression predictions,5th degree polynomial'
)

plt.title("2020 F1 British GP – HAM – HARD Compound Stint")
plt.xlabel("Lap Number")
plt.ylabel("Lap Time (sec)")

plt.legend()
plt.grid()

# Save to PNG
plt.savefig("../images/ham_hard_stint.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Build a dataframe focused on dry weather analysis, tire stints

# %% [markdown]
# **In this section, we will explore building a dataframe for the sole purpose of analyzing tire performance**

# %%
def load_hard_laps_british_2020():
    # 2020 British GP is Round 4
    session = fastf1.get_session(2020, 4, 'R')
    session.load()

    laps = session.laps.copy()

    # Clean laps
    mask = laps['IsAccurate'] == True
    if 'PitInLap' in laps.columns:
        mask &= ~laps['PitInLap']
    if 'PitOutLap' in laps.columns:
        mask &= ~laps['PitOutLap']

    laps = laps[mask].copy()

    # Filter to HARD compound only
    hard_laps = laps[laps['Compound'] == 'HARD'].copy()

    # Add LapTimeSeconds
    hard_laps['LapTimeSeconds'] = hard_laps['LapTime'].dt.total_seconds()

    cols = [
        'Driver', 'Team',
        'LapNumber', 'Stint', 'TyreLife', 'Compound',
        'LapTimeSeconds', 'TrackStatus'
    ]

    return hard_laps[cols]
df = load_hard_laps_british_2020()
df_hard = load_hard_laps_british_2020()

# %%
# Remove hamilton's last lap
df_clean = df[df['LapTimeSeconds'] < 115].copy()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

sns.lineplot(
    data=df_clean,
    x='TyreLife',
    y='LapTimeSeconds',
    hue='Driver',
    estimator=None,      # plot raw lines, not averaged
    lw=2
)

plt.title("HARD Tire Degradation – British GP 2020 – All Drivers")
plt.xlabel("Tire Age (laps)")
plt.ylabel("Lap Time (seconds)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 1. Filter out Hamilton's puncture lap
df_clean = df[df['LapTimeSeconds'] < 115].copy()

# 2. Find drivers who reached >= 40 laps of TyreLife
drivers_with_40 = (
    df_clean.groupby('Driver')['TyreLife']
    .max()
)
drivers_with_40 = drivers_with_40[drivers_with_40 >= 40].index.tolist()

# 3. Filter the main DataFrame to only those drivers
df_long = df_clean[df_clean['Driver'].isin(drivers_with_40)].copy()

# 4. Plot using df_long (NOT drivers_with_40)
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

sns.lineplot(
    data=df_long,          # ✅ correct DataFrame
    x='TyreLife',
    y='LapTimeSeconds',
    hue='Driver',
    estimator=None,
    lw=2
)

plt.title("HARD Tire Degradation – British GP 2020 – Drivers With ≥40 Laps")
plt.xlabel("Tire Age (laps)")
plt.ylabel("Lap Time (seconds)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
lap40 = (
    df_long[df_long['TyreLife'] == 40]
    .groupby('Driver')['LapTimeSeconds']
    .mean()
)

# %%
slowest_drivers = lap40.sort_values(ascending=False).head(4).index.tolist()

# %%
df_cliff = df_long[df_long['Driver'].isin(slowest_drivers)].copy()

# %%
# 1. Filter out Hamilton's puncture lap
df_clean = df[df['LapTimeSeconds'] < 115].copy()

# 2. Find drivers who reached >= 40 laps of TyreLife
drivers_with_40 = (
    df_clean.groupby('Driver')['TyreLife']
    .max()
)
drivers_with_40 = drivers_with_40[drivers_with_40 >= 40].index.tolist()

# 3. Filter the main DataFrame to only those drivers
df_long = df_clean[df_clean['Driver'].isin(drivers_with_40)].copy()

# 4. Plot using df_long (NOT drivers_with_40)
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

sns.lineplot(
    data=df_cliff,  # ✅ correct DataFrame
    x='TyreLife',
    y='LapTimeSeconds',
    hue='Driver',
    estimator=None,
    lw=2
)

plt.title("HARD Tire Degradation – British GP 2020 – Drivers With ≥40 Laps")
plt.xlabel("Tire Age (laps)")
plt.ylabel("Lap Time (seconds)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Now let's develop cliff detection**.

# %%
def detect_cliff_stints(df, z=3.0):
    """
    Detects tire degradation cliffs using slope spikes.

    Parameters:
        df : DataFrame with columns ['Driver', 'Stint', 'TyreLife', 'LapTimeSeconds']
        z  : number of standard deviations above mean slope to define a cliff

    Returns:
        cliff_drivers : list of drivers who hit a cliff
        cliff_rows    : DataFrame of laps where the cliff was detected
    """

    cliff_rows = []

    # Loop through each driver/stint
    for (driver, stint), group in df.groupby(['Driver', 'Stint']):
        g = group.sort_values('TyreLife').copy()

        # Compute slope (Δlap time / Δage)
        g['DeltaLap'] = g['LapTimeSeconds'].diff()
        g['DeltaAge'] = g['TyreLife'].diff()
        g['Slope'] = g['DeltaLap'] / g['DeltaAge']

        # Compute threshold for cliff
        mean_slope = g['Slope'].mean()
        std_slope = g['Slope'].std()
        threshold = mean_slope + z * std_slope

        # Find laps where slope exceeds threshold
        cliff_laps = g[g['Slope'] > threshold]

        if not cliff_laps.empty:
            cliff_rows.append(cliff_laps)

    if cliff_rows:
        cliff_rows = pd.concat(cliff_rows, ignore_index=True)
        cliff_drivers = cliff_rows['Driver'].unique().tolist()
    else:
        cliff_rows = pd.DataFrame()
        cliff_drivers = []

    return cliff_drivers, cliff_rows

# %%
def detect_cliff_stints(df, z=2.0):
    cliff_rows = []

    for (driver, stint), group in df.groupby(['Driver', 'Stint']):
        g = group.sort_values('TyreLife').copy()

        # Compute slope
        g['DeltaLap'] = g['LapTimeSeconds'].diff()
        g['DeltaAge'] = g['TyreLife'].diff()
        g['Slope'] = g['DeltaLap'] / g['DeltaAge']

        # Threshold for cliff
        mean_slope = g['Slope'].mean()
        std_slope = g['Slope'].std()
        threshold = mean_slope + z * std_slope

        # Require 2 consecutive high-slope laps
        g['IsCliff'] = g['Slope'] > threshold
        g['CliffRun'] = g['IsCliff'].rolling(window=2).sum() >= 2

        cliff_laps = g[g['CliffRun']]

        if not cliff_laps.empty:
            cliff_rows.append(cliff_laps)

    if cliff_rows:
        cliff_rows = pd.concat(cliff_rows, ignore_index=True)
        cliff_drivers = cliff_rows['Driver'].unique().tolist()
    else:
        cliff_rows = pd.DataFrame()
        cliff_drivers = []

    return cliff_drivers, cliff_rows

# %%
def detect_cliff_stints(df, z=2.0, late_age=35, extreme_z=4.0):
    """
    Detects tire cliffs with two mechanisms:
      1) Two consecutive high-slope laps (degradation cliff)
      2) One extreme high-slope lap at high TyreLife (failure cliff)
    """

    cliff_rows = []

    for (driver, stint), group in df.groupby(['Driver', 'Stint']):
        g = group.sort_values('TyreLife').copy()

        # Compute slope
        g['DeltaLap'] = g['LapTimeSeconds'].diff()
        g['DeltaAge'] = g['TyreLife'].diff()
        g['Slope'] = g['DeltaLap'] / g['DeltaAge']

        if g['Slope'].count() < 3:
            continue

        mean_slope = g['Slope'].mean()
        std_slope = g['Slope'].std()

        # Normal cliff threshold
        threshold = mean_slope + z * std_slope
        # Extreme late-stint threshold
        extreme_threshold = mean_slope + extreme_z * std_slope

        g['IsCliff'] = g['Slope'] > threshold

        # 1) Two consecutive high-slope laps
        g['TwoInARow'] = g['IsCliff'].rolling(window=2).sum() == 2

        # 2) One extreme spike at high TyreLife
        g['LateExtreme'] = (g['TyreLife'] >= late_age) & (g['Slope'] > extreme_threshold)

        # Combine conditions
        g['CliffFlag'] = g['TwoInARow'] | g['LateExtreme']

        cliff_laps = g[g['CliffFlag']]

        if not cliff_laps.empty:
            cliff_rows.append(cliff_laps)

    if cliff_rows:
        cliff_rows = pd.concat(cliff_rows, ignore_index=True)
        cliff_drivers = cliff_rows['Driver'].unique().tolist()
    else:
        cliff_rows = pd.DataFrame()
        cliff_drivers = []

    return cliff_drivers, cliff_rows

# %%
cliff_drivers, cliff_rows = detect_cliff_stints(df_hard)
print("Drivers who hit the cliff:", cliff_drivers)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Base degradation curves
sns.lineplot(
    data=df_hard,
    x='TyreLife',
    y='LapTimeSeconds',
    hue='Driver',
    estimator=None,
    lw=1.5,
    alpha=0.6
)

# Highlight cliff laps
if not cliff_rows.empty:
    plt.scatter(
        cliff_rows['TyreLife'],
        cliff_rows['LapTimeSeconds'],
        color='red',
        s=60,
        label='Detected Cliff Laps'
    )

plt.title("Detected Tire Cliffs – British GP 2020 – HARD Compound")
plt.xlabel("Tire Age (laps)")
plt.ylabel("Lap Time (seconds)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_cliff_drivers = df_hard[df_hard['Driver'].isin(cliff_drivers)].copy()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

sns.lineplot(
    data=df_cliff_drivers,
    x='TyreLife',
    y='LapTimeSeconds',
    hue='Driver',
    estimator=None,
    lw=2
)

plt.title("HARD Tire Degradation – British GP 2020 – Drivers Who Hit the Cliff")
plt.xlabel("Tire Age (laps)")
plt.ylabel("Lap Time (seconds)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's do a rolling z-score detector.

# %%
def detect_cliff_anomalies(df, window=5, z_thresh=1.0, extreme_z=4.0, late_age=35):
    """
    Rolling z-score anomaly detector for tire cliffs.
    Detects:
      - multi-lap degradation cliffs (rolling z-score > z_thresh)
      - single-lap late-stint failures (z-score > extreme_z at high TyreLife)
    """

    cliff_rows = []

    for (driver, stint), g in df.groupby(['Driver', 'Stint']):
        g = g.sort_values('TyreLife').copy()

        # Compute slope
        g['DeltaLap'] = g['LapTimeSeconds'].diff()
        g['DeltaAge'] = g['TyreLife'].diff()
        g['Slope'] = g['DeltaLap'] / g['DeltaAge']

        # Rolling mean and std
        g['RollMean'] = g['Slope'].rolling(window=window, min_periods=3).mean()
        g['RollStd'] = g['Slope'].rolling(window=window, min_periods=3).std()

        # Z-score
        g['Z'] = (g['Slope'] - g['RollMean']) / g['RollStd']

        # Conditions
        g['IsCliff'] = g['Z'] > z_thresh
        g['TwoInARow'] = g['IsCliff'].rolling(2).sum() == 2
        g['LateExtreme'] = (g['TyreLife'] >= late_age) & (g['Z'] > extreme_z)

        g['CliffFlag'] = g['TwoInARow'] | g['LateExtreme']

        cliff_laps = g[g['CliffFlag']]
        if not cliff_laps.empty:
            cliff_rows.append(cliff_laps)

    if cliff_rows:
        cliff_rows = pd.concat(cliff_rows, ignore_index=True)
        cliff_drivers = cliff_rows['Driver'].unique().tolist()
    else:
        cliff_rows = pd.DataFrame()
        cliff_drivers = []

    return cliff_drivers, cliff_rows

# %%
cliff_drivers, cliff_rows = detect_cliff_anomalies(df_hard)
print("Drivers who hit the cliff:", cliff_drivers)
df_cliff_drivers = df_hard[df_hard['Driver'].isin(cliff_drivers)].copy()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

sns.lineplot(
    data=df_cliff_drivers,
    x='TyreLife',
    y='LapTimeSeconds',
    hue='Driver',
    estimator=None,
    lw=2
)

plt.title("HARD Tire Degradation – British GP 2020 – Drivers Who Hit the Cliff")
plt.xlabel("Tire Age (laps)")
plt.ylabel("Lap Time (seconds)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's try a different approach, ruptures approach.

# %% [markdown]
# **The above ruptures detector didn't work, let's try the acceleration approach**.

# %%
# %% MONOLITHIC HARD-TIRE CLIFF DETECTOR WITH TOP_N RANKING + WILD LAP FILTER

# ------------------------------------------------------------
# GLOBAL SETTINGS (adjust in ONE place)
# ------------------------------------------------------------
SLOPE_WINDOW = 3          # smoothing (higher = less sensitive)
ACCEL_THRESHOLD = 0.08    # main sensitivity knob (higher = less sensitive)
MIN_TYRE_LIFE = 25        # ignore early-stint noise
TOP_N = 5                 # number of worst cliffs to plot
MAX_LAPTIME_JUMP = 8.0    # drop laps where lap time jumps > this many seconds


# ------------------------------------------------------------
# LOAD HARD LAPS FOR 2020 BRITISH GP
# ------------------------------------------------------------

def load_hard_laps_british_2020():
    session = fastf1.get_session(2020, 4, 'R')
    session.load()

    laps = session.laps.copy()

    # Clean laps
    mask = laps['IsAccurate'] == True
    if 'PitInLap' in laps.columns:
        mask &= ~laps['PitInLap']
    if 'PitOutLap' in laps.columns:
        mask &= ~laps['PitOutLap']

    laps = laps[mask].copy()

    # Filter to HARD compound only
    hard_laps = laps[laps['Compound'] == 'HARD'].copy()

    # Add LapTimeSeconds
    hard_laps['LapTimeSeconds'] = hard_laps['LapTime'].dt.total_seconds()

    cols = [
        'Driver', 'Team',
        'LapNumber', 'Stint', 'TyreLife', 'Compound',
        'LapTimeSeconds', 'TrackStatus'
    ]

    return hard_laps[cols]


df_hard = load_hard_laps_british_2020()


# ------------------------------------------------------------
# REMOVE WILD LAPTIME JUMPS PER DRIVER
# ------------------------------------------------------------

def remove_wild_laps(df, max_jump):
    df = df.copy()
    cleaned = []

    for driver, g in df.groupby("Driver"):
        g = g.sort_values("LapNumber").copy()
        g["LapDiff"] = g["LapTimeSeconds"].diff()

        # Keep laps where the jump is not insane
        g = g[(g["LapDiff"].isna()) | (g["LapDiff"] < max_jump)]

        cleaned.append(g)

    return pd.concat(cleaned).drop(columns=["LapDiff"])


df_hard = remove_wild_laps(df_hard, MAX_LAPTIME_JUMP)


# ------------------------------------------------------------
# ACCELERATION-BASED CLIFF DETECTOR
# ------------------------------------------------------------

def detect_cliffs_acceleration(
    df,
    slope_window,
    accel_threshold,
    min_tyre_life
):
    df = df.copy()
    df["Slope"] = np.nan
    df["SlopeSmooth"] = np.nan
    df["Accel"] = np.nan
    df["IsCliffLap"] = False

    cliff_events = []

    for (driver, stint), g in df.groupby(["Driver", "Stint"]):
        g = g.sort_values("TyreLife").copy()

        # First derivative
        g["Slope"] = g["LapTimeSeconds"].diff()

        # Smooth slope
        g["SlopeSmooth"] = g["Slope"].rolling(slope_window, min_periods=1).mean()

        # Second derivative
        g["Accel"] = g["SlopeSmooth"].diff()

        # Cliff condition
        g["Cliff"] = (
            (g["Accel"] > accel_threshold) &
            (g["TyreLife"] > min_tyre_life)
        )

        if g["Cliff"].any():
            cliff_idx = g.index[g["Cliff"]][0]
            cliff_lap = g.loc[cliff_idx, "TyreLife"]
            accel_value = g.loc[cliff_idx, "Accel"]

            cliff_events.append({
                "Driver": driver,
                "Stint": stint,
                "CliffLap": cliff_lap,
                "AccelAtCliff": accel_value
            })

            df.loc[cliff_idx, "IsCliffLap"] = True

    return pd.DataFrame(cliff_events), df


# ------------------------------------------------------------
# RUN DETECTOR
# ------------------------------------------------------------

cliff_events, df_hard_with_flags = detect_cliffs_acceleration(
    df_hard,
    slope_window=SLOPE_WINDOW,
    accel_threshold=ACCEL_THRESHOLD,
    min_tyre_life=MIN_TYRE_LIFE
)

print("Detected cliff events:")
print(cliff_events)


# ------------------------------------------------------------
# SELECT TOP_N WORST CLIFFS
# ------------------------------------------------------------

cliff_events_sorted = cliff_events.sort_values(
    "AccelAtCliff", ascending=False
).reset_index(drop=True)

top_drivers = cliff_events_sorted["Driver"].head(TOP_N).tolist()
print(f"\nTop {TOP_N} worst cliff drivers:", top_drivers)

df_plot = df_hard_with_flags[
    df_hard_with_flags["Driver"].isin(top_drivers)
].sort_values(["Driver", "TyreLife"])


# ------------------------------------------------------------
# PLOT TOP_N DRIVERS ONLY
# ------------------------------------------------------------

plt.figure(figsize=(12, 6))

sns.lineplot(
    data=df_plot,
    x="TyreLife",
    y="LapTimeSeconds",
    hue="Driver",
    errorbar=None,
    lw=2
)

df_cliff_points = df_plot[df_plot["IsCliffLap"]]

sns.scatterplot(
    data=df_cliff_points,
    x="TyreLife",
    y="LapTimeSeconds",
    hue="Driver",
    marker="X",
    s=140,
    legend=False
)

plt.title(f"Top {TOP_N} Worst Tire Cliffs – HARD Tire – British GP 2020")
plt.xlabel("Tire Age (laps)")
plt.ylabel("Lap Time (seconds)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Now we can build a cliff detector that has year, race venue, compound as inputs at the top of the code**

# %%
# %% GENERALIZED TIRE CLIFF DETECTOR WITH TOP_N RANKING + WILD LAP FILTER


# ------------------------------------------------------------
# GLOBAL SETTINGS (adjust in ONE place)
# ------------------------------------------------------------
RACE_YEAR = 2023
RACE_ROUND = 'Japanese Grand Prix'             # can also be a venue string like "Silverstone"
TARGET_COMPOUND = "SOFT"    # HARD, MEDIUM, SOFT
if TARGET_COMPOUND == "HARD":
    SLOPE_WINDOW = 3            # smoothing (higher = less sensitive)
    ACCEL_THRESHOLD = 0.12      # main sensitivity knob (higher = less sensitive)
    MIN_TYRE_LIFE = 25          # ignore early-stint noise
    TOP_N = 5                   # number of worst cliffs to plot
    MAX_LAPTIME_JUMP = 8.0      # drop laps where lap time jumps > this many seconds
elif TARGET_COMPOUND == "MEDIUM":
    SLOPE_WINDOW = 4            # smoothing (higher = less sensitive)
    ACCEL_THRESHOLD = 0.05      # main sensitivity knob (higher = less sensitive)
    MIN_TYRE_LIFE = 10         # ignore early-stint noise
    TOP_N = 5                   # number of worst cliffs to plot
    MAX_LAPTIME_JUMP = 8.0      # drop laps where lap time jumps > this many seconds

elif TARGET_COMPOUND == "SOFT":
    SLOPE_WINDOW = 3          # more responsive to early bend
    ACCEL_THRESHOLD = 0.025   # SOFT cliffs are smaller in magnitude
    MIN_TYRE_LIFE = 6         # SOFT stints are short; cliff often 8–12 laps
    TOP_N = 5
    MAX_LAPTIME_JUMP = 8.0
else:
    raise ValueError(f"Unknown compound: {TARGET_COMPOUND}")

# ------------------------------------------------------------
# LOAD LAPS FOR ANY RACE + COMPOUND
# ------------------------------------------------------------

def load_laps(year, round_or_name, compound):
    session = fastf1.get_session(year, round_or_name, 'R')
    session.load()

    laps = session.laps.copy()

    # Clean laps
    mask = laps['IsAccurate'] == True
    if 'PitInLap' in laps.columns:
        mask &= ~laps['PitInLap']
    if 'PitOutLap' in laps.columns:
        mask &= ~laps['PitOutLap']

    laps = laps[mask].copy()

    # Filter to target compound
    laps = laps[laps['Compound'] == compound].copy()

    # Add LapTimeSeconds
    laps['LapTimeSeconds'] = laps['LapTime'].dt.total_seconds()

    cols = [
        'Driver', 'Team',
        'LapNumber', 'Stint', 'TyreLife', 'Compound',
        'LapTimeSeconds', 'TrackStatus'
    ]

    return laps[cols]


df = load_laps(RACE_YEAR, RACE_ROUND, TARGET_COMPOUND)


# ------------------------------------------------------------
# REMOVE WILD LAPTIME JUMPS PER DRIVER
# ------------------------------------------------------------

def remove_wild_laps(df, max_jump):
    df = df.copy()
    cleaned = []

    for driver, g in df.groupby("Driver"):
        g = g.sort_values("LapNumber").copy()
        g["LapDiff"] = g["LapTimeSeconds"].diff()

        # Keep laps where the jump is not insane
        g = g[(g["LapDiff"].isna()) | (g["LapDiff"] < max_jump)]

        cleaned.append(g)

    return pd.concat(cleaned).drop(columns=["LapDiff"])


df = remove_wild_laps(df, MAX_LAPTIME_JUMP)


# ------------------------------------------------------------
# ACCELERATION-BASED CLIFF DETECTOR
# ------------------------------------------------------------

def detect_cliffs_acceleration(
    df,
    slope_window,
    accel_threshold,
    min_tyre_life
):
    df = df.copy()
    df["Slope"] = np.nan
    df["SlopeSmooth"] = np.nan
    df["Accel"] = np.nan
    df["IsCliffLap"] = False

    cliff_events = []

    for (driver, stint), g in df.groupby(["Driver", "Stint"]):
        g = g.sort_values("TyreLife").copy()

        # First derivative
        g["Slope"] = g["LapTimeSeconds"].diff()

        # Smooth slope
        g["SlopeSmooth"] = g["Slope"].rolling(slope_window, min_periods=1).mean()

        # Second derivative
        g["Accel"] = g["SlopeSmooth"].diff()

        # Cliff condition
        g["Cliff"] = (
            (g["Accel"] > accel_threshold) &
            (g["TyreLife"] > min_tyre_life)
        )

        if g["Cliff"].any():
            cliff_idx = g.index[g["Cliff"]][0]
            cliff_lap = g.loc[cliff_idx, "TyreLife"]
            accel_value = g.loc[cliff_idx, "Accel"]

            cliff_events.append({
                "Driver": driver,
                "Stint": stint,
                "CliffLap": cliff_lap,
                "AccelAtCliff": accel_value
            })

            df.loc[cliff_idx, "IsCliffLap"] = True

    return pd.DataFrame(cliff_events), df


# ------------------------------------------------------------
# RUN DETECTOR
# ------------------------------------------------------------

cliff_events, df_with_flags = detect_cliffs_acceleration(
    df,
    slope_window=SLOPE_WINDOW,
    accel_threshold=ACCEL_THRESHOLD,
    min_tyre_life=MIN_TYRE_LIFE
)

print("Detected cliff events:")
print(cliff_events)


# ------------------------------------------------------------
# SELECT TOP_N WORST CLIFFS
# ------------------------------------------------------------

cliff_events_sorted = cliff_events.sort_values(
    "AccelAtCliff", ascending=False
).reset_index(drop=True)

top_drivers = cliff_events_sorted["Driver"].head(TOP_N).tolist()
print(f"\nTop {TOP_N} worst cliff drivers:", top_drivers)

df_plot = df_with_flags[
    df_with_flags["Driver"].isin(top_drivers)
].sort_values(["Driver", "TyreLife"])


# ------------------------------------------------------------
# PLOT TOP_N DRIVERS ONLY
# ------------------------------------------------------------

plt.figure(figsize=(12, 6))

sns.lineplot(
    data=df_plot,
    x="TyreLife",
    y="LapTimeSeconds",
    hue="Driver",
    errorbar=None,
    lw=2
)

df_cliff_points = df_plot[df_plot["IsCliffLap"]]

sns.scatterplot(
    data=df_cliff_points,
    x="TyreLife",
    y="LapTimeSeconds",
    hue="Driver",
    marker="X",
    s=140,
    legend=False
)

plt.title(
    f"Top {TOP_N} Worst Tire Cliffs – {TARGET_COMPOUND} – "
    f"{RACE_YEAR} Round {RACE_ROUND}"
)

plt.xlabel("Tire Age (laps)")
plt.ylabel("Lap Time (seconds)")
plt.grid(True)
plt.tight_layout()
if (TARGET_COMPOUND == "HARD"):
    plt.savefig("../images/hard_degradation_plot.png", dpi=300, bbox_inches='tight')
if (TARGET_COMPOUND == "MEDIUM"):
    plt.savefig("../images/medium_degradation_plot.png", dpi=300, bbox_inches='tight')
if (TARGET_COMPOUND == "SOFT"):
    plt.savefig("../images/soft_degradation_plot.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
session = fastf1.get_session(2020, "British Grand Prix", "R")
session.load()

records = []

for drv in session.drivers:
    laps = session.laps.pick_driver(drv)
    for _, lap in laps.iterlaps():
        records.append({
            "Driver": drv,
            "LapNumber": lap["LapNumber"],
            "LapTimeSeconds": lap["LapTime"].total_seconds(),
            "TyreLife": lap["TyreLife"],
            "Compound": lap["Compound"]
        })

df = pd.DataFrame(records)
plt.figure(figsize=(12, 6))

for compound, color in [
    ("HARD", "blue"),
    ("MEDIUM", "orange"),
    ("SOFT", "red")
]:
    # 1. Filter laps for this compound
    df_comp = df[df["Compound"] == compound]

    # 2. Smooth lap times
    #df_comp["LapTimeSmooth"] = df_comp["LapTime"].rolling(5, center=True).mean()
    df_comp["LapTimeSmooth"] = (
        df_comp["LapTimeSeconds"].rolling(5, center=True).mean()
    )

    # 3. Compute average lap time per TyreLife
    archetype = df_comp.groupby("TyreLife")["LapTimeSmooth"].mean()

    # 4. Plot
    plt.plot(archetype.index, archetype.values, label=compound, color=color)

plt.xlabel("Tyre Life (laps)")
plt.ylabel("Lap Time (seconds)")
plt.title("Degradation Archetypes: HARD vs MEDIUM vs SOFT")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# %% ROBUST GENERALIZED TIRE CLIFF DETECTOR (SMOOTHED DERIVATIVES + TOP_N)



# ------------------------------------------------------------
# GLOBAL SETTINGS (adjust in ONE place)
# ------------------------------------------------------------
RACE_YEAR = 2020
RACE_ROUND = "British Grand Prix"     # can also be a round number
TARGET_COMPOUND = "HARD"

# Robust detector parameters
LAPTIME_SMOOTH_WINDOW = 5      # smooth raw lap times
SLOPE_WINDOW = 5               # smooth slope
ACCEL_WINDOW = 3               # smooth acceleration
ACCEL_THRESHOLD = 0.04         # threshold for smoothed acceleration
MIN_TYRE_LIFE = 20             # ignore early laps
CONSECUTIVE_LAPS = 2           # require multi-lap confirmation

TOP_N = 5                      # number of drivers to plot
MAX_LAPTIME_JUMP = 8.0         # remove wild laps


# ------------------------------------------------------------
# LOAD LAPS FOR ANY RACE + COMPOUND
# ------------------------------------------------------------

def load_laps(year, round_or_name, compound):
    session = fastf1.get_session(year, round_or_name, 'R')
    session.load()

    laps = session.laps.copy()

    # Clean laps
    mask = laps['IsAccurate'] == True
    if 'PitInLap' in laps.columns:
        mask &= ~laps['PitInLap']
    if 'PitOutLap' in laps.columns:
        mask &= ~laps['PitOutLap']

    laps = laps[mask].copy()

    # Filter to target compound
    laps = laps[laps['Compound'] == compound].copy()

    # Add LapTimeSeconds
    laps['LapTimeSeconds'] = laps['LapTime'].dt.total_seconds()

    cols = [
        'Driver', 'Team',
        'LapNumber', 'Stint', 'TyreLife', 'Compound',
        'LapTimeSeconds', 'TrackStatus'
    ]

    return laps[cols]


df = load_laps(RACE_YEAR, RACE_ROUND, TARGET_COMPOUND)


# ------------------------------------------------------------
# REMOVE WILD LAPTIME JUMPS PER DRIVER
# ------------------------------------------------------------

def remove_wild_laps(df, max_jump):
    df = df.copy()
    cleaned = []

    for driver, g in df.groupby("Driver"):
        g = g.sort_values("LapNumber").copy()
        g["LapDiff"] = g["LapTimeSeconds"].diff()

        g = g[(g["LapDiff"].isna()) | (g["LapDiff"] < max_jump)]
        cleaned.append(g)

    return pd.concat(cleaned).drop(columns=["LapDiff"])


df = remove_wild_laps(df, MAX_LAPTIME_JUMP)


# ------------------------------------------------------------
# ROBUST ACCELERATION-BASED CLIFF DETECTOR
# ------------------------------------------------------------

def detect_cliffs_robust(
    df,
    laptime_smooth_window,
    slope_window,
    accel_window,
    accel_threshold,
    min_tyre_life,
    consecutive_laps
):
    df = df.copy()
    df["IsCliffLap"] = False

    cliff_events = []

    for (driver, stint), g in df.groupby(["Driver", "Stint"]):
        g = g.sort_values("TyreLife").copy()

        # 1. Smooth lap times FIRST
        g["LapSmooth"] = g["LapTimeSeconds"].rolling(
            laptime_smooth_window, min_periods=1
        ).mean()

        # 2. First derivative (slope)
        g["Slope"] = g["LapSmooth"].diff()

        # 3. Smooth slope
        g["SlopeSmooth"] = g["Slope"].rolling(
            slope_window, min_periods=1
        ).mean()

        # 4. Second derivative (acceleration)
        g["Accel"] = g["SlopeSmooth"].diff()

        # 5. Smooth acceleration
        g["AccelSmooth"] = g["Accel"].rolling(
            accel_window, min_periods=1
        ).mean()

        # 6. Cliff condition: multi-lap confirmation
        g["CliffRaw"] = (
            (g["AccelSmooth"] > accel_threshold) &
            (g["TyreLife"] > min_tyre_life)
        )

        # Require consecutive laps above threshold
        g["Cliff"] = (
            g["CliffRaw"] &
            g["CliffRaw"].shift(1).fillna(False)
        )

        if g["Cliff"].any():
            idx = g.index[g["Cliff"]][0]
            cliff_lap = g.loc[idx, "TyreLife"]
            accel_value = g.loc[idx, "AccelSmooth"]

            cliff_events.append({
                "Driver": driver,
                "Stint": stint,
                "CliffLap": cliff_lap,
                "AccelAtCliff": accel_value
            })

            df.loc[idx, "IsCliffLap"] = True

    return pd.DataFrame(cliff_events), df


# ------------------------------------------------------------
# RUN DETECTOR
# ------------------------------------------------------------

cliff_events, df_with_flags = detect_cliffs_robust(
    df,
    laptime_smooth_window=LAPTIME_SMOOTH_WINDOW,
    slope_window=SLOPE_WINDOW,
    accel_window=ACCEL_WINDOW,
    accel_threshold=ACCEL_THRESHOLD,
    min_tyre_life=MIN_TYRE_LIFE,
    consecutive_laps=CONSECUTIVE_LAPS
)

print("Detected cliff events:")
print(cliff_events)


# ------------------------------------------------------------
# SELECT TOP_N WORST CLIFFS
# ------------------------------------------------------------

cliff_events_sorted = cliff_events.sort_values(
    "AccelAtCliff", ascending=False
).reset_index(drop=True)

top_drivers = cliff_events_sorted["Driver"].head(TOP_N).tolist()
print(f"\nTop {TOP_N} worst cliff drivers:", top_drivers)

df_plot = df_with_flags[
    df_with_flags["Driver"].isin(top_drivers)
].sort_values(["Driver", "TyreLife"])


# ------------------------------------------------------------
# PLOT TOP_N DRIVERS ONLY
# ------------------------------------------------------------

plt.figure(figsize=(12, 6))

sns.lineplot(
    data=df_plot,
    x="TyreLife",
    y="LapTimeSeconds",
    hue="Driver",
    errorbar=None,
    lw=2
)

df_cliff_points = df_plot[df_plot["IsCliffLap"]]

sns.scatterplot(
    data=df_cliff_points,
    x="TyreLife",
    y="LapTimeSeconds",
    hue="Driver",
    marker="X",
    s=140,
    legend=False
)

plt.title(
    f"Top {TOP_N} Worst Tire Cliffs – {TARGET_COMPOUND} – "
    f"{RACE_YEAR} {RACE_ROUND}"
)

plt.xlabel("Tire Age (laps)")
plt.ylabel("Lap Time (seconds)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def load_single_race(year, round_number, driver=None):
    session = fastf1.get_session(year, round_number, 'R')
    session.load()

    laps = session.laps.copy()

    # Clean laps
    mask = laps['IsAccurate'] == True
    if 'PitInLap' in laps.columns:
        mask &= ~laps['PitInLap']
    if 'PitOutLap' in laps.columns:
        mask &= ~laps['PitOutLap']

    laps = laps[mask].copy()

    # Optional: filter to one driver
    if driver is not None:
        laps = laps[laps['Driver'] == driver].copy()

    # Add metadata
    event = session.event
    laps['Year'] = year
    laps['EventName'] = event['EventName']
    laps['CircuitName'] = event['Location']
    laps['LapTimeSeconds'] = laps['LapTime'].dt.total_seconds()

    cols = [
        'Year', 'EventName', 'CircuitName',
        'Driver', 'Team', 'LapNumber', 'Stint',
        'TyreLife', 'Compound', 'LapTimeSeconds'
    ]

    return laps[cols]

# Example: 2023 Bahrain GP, Hamilton only
df = load_single_race(2023, 1, driver='HAM')

# %%
df.head()

# %%
def load_all_laps(start_year=2024, end_year=2025):
    all_laps = []

    for year in range(start_year, end_year + 1):
        schedule = fastf1.get_event_schedule(year)

        for rnd in schedule.index:

            # Skip pre-season testing (Round 0)
            if rnd == 0:
                continue

            event = schedule.loc[rnd]

            # Load the race session
            session = fastf1.get_session(year, rnd, 'R')

            try:
                session.load()
            except Exception:
                continue  # skip sessions that fail to load

            laps = session.laps.copy()

            # Clean laps safely depending on available columns
            mask = laps['IsAccurate'] == True

            if 'PitInLap' in laps.columns:
                mask &= ~laps['PitInLap']
            if 'PitOutLap' in laps.columns:
                mask &= ~laps['PitOutLap']

            # IMPORTANT: make a real copy to avoid SettingWithCopyWarning
            laps = laps[mask].copy()

            # Add metadata
            laps['Year'] = year
            laps['RoundNumber'] = rnd
            laps['EventName'] = event['EventName']
            laps['CircuitName'] = event['Location']

            # Convert LapTime to seconds
            laps['LapTimeSeconds'] = laps['LapTime'].dt.total_seconds()

            # Select useful columns
            cols = [
                'Year', 'RoundNumber', 'EventName', 'CircuitName',
                'Driver', 'Team', 'DriverNumber',
                'LapNumber', 'Stint', 'TyreLife', 'Compound',
                'TrackStatus', 'IsAccurate',
                'LapTime', 'LapTimeSeconds',
                'Sector1Time', 'Sector2Time', 'Sector3Time'
            ]

            all_laps.append(laps[cols])

    return pd.concat(all_laps, ignore_index=True)

# Build the full dataset
df = load_all_laps()

# %%
## let's plot lewis hamilton 2020 british grandprix

session = fastf1.get_session(2020, 'British Grand Prix', 'R')
session.load()
import matplotlib.pyplot as plt
import numpy as np

driver_styles = {
    "HAM": {"edgecolor": "black", "marker": "o"},
    "VER": {"edgecolor": "black", "marker": "s"}  # square marker for VER
}

COMPOUND_COLORS = {
    "SOFT": "#FF3333",
    "MEDIUM": "#FFCC33",
    "HARD": "#FFFFFF",
    "INTERMEDIATE": "#39B54A",
    "WET": "#00AEEF"
}

plt.figure(figsize=(14, 6))

# ---------------------------
# Plot HAM and VER together
# ---------------------------
for drv in ["HAM", "VER"]:
    drv_laps = session.laps.pick_drivers(drv).pick_quicklaps()
    style = driver_styles[drv]

    for compound, comp_laps in drv_laps.groupby("Compound"):
        plt.scatter(
            comp_laps["LapNumber"],
            comp_laps["LapTime"].dt.total_seconds(),
            s=60,
            color=COMPOUND_COLORS.get(compound.upper(), "gray"),
            edgecolor=style["edgecolor"],
            marker=style["marker"],
            linewidth=1.2,
            alpha=0.85,
            label=f"{drv} – {compound}"
        )

# --- Add green line between (19, 90.5) and (45, 89.25) ---
x_line = np.linspace(19, 45, 200)

m = (89.25 - 90.5) / (45 - 19)  # slope
b = 90.5 - m * 19  # intercept

y_line = m * x_line + b

plt.plot(x_line, y_line, color='lime', linewidth=2.5, label='Fuel Consumption - Linear Fit (19–45)')

# --- Add updated parabola for laps 45–51 ---
a = 0.074
h = 45
k = 89.25

x_parabola = np.linspace(45, 51, 200)
y_parabola = a * (x_parabola - h) ** 2 + k

plt.plot(x_parabola, y_parabola, color='red', linewidth=2.5, label='Tire Degradation - Parabola Fit (45–51)')

plt.xlabel("Lap Number")
plt.ylabel("Lap Time (seconds)")
plt.title("2020 British GP – Lap Times by Compound (HAM & VER)")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# **From the plot above, we see that the Soft tire lap time (lap 52) was just over 87 seconds, as compared to Hamilton's 51st lap of over 92 seconds - an exciting end to the 2020 British Grand Prix!**

# %% [markdown]
# Next steps, build a workflow and model for predicting lap time.
# The equation will be lap_time = lap_time_base + lap_time_fuel + lap_time_tire_degrad:
# * lap_time_base will be determined from qualification testing available in fastf1 data
# * lap_time_fuel will be determined from the first 5 laps of a stint
# * lap_time_degrad will be determined by modeling race day data - particularly for races where the degradation cliff is observed

# %%
# 1. Basic stint/compound table
out = drv_laps.groupby("Stint")["Compound"].value_counts().reset_index(name="Count")

# 2. Get stint end laps
stint_end_laps = drv_laps.groupby("Stint")["LapNumber"].max()

# 3. Get pit-in laps
pit_laps = drv_laps.loc[drv_laps["PitInTime"].notna(), "LapNumber"]

# 4. Map: if a stint ends on a pit lap, assign it
out["PitLap"] = out["Stint"].map(
    stint_end_laps[stint_end_laps.isin(pit_laps)]
)
out

# %% [markdown]
# Answering the question, "Should we pit now or wait?" correctly requires a strategy - each pit don't pit decision is critical and non-reversible and as the Qatar race revealed, critical.  One of the most sigficant factors toward choosing a pit strategy is  to choose a combination of tire compounds that will minimize lap times and thus minimize the race elapsed time.   Properly evaluating tire compound performance requires that we remove fuel consumption effects from lap time allowing tire compound performance to be evaluated as independently as possible.

# %% [markdown]
# ## Approach for modeling fuel consumption effects - I'll review from co-pilot

# %% [markdown]
# notes about fuel and tires,
#
# You’re thinking about this in exactly the right order. If you try to model tire degradation *and* fuel effects at the same time, they blur together and you end up with a mushy model that doesn’t cleanly explain either. The cleanest workflow is:
#
# 1. **Extract the fuel‑effect signal first**
# 2. **Remove it from the lap times**
# 3. **Use the fuel‑corrected lap times to study tire degradation later**
#
# That separation gives you two clean, interpretable models instead of one tangled one.
#
# Let’s walk through how to do this in a way that keeps the physics and the data aligned.
#
# ---
#
# # 🔥 Step 1 — Identify laps where tire degradation is minimal relative to fuel burn
#
# Fuel effect is strongest early in the stint. Tire degradation is weakest early in the stint.
#
# So the best place to isolate fuel effect is:
# - **First 5–10 laps of each stint**
# - **On the same compound**
# - **On green-flag laps**
# - **On representative pace (no in/out laps)**
#
# This gives you a window where the lap-time slope is dominated by fuel burn.
#
# ---
#
# # 🧹 Step 2 — Clean the laps so only fuel effect remains
#
# You want to remove everything that contaminates the signal:
#
# - Safety car / VSC laps
# - In-laps and out-laps
# - Laps with yellow flags
# - Laps with traffic (optional, but helpful)
# - Laps with big driver push variation (FastF1’s `pick_quicklaps()` helps)
#
# This leaves you with a clean lap-time progression.
#
# ---
#
# # 🎯 Step 3 — Fit a simple model to extract the fuel effect
#
# For each stint, fit:
#
# \[
# \text{LapTime} = \alpha + \gamma \cdot \text{LapInStint} + \epsilon
# \]
#
# Where:
# - \( \gamma \) is the **fuel effect per lap**
# - \( \alpha \) is the base pace at the start of the stint
# - \( \epsilon \) is noise
#
# Because fuel load decreases linearly with laps, this slope is proportional to:
#
# \[
# \frac{\Delta \text{LapTime}}{\Delta \text{FuelMass}}
# \]
#
# You can later convert this to “seconds per kg” if you want.
#
# This model intentionally ignores tire degradation for now. You’re isolating the *dominant* trend early in the stint, which is fuel burn.
#
# ---
#
# # 🧲 Step 4 — Remove the fuel effect from the entire stint
#
# Once you have \( \gamma \), you can subtract the fuel effect from every lap:
#
# \[
# \text{LapTime}_{\text{fuel-corrected}}(t)
# = \text{LapTime}(t) - \gamma \cdot \text{LapInStint}(t)
# \]
#
# Now the lap times reflect:
# - Tire degradation
# - Track evolution
# - Driver push variation
# - Noise
#
# But **not fuel**.
#
# This is the dataset you’ll use later for tire degradation modeling.
#
# ---
#
# # 🌱 Step 5 — Later, fit tire degradation on the fuel‑corrected data
#
# Once fuel is removed, you can study tire degradation cleanly:
#
# - Fit degradation curves
# - Identify “cliff” points
# - Compare compounds
# - Compare drivers
# - Compare stints
# - Estimate degradation rates as a function of tire age
#
# This is where you’ll get the real insights for your simulator.
#
# ---
#
# # 🧠 Why this two‑stage approach works so well
#
# Fuel effect is:
# - Smooth
# - Linear
# - Predictable
# - Dominant early in the stint
#
# Tire degradation is:
# - Nonlinear
# - Compound‑dependent
# - Often small early, large late
# - Sensitive to track evolution and driver behavior
#
# If you try to fit both at once, the model will misattribute one to the other. Separating them gives you clean, interpretable physics.
#
# ---
#
# # If you want, I can help you write:
#
# - A FastF1 data extraction function
# - A “fuel effect fitter” that loops over all stints
# - A “fuel correction” function
# - A visualization to confirm the fuel slope is correct
# - A pipeline that outputs a clean dataset for tire modeling
#
# Just tell me what part you want to build next.

# %% [markdown]
# You’re thinking in exactly the right direction — and the suggestion you were given is very much in line with how professional F1 performance engineers separate **fuel‑mass effects** from **tire‑degradation effects**. Let’s unpack why the “first 5 laps” idea works and how to make it rigorous.
#
# ---
#
# # 🏎️ Why the first 5 laps are useful
# During the opening laps of a stint:
#
# - The tire is **fresh**, so degradation hasn’t meaningfully started.
# - The driver is usually settling into a rhythm, not yet pushing the tire to its thermal limits.
# - The fuel load is **changing the fastest** (because the car is heaviest at the start).
#
# This creates a window where **fuel mass is the dominant factor** affecting lap time.
#
# So yes — using the first few laps to isolate the fuel effect is a sound approach.
#
# ---
#
# # 📉 What you’re actually modeling
# You’re trying to estimate:
#
# **Lap time = Base pace + Fuel effect + Tire degradation + Noise**
#
# In the first 5 laps:
#
# - Tire degradation ≈ 0 (or very small)
# - Base pace is stable for a given driver/track/compound
# - Fuel effect is linear-ish because fuel burn per lap is roughly constant
#
# So you can model:
#
# **Lap time ≈ a + b · fuel_mass**
#
# Where:
#
# - **a** = baseline lap time (driver + track + compound)
# - **b** = time penalty per kg of fuel
#   (typically around 0.03–0.05 sec/kg depending on track)
#
# This is the “linear component” you’re talking about.
#
# ---
#
# # 🧪 How to do it cleanly
# Here’s a practical workflow that matches what F1 data analysts do:
#
# ### **1. Filter your dataset**
# - Same venue
# - Same driver
# - Same tire compound
# - First 5 laps of each stint
#
# ### **2. Compute fuel mass per lap**
# If you don’t have exact fuel data, estimate:
#
# ```
# fuel_mass(lap) = starting_fuel - lap_number * fuel_burn_rate
# ```
#
# Fuel burn rate is usually 1.5–2.5 kg/lap depending on track.
#
# ### **3. Fit a linear regression**
# Use:
#
# - X = fuel_mass
# - y = lap_time
#
# The slope gives you the **fuel‑mass penalty**.
#
# ### **4. Subtract this effect from all laps**
# Once you know the fuel effect, you can remove it:
#
# ```
# lap_time_corrected = lap_time - b * fuel_mass
# ```
#
# Now the remaining trend is **pure tire degradation**.
#
# ---
#
# # 🎯 Does this approach “seem right”?
# Yes — it’s the standard, defensible way to separate fuel and tire effects when you don’t have full telemetry. It’s simple, explainable, and grounded in physics:
#
# - Fuel mass → linear-ish effect
# - Tire degradation → nonlinear, compound‑dependent effect
#
# By isolating the linear part early in the stint, you get a clean estimate of the fuel penalty.
#
# ---
#
# If you want, we can go deeper into:
#
# - how many laps you should use (5 is good, but we can test it)
# - how to detect outliers (traffic, mistakes, safety car restarts)
# - how to model tire degradation once fuel is removed
# - how to visualize the two effects separately
#
# Just tell me where you want to take it next.

# %% [markdown]
# ver_laps('TrackStatus')

# %%
ver_laps = laps.copy() #this df is specific to only one driver, Max Verstappen


ver_laps["lap_time"] = ver_laps["LapTime"].dt.total_seconds()  #convert LapTime to lap_time in seconds, not hours, minutes, seconds

# Test for NaNs or zeros in lap_time
num_nans = ver_laps["lap_time"].isna().sum()
num_zeros = (ver_laps["lap_time"] == 0).sum()

if num_nans > 0 or num_zeros > 0:
    print(f"Warning: lap_time contains {num_nans} NaNs and {num_zeros} zeros.")
else:
    print("lap_time looks clean — no NaNs or zeros found.")

# Count laps per compound
lap_counts = ver_laps["Compound"].value_counts().reset_index()
lap_counts.columns = ["Compound", "LapCount"]

print(lap_counts)

# %% [markdown]
# **From above we see that for the 2025 Qatar GrandPrix, Max Verstappen ran 32 laps on the Medium tire compound, and 25 laps on the Soft tire compound**
#
# Answering the question of when to pit depends on the tire
# compound strategy chosen, and well as Safety Car (SC), or Virtual Safety Car(VSC) deployment.
# Next, let's evaluate for the 2025 Qatar race if any SC or VSC were deployed.

# %%
#fast f1 captures track status in the .track_status method on session
ts = session.track_status
ts

# %% [markdown]
# **From above, we can see that a race yellow occurred at a specific time, followed by deployment of a Safety Car, followed by the "All Clear Given".**
#
# Later we will need to merge lap times with track status to map SC or VSC deployment to laps,
#
# this will be important because F1 teams use SC or VSC opportunities to pit since for those
#
# conditions the pit loss is less than the pit loss under an AllClear or Green condition.

# %% [markdown]
# **Now let's code a block to determine race finish time for Max as well as other
# information, like lap number, tire stints, speed trap measurements, tire compound, team name.**

# %%
# Last lap entry
ver_final_lap = ver_laps.iloc[-1]

ver_finish_time = ver_final_lap['Time']
ver_position = ver_final_lap['Position']

print("Max Verstappen finish time:", ver_finish_time, "Max's position", ver_position)
ver_final_lap.info

# %% [markdown]
# **From prior info above, we had seen that Max used medium tires for 32 laps, soft for 25.  For the info above note that
# stints = 3, meaning, that Max must have started on mediums, pitted, put on mediums, pitted again and put on hards.  Further
# investigation is needed, so we can better understand the tire compound strategy Max used.**

# %%
# Convert LapTime → seconds
ver_laps["lap_time"] = ver_laps["LapTime"].dt.total_seconds()

# Loop through laps and print pit-in times
final_lap = int(ver_final_lap["LapNumber"])

for i in range(1, final_lap + 1):
    # Only check rows that exist
    if i in ver_laps.index:

        pit_in_time = ver_laps.loc[i, "PitInTime"]
        pit_out_time = ver_laps.loc[i, "PitOutTime"]
        compound = ver_laps.loc[i, "Compound"]
        stint = ver_laps.loc[i, "Stint"]

        # Pit In
        if pd.notna(pit_in_time):
            print(
                f"Lap {ver_laps.loc[i, 'LapNumber']}: "
                f"Pit In at {pit_in_time} | "
                f"Compound: {compound} | "
                f"Stint: {stint}"
            )

        # Pit Out
        if pd.notna(pit_out_time):
            print(
                f"Lap {ver_laps.loc[i, 'LapNumber']}: "
                f"Pit Out at {pit_out_time} | "
                f"Compound: {compound} | "
                f"Stint: {stint}"
            )

# %% [markdown]
# **Let's start with accessing the fastf1.api for a race that I watched this past year.  A single per lap time plot for a single race
# for a single driver exposes the challenges of the project.**

# %%
import fastf1 # fast f1 api
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure cache exists, this is recommended by fastf1 to speed up analayis after the initial data load
os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")

# Load 2025 Austin Race, US GrandPrix, "R" stands for Race versus qualifying, practice1, etc.
session = fastf1.get_session(2025, "Qatar", "R")
session.load()

# Extract Max Verstappen's laps
laps_ver = session.laps.pick_drivers("VER")

# Build clean DataFrame, with only the data we need
df_max = laps_ver[["LapNumber", "LapTime", "Compound", "TrackStatus"]].copy()

# Convert LapTime (timedelta) → seconds
df_max["lap_time"] = df_max["LapTime"].dt.total_seconds()

# Rename for consistency
df_max.rename(columns={"LapNumber": "lap", "Compound": "tire compound"}, inplace=True)

# Remove invalid laps (out-laps, in-laps, SC laps)
df_max = df_max[df_max["lap_time"] > 0]


plt.figure(figsize=(14, 7))

# Main lap-time line
sns.lineplot(
    data=df_max,
    x="lap",
    y="lap_time",
    style="tire compound",
    linewidth=2
)

plt.title("Max Verstappen (Qatar Grand Prix 2025)")
plt.xlabel("Lap")
plt.ylabel("Lap Time (seconds)")
plt.grid(alpha=0.3)
plt.show()

# %%
import fastf1
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure cache exists
os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")

# Load session
session = fastf1.get_session(2025, "Qatar", "R")
session.load()

# Extract Max Verstappen's laps
laps_ver = session.laps.pick_drivers("VER")

# Build clean DataFrame
df_max = laps_ver[[
    "LapNumber", "LapTime", "Compound", "TrackStatus",
    "Stint", "PitInTime", "PitOutTime"
]].copy()

# Convert LapTime → seconds
df_max["lap_time"] = df_max["LapTime"].dt.total_seconds()

# Rename for consistency
df_max.rename(columns={"LapNumber": "lap", "Compound": "tire compound"}, inplace=True)

# Remove invalid laps
df_max = df_max[df_max["lap_time"] > 0]

# Extract pit-in and pit-out laps
pit_in_laps = df_max[df_max["PitInTime"].notna()][["lap", "Stint"]]
pit_out_laps = df_max[df_max["PitOutTime"].notna()][["lap", "Stint"]]

# Build mapping: Stint (int) → tire compound (string)
# Each stint uses one compound, so .first() is safe
stint_compound_map = (
    df_max.groupby("Stint")["tire compound"]
    .first()
    .to_dict()
)

# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(14, 7))

# Lap-time line colored by stint number
ax = sns.lineplot(
    data=df_max,
    x="lap",
    y="lap_time",
    hue="Stint",
    palette="tab10",
    linewidth=2
)

# Pit-in / Pit-out markers
for _, row in pit_in_laps.iterrows():
    plt.axvline(row["lap"], color="black", linestyle="--", alpha=0.5)

for _, row in pit_out_laps.iterrows():
    plt.axvline(row["lap"], color="black", linestyle="--", alpha=0.5)

# -----------------------------
# Update legend to include compound
# -----------------------------
handles, labels = ax.get_legend_handles_labels()
new_labels = []

for label in labels:
    # Seaborn may give '1', '2', or '1.0', '2.0' as strings
    # We treat anything numeric as a stint label
    try:
        stint_num = int(float(label))
        compound = stint_compound_map.get(stint_num, "Unknown")
        new_labels.append(f"Stint {stint_num} – {compound}")
    except ValueError:
        # Non-numeric labels like "Stint" (legend title entry)
        new_labels.append(label)

ax.legend(handles, new_labels, title="Stint / Compound", loc="upper right")

# -----------------------------
# Title and labels
# -----------------------------
plt.title("Max Verstappen – Qatar Grand Prix 2025\nLap Times Colored by Stint")
plt.xlabel("Lap")
plt.ylabel("Lap Time (seconds)")
plt.grid(alpha=0.3)

plt.show()

# %%
import fastf1
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Ensure cache exists
os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")

# Load session
session = fastf1.get_session(2025, "Qatar", "R")
session.load()

# -----------------------------
# Helper to build driver dataframe
# -----------------------------
def build_driver_df(laps, driver_name):
    df = laps[[
        "LapNumber", "LapTime", "Compound", "TrackStatus",
        "Stint", "PitInTime", "PitOutTime"
    ]].copy()

    df["lap_time"] = df["LapTime"].dt.total_seconds()
    df.rename(columns={"LapNumber": "lap", "Compound": "tire compound"}, inplace=True)
    df = df[df["lap_time"] > 0]
    df["driver"] = driver_name
    return df

# Extract laps
df_ver = build_driver_df(session.laps.pick_drivers("VER"), "Verstappen")
df_pia = build_driver_df(session.laps.pick_drivers("PIA"), "Piastri")

# Combine
df_all = pd.concat([df_ver, df_pia], ignore_index=True)

# -----------------------------
# Build stint → compound map per driver
# -----------------------------
stint_compound_map = (
    df_all.groupby(["driver", "Stint"])["tire compound"]
    .first()
    .to_dict()
)

# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(14, 7))

# Fixed colors for stints 1–3
stint_colors = {1: "blue", 2: "orange", 3: "green"}

ax = sns.lineplot(
    data=df_all,
    x="lap",
    y="lap_time",
    hue="Stint",
    palette=stint_colors,
    style="driver",
    dashes={"Verstappen": "", "Piastri": (4, 2)},
    linewidth=2
)

# -----------------------------
# Pit markers + lap labels BELOW x-axis
# -----------------------------
pit_laps = df_all[df_all["PitInTime"].notna() | df_all["PitOutTime"].notna()]["lap"].unique()
pit_laps = sorted([int(l) for l in pit_laps])

ymin = ax.get_ylim()[0]

for lap in pit_laps:
    plt.axvline(lap, color="gray", linestyle="--", alpha=0.5)
    ax.text(
        lap,
        ymin - 0.5,
        f"{lap}",
        ha="center",
        va="top",
        fontsize=8,
        color="gray"
    )

plt.subplots_adjust(bottom=0.18)

# -----------------------------
# CUSTOM LEGEND
# -----------------------------
legend_handles = []
legend_labels = []

# Verstappen header
legend_handles.append(Line2D([], [], color="none"))
legend_labels.append("Driver- Verstappen")

# Verstappen stints (solid)
for stint in [1, 2, 3]:
    compound = stint_compound_map.get(("Verstappen", stint), "Unknown")
    legend_handles.append(Line2D([0], [0], color=stint_colors[stint], linewidth=2))
    legend_labels.append(f"Stint {stint} – {compound}")

# Piastri header
legend_handles.append(Line2D([], [], color="none"))
legend_labels.append("Driver- Piastri")

# Piastri stints (dashed)
for stint in [1, 2, 3]:
    compound = stint_compound_map.get(("Piastri", stint), "Unknown")
    legend_handles.append(
        Line2D([0], [0], color=stint_colors[stint], linewidth=2, dashes=(4, 2))
    )
    legend_labels.append(f"Stint {stint} – {compound}")

# Pit line (unchanged)
legend_handles.append(Line2D([0], [0], color="gray", linestyle="--"))
legend_labels.append("Pit In/Out")

ax.legend(legend_handles, legend_labels, title="Legend", loc="upper right")

# -----------------------------
# Title and labels
# -----------------------------
plt.title("Verstappen vs Piastri – Qatar Grand Prix 2025\nLap Times Colored by Stint")
plt.xlabel("Lap")
plt.ylabel("Lap Time (seconds)")
plt.grid(alpha=0.3)

plt.show()

# %%
import fastf1
import pandas as pd
import os

# ---------------------------------------------------------
# 1. Enable cache and load a race session
# ---------------------------------------------------------
os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")

session = fastf1.get_session(2025, "United States", "R")
session.load()

# ---------------------------------------------------------
# 2. Identify the race leader (P1 on Lap 1)
# ---------------------------------------------------------
lap1 = session.laps[session.laps["LapNumber"] == 1]
leader = lap1.sort_values("Position").iloc[0]["Driver"]

# Get leader's laps (best reference for LapStartTime)
leader_laps = session.laps.pick_drivers(leader)[["LapNumber", "LapStartTime"]].copy()

# ---------------------------------------------------------
# 3. Get full track status timeline
# ---------------------------------------------------------
ts = session.track_status.copy()   # columns: Time, Status

# ---------------------------------------------------------
# 4. Convert track-status timestamps → lap numbers
# ---------------------------------------------------------
def timestamp_to_lap(ts_time, laps_df):
    """
    Map a timestamp (ts_time) to the lap that was active at that moment.
    """
    mask = laps_df["LapStartTime"] <= ts_time
    if not mask.any():
        return None  # before race start
    return laps_df.loc[mask, "LapNumber"].max()

ts["LapNumber"] = ts["Time"].apply(lambda t: timestamp_to_lap(t, leader_laps))

# Remove entries before race start
ts = ts.dropna(subset=["LapNumber"])
ts["LapNumber"] = ts["LapNumber"].astype(int)

# ---------------------------------------------------------
# 5. Extract SC and VSC laps
# ---------------------------------------------------------
# FIA codes:
# 4 = Safety Car
# 5 = VSC deployed
# 6 = VSC ending

sc_laps = ts[ts["Status"] == "4"]["LapNumber"].unique()
vsc_laps = ts[ts["Status"].isin(["5", "6"])]["LapNumber"].unique()

print("Race leader:", leader)
print("Safety Car laps:", sc_laps)
print("Virtual Safety Car laps:", vsc_laps)

# %% [markdown]
# **Analysis and commentary on above**
#
# The plot above shows lap time in seconds for the entirety of the race.  It shows the change in tire compound at lap 33, from Medium compound to Soft compound tires.  When the tires are changed at lap 33, the lap time jumps up to approximately 118 seconds.  This is called the pit loss, since the car has to enter pit lane, tires are changed, and then exits the pit.  The change in laptime at approximately lap 7 (I rewatched the race) was due to a Virtual Safety car which was deployed because of an accident.  Going forward, Saftey Cars, and Virtual Safety Car information will be shown explicitly.
#
# Of note is the nominal lap time difference between the Medium and Soft tires, the Medium is slower, the Soft is faster, lap times are less.

# %%
sns.lineplot(data=df, x="lap_number", y="lap_time", hue="compound")
plt.title("Lap Time vs Lap Number by Compound")
plt.show()

# %% [markdown]
# # 4. Approach - Simulator, Optimizer, Future Opportunties for regression or ML

# %% [markdown]
# The approach for answering the question, when should I pit requires a system approach.  F1 teams have access to fastf1 data as well as their own recorded car telemetry for each race venue, and likely for several years.  Utlimately as each F1 team approaches a race weekend, they will be using practive and qualifying data to tune a race day strategy, fuel load, tire compound, analysis of prior race Safety Car deployments, as well as evaluating what other teams did on race day.
#
# Here's a resource/primer on how F1 teams prepare for race day, https://michaelluzich.com/how-f1-teams-prepare-for-a-grand-prix-weekend/
#
# Upon reviewing this source, and having watched dozens of F1 races over the years, and upon reviewing other soruces of how F1 teams operate, I've chosen the following approach to answering the question, "Should we pit now?", or "stay out?".
#
# My approach is as follows:
#
# - Build a race simulator that has inputs of total laps, a simple model for tire degradation and pit loss
# - Perform a sanity check of above using fastf1
# - Build a strategy optimizer which iterates through all "legal" possible tire compond strategies. By legal, F1 has some rules for tire usage and pitting
#
# My working theory, is that a F1 team principal would use the simulator and optimizer before race day to select a plan A, B, and C for tire compound strategies that have been informed by Safety Car probabilities.  Then, as the race unfolds, the optimizer would rerun candidate strategies based on real time conditions.  For example, "we are at lap 7, and a Safety Car was just deployed, what are our best strategy options going forward?".
#
# From my research, ML could be used to help with downselection strategy options in the heat of the moment, versus a total rerun of the race simulator with the candidate options.   This is to be yet determined.

# %% [markdown]
# # 4. Tire Degradation Modeling

# %% [markdown]
# ## 4.1 Initial Race Lap Simulator with linear tire degradation

# %% [markdown]
# This code represents an initial version of a race lap simulator with a simple model for tire degredation.
# Though simple, one can see from the plots the complexity of choosing a pit strategy,
# as part of answering the question, when do we pit?
# 1. Tire degredation is measured in a tire_age * degredation/lap approach
# 2. A strategy structure was defined
# 3. Includes pit stop loss when tires are changed
# 4. Safety Cars (SC) and Virtual Safety Car (VSC) were not introduced

# %%
import numpy as np
import pandas as pd

# ------------------------------------------------------------
# 1. Simple lap time model
# ------------------------------------------------------------

"""
Use of an actual race simulator, calling an API was explored, but the following approach was taken, "build my own" to help
provide a basic understanding of the components of lap time.

This is the simplest of models that will allow us to start.  Our pit strategy optimizer will provide this model with
a pit strategy.  Pit strategy is defined as follows,

1. What tire do I start the race with?
2. When do I pit?
3. What compound (tire type) do I switch to?
4. When do I pit again?

An optimal pit strategy will minimize lap times and ultimately result in the fastest race total time.
The race lap and total time simulator will allow us to try different compounds and pit time (which lap to pit on) to compare and visualize results

A stint is defined as the time frame that a particular tire compound in use

lap time = base_lap_time + compound_offset + degradation_rate per lap * tire age in laps, all in seconds

Initially we will only concern ourselves with races run in the dry,
so we don't need to model intermediate or wet tires, only soft, medium and hard compound tires

Soft tires are the fastest since they are sticky, but degrade quickly,
Hard tires degrade at the slowest rate, they last a long time, but are the slowest
Medium tires set in the middle of these two for speed and degradation.

Below Soft = S, Medium = M, Hard = H

A strategy example for Austin TX would be to start on Soft, Pit at Lap 18, then switch to Medium tires to complete the race
The short hand for this would be Soft -> Medium
"""

# To get a handle on the results, we will use the Austin TX venue
AUSTIN_BASE_LAP = 93 # the base lap time for the Austin TX venue is 93 seconds
AUSTIN_PIT_LOSS = 24 # this is the amount of time that is lost in the pit lane entrance, pit, and exit
AUSTIN_TOTAL_LAPS = 56 # total laps for Austin Race
TOTAL_LAPS = AUSTIN_TOTAL_LAPS
BASE_LAP_TIME = AUSTIN_BASE_LAP  # seconds, US Gran Prix Austin TX baseline


TIRE_COMPOUND_OFFSETS = {
    "S": -1.2,   # Softs are fastest, this is the amount per lap where softs improve the baseline performance
    "M": 0.0,    # Medium tire baseline
    "H": +1.5    # Hards are slowest, this is the amount per lap where hard tires add take away from baseline performance
}


TIRE_DEGRADATION_RATES = {
    "S": 0.12,  # Softs degrade fastest,
    "M": 0.08,  # Medium tires degrade at a rate that's between Softs and Hards
    "H": 0.05   # degrade at a rate that is slowest
}

PIT_LOSS = AUSTIN_PIT_LOSS

#define a function that returns the elapsed time for a lap given inputs tire compound and tire age

def lap_time(tire, tire_age):
    return (
        BASE_LAP_TIME
        + TIRE_COMPOUND_OFFSETS[tire]
        + TIRE_DEGRADATION_RATES[tire] * tire_age
    )


# ------------------------------------------------------------
# 2. Simulator
# ------------------------------------------------------------


# now pass in strategy
# a strategy can be starting compound, pit lap, next compound
# when lap count hits pit lap, a pit loss is added, the next lap switches to next compound
# so ("S", 18, "M"), would be a strategy for one stop.
# let's build it for one stop,
# we can define a tuple with a name, first compound, pit stop lap, the next compound

#put in a test to ensure all laps add up to less than the total laps for the race venue
# also extend strategies like below
"""

loop through a strategy stint to ensure lap count does not exceed race total, ultimately decided not to implement
this, since the optimizer will likely be built to test for correct strategies before the simulator is called.
"""

strategy = [
    {"tire": "S", "laps": 18}, # indicates tire compound and laps till pit to change
    {"tire": "M", "laps": 28},
    {"tire": "S", "laps": None}   # final stint
]


#for stint in strategy:
#    print(stint["tire"], stint["laps"])

# now extend the strategy list by building a new list that will bracket stints by lap number
def expand_strategy(strategy, TOTAL_LAPS):

    stints = []
    current_lap = 1

    for stint in strategy:
        tire = stint["tire"]
        laps = stint["laps"]

        if laps is None:
                # final stint goes to end of race
            end_lap = TOTAL_LAPS
        else:
            end_lap = current_lap + laps - 1
        #print(stint)
        stints.append({
            "tire": tire,
            "start": current_lap,
            "end": end_lap
        })
        #print(stints)
        current_lap = end_lap + 1

    return stints
#stints = expand_strategy(strategy, TOTAL_LAPS)
#print(stints)


stints = expand_strategy(strategy, TOTAL_LAPS)
print(stints)
#for stint in strategy:
#    print(stint)
lap_records = []

def total_race_time(strategy_name, strategy, TOTAL_LAPS):
    stints = expand_strategy(strategy, TOTAL_LAPS)
    total = 0
    delta_time = 0

    for stint in stints:
        tire = stint["tire"]
        for lap in range(stint["start"], stint["end"] + 1):
            tire_age = lap - stint["start"]
            delta_time = lap_time(tire, tire_age)
            if (lap == stint["end"] and stint["end"] != TOTAL_LAPS):
                delta_time += PIT_LOSS
            total += delta_time
            #print(f"lap {lap}, tire {tire}, delta_time {delta_time:.3f} cumulative time {total:.3f}")
            lap_records.append({ "strategy": strategy_name,"lap": lap, "tire": tire, "delta_time": delta_time, "cumulative_time": total})

    return total

strategy1 = [
    {"tire": "S", "laps": 18}, # indicates tire compound and laps till pit to change
    {"tire": "M", "laps": 28},
    {"tire": "S", "laps": None}   # final stint
]
strategy2 = [
    {"tire": "S", "laps": 30}, # indicates tire compound and laps till pit to change
    {"tire": "M", "laps": None}
]
strategy3 = [
    {"tire": "S", "laps": 20}, # indicates tire compound and laps till pit to change
    {"tire": "M", "laps": None}
]


total = total_race_time("Jeff", strategy1, TOTAL_LAPS)
total = total_race_time("Sam", strategy2, TOTAL_LAPS)
total_race_time("Tim", strategy3, TOTAL_LAPS)
df_laps = pd.DataFrame(lap_records)
#print(df_laps)
#print(total)


""" Experimentation with plots to review data
"""
import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(data=df_laps, x="lap", y="delta_time", hue="tire")
plt.title("Lap Time by Lap Number")
plt.show()

sns.lineplot(data=df_laps, x="lap", y="delta_time", hue="strategy")
plt.title("Lap Time by Lap Number")
plt.show()


sns.lineplot(data=df_laps, x="lap", y="cumulative_time", hue="strategy")
plt.title("Cumulative Race Time")
plt.show()

g = sns.FacetGrid(df_laps, col="strategy", col_wrap=2, height=4, sharey=False)
g.map_dataframe(sns.lineplot, x="lap", y="cumulative_time")
g.set_titles("{col_name}")
plt.show()

df_final = (
    df_laps
    .groupby("strategy", as_index=False)
    .agg(final_time=("cumulative_time", "max"))
)

plt.figure(figsize=(8, 5))



ax = sns.barplot(
    data=df_final,
    x="strategy",
    y="final_time",
    hue="strategy",
    palette="tab10",
    legend=False
)


plt.ylim(df_final["final_time"].min() - 5,
         df_final["final_time"].max() + 5)

plt.title("Final Race Time by Strategy (Zoomed)")
plt.ylabel("Final Time (s)")

# Label ALL bars, not just the first container
for container in ax.containers:
    ax.bar_label(container, fmt="%.2f", padding=3)

plt.show()

# %% [markdown]
# ## 4.2 Refactor Race Simulator to accept programatic inputs from a brute force optimizer
#
# Refactor code above so that a pit strategy optimizer can call it programmatically to iterate though strategy combinations in search of the best strategy for shortest race time.

# %%
import pandas as pd

TOTAL_LAPS = 56          # later will have this as a race venue input
PIT_LOSS = 20.0          # later will have this as a race venue input

TIRE_COMPOUND_OFFSETS = {
    "S": -1.2,   # Softs are fastest, this is the amount per lap where softs improve the baseline performance
    "M": 0.0,    # Medium tire baseline
    "H": +1.5    # Hards are slowest, this is the amount per lap where hard tires add take away from baseline performance
}

TIRE_DEGRADATION_RATES = {
    "S": 0.12,  # Softs degrade fastest,
    "M": 0.08,  # Medium tires degrade at a rate that's between Softs and Hards
    "H": 0.05   # degrade at a rate that is slowest
}


#define a function that returns the elapsed time for a lap given inputs tire compound and tire age

def lap_time(tire, tire_age):
    return (
        BASE_LAP_TIME
        + TIRE_COMPOUND_OFFSETS[tire]
        + TIRE_DEGRADATION_RATES[tire] * tire_age
    )


# --------------------------------------------------
# 1. Strategy expansion (laps -> [start, end])
# --------------------------------------------------

def expand_strategy(strategy, total_laps):
    """
    Convert a stint-based strategy into explicit lap ranges.

    Input example:
        strategy = [
            {"tire": "S", "laps": 18},
            {"tire": "M", "laps": 28},
            {"tire": "S", "laps": None},  # final stint to race end
        ]

    Output example:
        [
            {"tire": "S", "start": 1,  "end": 18},
            {"tire": "M", "start": 19, "end": 46},
            {"tire": "S", "start": 47, "end": 56},
        ]
    """
    stints = []
    current_lap = 1

    for stint in strategy:
        tire = stint["tire"]
        laps = stint["laps"]

        if laps is None:
            # final stint goes to end of race
            end_lap = total_laps
        else:
            end_lap = current_lap + laps - 1

        stints.append({
            "tire": tire,
            "start": current_lap,
            "end": end_lap
        })

        current_lap = end_lap + 1

    return stints


# --------------------------------------------------
# 2. Pure simulation: total race time only
# --------------------------------------------------

def total_race_time(strategy, total_laps, pit_loss=PIT_LOSS):
    """
    Compute total race time for a given strategy.
    """
    stints = expand_strategy(strategy, total_laps)
    total = 0.0

    for stint in stints:
        tire = stint["tire"]
        start = stint["start"]
        end = stint["end"]

        for lap in range(start, end + 1):
            tire_age = lap - start
            lap_time_value = lap_time(tire, tire_age)

            # Add pit loss at end of stint, except final stint
            if lap == end and end != total_laps:
                lap_time_value += pit_loss

            total += lap_time_value

    return total


# --------------------------------------------------
# 3. Detailed simulation: lap-by-lap records
# --------------------------------------------------

def simulate_with_lap_data(strategy_name, strategy, total_laps, pit_loss=PIT_LOSS):
    """
    Same core logic as total_race_time, but returns lap-by-lap data
    for analysis and plotting.
    """
    stints = expand_strategy(strategy, total_laps)
    total = 0.0
    lap_records = []

    for stint in stints:
        tire = stint["tire"]
        start = stint["start"]
        end = stint["end"]

        for lap in range(start, end + 1):
            tire_age = lap - start
            lap_time_value = lap_time(tire, tire_age)

            # Add pit loss at end of stint, except final stint
            if lap == end and end != total_laps:
                lap_time_value += pit_loss

            total += lap_time_value

            lap_records.append({
                "strategy": strategy_name,
                "lap":      lap,
                "tire":     tire,
                "lap_time": lap_time_value,
                "cumulative_time": total
            })

    return total, lap_records


# --------------------------------------------------
# 4. Example strategies and usage
# --------------------------------------------------

strategy1 = [
    {"tire": "S", "laps": 18},
    {"tire": "M", "laps": 28},
    {"tire": "S", "laps": None}
]

strategy2 = [
    {"tire": "S", "laps": 30},
    {"tire": "M", "laps": None}
]

strategy3 = [
    {"tire": "S", "laps": 20},
    {"tire": "M", "laps": None}
]

# run if from Jupyter notebook, but don't run if called, imported by another program
if __name__ == "__main__":
    # Example: how a brute-force optimizer will use total_race_time
    t1 = total_race_time(strategy1, TOTAL_LAPS)
    t2 = total_race_time(strategy2, TOTAL_LAPS)
    t3 = total_race_time(strategy3, TOTAL_LAPS)

    print(f"Strategy1 total time: {t1:.3f}")
    print(f"Strategy2 total time: {t2:.3f}")
    print(f"Strategy3 total time: {t3:.3f}")
    # Example: detailed simulation for plotting, put all runs in this

    all_lap_records = []

# for strategy pair, use name to call name in simulate with lap time function
# then for loop calls function with strategy using the strat variable
# then all_lap_records is used to hold the laps info returned for each strategy
    for name, strat in [("Jeff", strategy1), ("Sam", strategy2), ("Tim", strategy3)]:
        total, laps = simulate_with_lap_data(name, strat, TOTAL_LAPS)
        all_lap_records.extend(laps)

    df_laps = pd.DataFrame(all_lap_records)
    print(df_laps.head())

# %%
""" Experimentation with plots to review data
"""
import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(data=df_laps, x="lap", y="lap_time", hue="tire")
plt.title("Lap Time by Lap Number")
plt.show()

sns.lineplot(data=df_laps, x="lap", y="lap_time", hue="strategy")
plt.title("Lap Time by Lap Number")
plt.show()

sns.lineplot(data=df_laps, x="lap", y="cumulative_time", hue="strategy")
plt.title("Cumulative Race Time")
plt.show()

g = sns.FacetGrid(df_laps, col="strategy", col_wrap=2, height=4, sharey=False)
g.map_dataframe(sns.lineplot, x="lap", y="cumulative_time")
g.set_titles("{col_name}")
plt.show()

df_final = (
    df_laps
    .groupby("strategy", as_index=False)
    .agg(final_time=("cumulative_time", "max"))
)

plt.figure(figsize=(8, 5))

ax = sns.barplot(
    data=df_final,
    x="strategy",
    y="final_time",
    hue="strategy",
    palette="tab10",
    legend=False
)

plt.ylim(df_final["final_time"].min() - 5,
         df_final["final_time"].max() + 5)

plt.title("Final Race Time by Strategy (Zoomed)")
plt.ylabel("Final Time (s)")

# Label ALL bars, not just the first container
for container in ax.containers:
    ax.bar_label(container, fmt="%.2f", padding=3)

plt.show()

# %% [markdown]
# ## 4.3 Quadratic Tire Model
#
# Model form:
# lap_time = a + b * lap_number + c * lap_number^2

# %%
df["lap_number_sq"] = df["lap_number"]**2
Xq = df[["lap_number", "lap_number_sq"]]

quad_model = LinearRegression().fit(Xq, y)
quad_model.coef_, quad_model.intercept_

# %% [markdown]
# ## 4.4 Machine Learning Tire Model
#
# Use a more flexible model (Random Forest, Gradient Boosting, etc.)
# Include:
# - Feature engineering
# - Train/validation split

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

features = ["lap_number", "lap_number_sq"]
X_ml = df[features]

X_train, X_test, y_train, y_test = train_test_split(X_ml, y, test_size=0.2)

rf = RandomForestRegressor(n_estimators=200)
rf.fit(X_train, y_train)

# %% [markdown]
# # 5. Model Validation & Comparison

# %% [markdown]
# ## 5.1 Metrics
#
# Compute RMSE, MAE, R² for each model.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def evaluate(model, X, y):
    preds = model.predict(X)
    return {
        "RMSE": np.sqrt(mean_squared_error(y, preds)),
        "MAE": mean_absolute_error(y, preds),
        "R2": r2_score(y, preds)
    }

lin_eval = evaluate(lin_model, X, y)
quad_eval = evaluate(quad_model, Xq, y)
rf_eval = evaluate(rf, X_test, y_test)

lin_eval, quad_eval, rf_eval

# %% [markdown]
# ## 5.2 Visual Validation
#
# Plot predicted vs actual lap times.

# %%
plt.scatter(y_test, rf.predict(X_test), alpha=0.5)
plt.xlabel("Actual Lap Time")
plt.ylabel("Predicted Lap Time")
plt.title("Random Forest: Actual vs Predicted")
plt.show()

# %% [markdown]
# # 6. Pit Strategy Optimization

# %% [markdown]
# ## 6.1 Problem Definition
#
# Goal:
# Minimize total race time by choosing optimal pit laps and tire compounds.
#
# Constraints:
# - Max stint length
# - Tire compound rules
# - Degradation model

# %% [markdown]
# ## 6.2 Optimization Approach
#
# Start with brute-force search to compute total race time for:
# - 1-stop strategies
# - 2-stop strategies
# - 3-stop strategies
# - Possibly other strategies imposed by F1 for specific races, like Monaco (2 pit stops required) and Abi Dhabi (max distance imposed on tires)

# %%
import itertools

TIRES = ["S", "M", "H"]

def generate_strategies(total_laps, max_stints=3):
    """
    Generate all legal strategies:
      - 1 to max_stints stints
      - final stint uses laps=None
      - must use at least 2 different compounds (FIA dry race rule)
    """
    for num_stints in range(1, max_stints + 1):

        # All possible tire sequences
        for tire_seq in itertools.product(TIRES, repeat=num_stints):

            # FIA rule: must use at least 2 different compounds
            if len(set(tire_seq)) < 2:
                continue

            # All possible lap splits for the first N-1 stints
            for lap_splits in itertools.product(range(1, total_laps), repeat=num_stints - 1):

                # Reject splits that exceed total laps
                if sum(lap_splits) >= total_laps:
                    continue

                # Build the strategy
                strategy = []
                for i in range(num_stints):
                    if i < num_stints - 1:
                        strategy.append({"tire": tire_seq[i], "laps": lap_splits[i]})
                    else:
                        strategy.append({"tire": tire_seq[i], "laps": None})

                yield strategy

def brute_force_optimize(total_laps):
    best_time = float("inf")
    best_strategy = None
    count = 0

    for strategy in generate_strategies(total_laps):
        count += 1
        t = total_race_time(strategy, total_laps)

        if t < best_time:
            best_time = t
            best_strategy = strategy

    return best_strategy, best_time, count

# %%
best_strategy, best_time, count = brute_force_optimize(TOTAL_LAPS)

print("Best strategy:", best_strategy)
print(f"Best time: {best_time:.3f}")
print("Total strategies evaluated:", count)

# %% [markdown]
# Now let's plot the best strategy

# %%
best_strategy, best_time, count = brute_force_optimize(TOTAL_LAPS)
total, lap_records = simulate_with_lap_data(
    "Best Strategy",
    best_strategy,
    TOTAL_LAPS
)
df_best = pd.DataFrame(lap_records)
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(data=df_best, x="lap", y="lap_time", hue="tire")
plt.title("Lap Time by Lap Number — Best Strategy")
plt.show()
sns.lineplot(data=df_best, x="lap", y="cumulative_time")
plt.title("Cumulative Race Time — Best Strategy")
plt.show()

# %% [markdown]
# Now let's look at best strategy per compound set

# %% [markdown]
# **Setup a standalone race simulator and optimizer.**

# %%
# ============================================================
#  RACE SIMULATOR + BEST-PER-COMPOUND-SET OPTIMIZER + PLOTTING
# ============================================================

import os
import pandas as pd
import itertools
import seaborn as sns
import matplotlib.pyplot as plt

import fastf1 #import fastf1 package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set up cache, recommended by fastf1 documentation
fastf1.Cache.enable_cache('/Users/jeffreylgoode/documents/f1-capstone-project')
# Ensure cache exists
os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")

TIRES = ["S", "M", "H"]
# Circuit of the Americas (Austin) – dry race approximation

TOTAL_LAPS = 56          # Official race distance

PIT_LOSS = 24.0          # Typical race pit lane loss (box to box)

BASE_LAP_TIME = 100.0    # ~1:40.0 base race-pace lap

TIRE_COMPOUND_OFFSETS = {
    "S": -0.8,   # Soft: ~0.8 s faster than Medium when fresh
    "M":  0.0,   # Medium: baseline
    "H": +0.7    # Hard: ~0.7 s slower than Medium when fresh
}

TIRE_DEGRADATION_RATES = {
    "S": 0.06,   # Soft degrades fastest (but not crazy)
    "M": 0.04,   # Medium in the middle
    "H": 0.03    # Hard degrades slowest
}


# ============================================================
# 1. LAP TIME MODEL
# ============================================================

def lap_time(tire, tire_age):
    return (
        BASE_LAP_TIME
        + TIRE_COMPOUND_OFFSETS[tire]
        + TIRE_DEGRADATION_RATES[tire] * tire_age
    )


# ============================================================
# 2. EXPAND STRATEGY INTO LAP RANGES
# ============================================================

def expand_strategy(strategy, total_laps):
    stints = []
    current_lap = 1

    for stint in strategy:
        tire = stint["tire"]
        laps = stint["laps"]

        if laps is None:
            end_lap = total_laps
        else:
            end_lap = current_lap + laps - 1

        stints.append({
            "tire": tire,
            "start": current_lap,
            "end": end_lap
        })

        current_lap = end_lap + 1

    return stints


# ============================================================
# 3. TOTAL RACE TIME (FAST SIMULATION)
# ============================================================

def total_race_time(strategy, total_laps, pit_loss=PIT_LOSS):
    stints = expand_strategy(strategy, total_laps)
    total = 0.0

    for stint in stints:
        tire = stint["tire"]
        start = stint["start"]
        end = stint["end"]

        for lap in range(start, end + 1):
            tire_age = lap - start
            lap_time_value = lap_time(tire, tire_age)

            if lap == end and end != total_laps:
                lap_time_value += pit_loss

            total += lap_time_value

    return total


# ============================================================
# 4. DETAILED SIMULATION (LAP-BY-LAP)
# ============================================================

def simulate_with_lap_data(strategy_name, strategy, total_laps, pit_loss=PIT_LOSS):
    stints = expand_strategy(strategy, total_laps)
    total = 0.0
    lap_records = []

    for stint in stints:
        tire = stint["tire"]
        start = stint["start"]
        end = stint["end"]

        for lap in range(start, end + 1):
            tire_age = lap - start
            lap_time_value = lap_time(tire, tire_age)

            if lap == end and end != total_laps:
                lap_time_value += pit_loss

            total += lap_time_value

            lap_records.append({
                "strategy": strategy_name,
                "lap": lap,
                "tire": tire,
                "lap_time": lap_time_value,
                "cumulative_time": total
            })

    return total, lap_records


# ============================================================
# 5. STRATEGY GENERATOR (FIA RULE: MUST USE ≥2 COMPOUNDS)
# ============================================================

def generate_strategies(total_laps, max_stints=3):
    for num_stints in range(2, max_stints + 1):

        for tire_seq in itertools.product(TIRES, repeat=num_stints):

            # FIA rule: must use at least 2 compounds
            if len(set(tire_seq)) < 2:
                continue

            # Generate all possible lap splits for first N-1 stints
            for lap_splits in itertools.product(range(1, total_laps), repeat=num_stints - 1):

                if sum(lap_splits) >= total_laps:
                    continue

                strategy = []
                for i in range(num_stints):
                    if i < num_stints - 1:
                        strategy.append({"tire": tire_seq[i], "laps": lap_splits[i]})
                    else:
                        strategy.append({"tire": tire_seq[i], "laps": None})

                yield strategy


# ============================================================
# 6. BEST STRATEGY PER COMPOUND SET
# ============================================================

def best_by_compound_group(total_laps):
    groups = {}

    for strategy in generate_strategies(total_laps):
        compounds = frozenset(stint["tire"] for stint in strategy)

        t = total_race_time(strategy, total_laps)

        if compounds not in groups or t < groups[compounds][1]:
            groups[compounds] = (strategy, t)

    return groups


# ============================================================
# 7. SIMULATE ALL GROUP-BEST STRATEGIES
# ============================================================

def simulate_group_strategies(groups, total_laps):
    all_laps = []

    for compounds, (strategy, time) in groups.items():
        name = f"{''.join(sorted(compounds))} best"
        total, laps = simulate_with_lap_data(name, strategy, total_laps)
        all_laps.extend(laps)

    return all_laps


# ============================================================
# 8. PLOT ALL GROUP-BEST STRATEGIES
# ============================================================

def plot_group_strategies(df):
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=df, x="lap", y="cumulative_time", hue="strategy")
    plt.title("Best Strategy per Compound Set — Cumulative Race Time")
    plt.xlabel("Lap")
    plt.ylabel("Cumulative Time (s)")
    plt.grid(True, alpha=0.3)
    plt.show()
def plot_final_times_bar(groups):
    """
    Plots a normalized bar chart showing delta vs. best strategy.
    """
    # Build DataFrame
    data = []
    for compounds, (strategy, time) in groups.items():
        name = "".join(sorted(compounds)) + " best"
        data.append({"strategy": name, "final_time": time})

    df = pd.DataFrame(data)

    # Normalize: subtract the minimum time
    best_time = df["final_time"].min()
    df["delta"] = df["final_time"] - best_time

    plt.figure(figsize=(10, 5))
    sns.barplot(data=df, x="strategy", y="delta", palette="viridis")

    plt.title("Normalized Final Race Time — Delta vs Best Strategy")
    plt.xlabel("Compound Set")
    plt.ylabel("Delta Time (s)")
    plt.grid(axis="y", alpha=0.3)

    # Annotate bars with delta values
    for i, row in df.iterrows():
        plt.text(i, row["delta"] + 0.05, f"{row['delta']:.3f}s",
                 ha='center', va='bottom', fontsize=10)

    plt.show()



# ============================================================
# 9. MAIN EXECUTION
# ============================================================

if __name__ == "__main__":

    # 1. Find best strategy per compound set
    groups = best_by_compound_group(TOTAL_LAPS)

    print("Best strategy per compound set:")
    for comp, (strat, t) in groups.items():
        print(f"Compounds {comp}: time={t:.3f}, strategy={strat}")

    # 2. Simulate all group-best strategies
    all_laps = simulate_group_strategies(groups, TOTAL_LAPS)

    # 3. Build DataFrame
    df_groups = pd.DataFrame(all_laps)

    # 4. Visualize
    plot_group_strategies(df_groups)
    plot_final_times_bar(groups)

# %% [markdown]
# **stand alone block**

# %%
# ============================================================
#  FULL STANDALONE SCRIPT: FASTF1 ACTUAL DATA vs SIMULATOR
# ============================================================

import os
import itertools
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import fastf1

# ------------------------------------------------------------
# FASTF1 SETUP
# ------------------------------------------------------------
fastf1.Cache.enable_cache("fastf1_cache")
os.makedirs("fastf1_cache", exist_ok=True)

# ------------------------------------------------------------
# SIMULATOR CONSTANTS
# ------------------------------------------------------------
TIRES = ["S", "M", "H"]
TOTAL_LAPS = 56
PIT_LOSS = 24.0
BASE_LAP_TIME = 100.0

TIRE_COMPOUND_OFFSETS = {"S": -0.8, "M": 0.0, "H": +0.7}
TIRE_DEGRADATION_RATES = {"S": 0.06, "M": 0.04, "H": 0.03}


# ------------------------------------------------------------
# 1. LAP TIME MODEL
# ------------------------------------------------------------
def lap_time(tire, tire_age):
    return (
            BASE_LAP_TIME
            + TIRE_COMPOUND_OFFSETS[tire]
            + TIRE_DEGRADATION_RATES[tire] * tire_age
    )


# ------------------------------------------------------------
# 2. EXPAND STRATEGY
# ------------------------------------------------------------
def expand_strategy(strategy, total_laps):
    stints = []
    current_lap = 1

    for stint in strategy:
        tire = stint["tire"]
        laps = stint["laps"]

        end_lap = total_laps if laps is None else current_lap + laps - 1

        stints.append({"tire": tire, "start": current_lap, "end": end_lap})
        current_lap = end_lap + 1

    return stints


# ------------------------------------------------------------
# 3. TOTAL RACE TIME
# ------------------------------------------------------------
def total_race_time(strategy, total_laps, pit_loss=PIT_LOSS):
    stints = expand_strategy(strategy, total_laps)
    total = 0.0

    for stint in stints:
        tire = stint["tire"]
        start, end = stint["start"], stint["end"]

        for lap in range(start, end + 1):
            tire_age = lap - start
            lap_t = lap_time(tire, tire_age)

            if lap == end and end != total_laps:
                lap_t += pit_loss

            total += lap_t

    return total


# ------------------------------------------------------------
# 4. DETAILED SIMULATION
# ------------------------------------------------------------
def simulate_with_lap_data(name, strategy, total_laps, pit_loss=PIT_LOSS):
    stints = expand_strategy(strategy, total_laps)
    total = 0.0
    lap_records = []

    for stint in stints:
        tire = stint["tire"]
        start, end = stint["start"], stint["end"]

        for lap in range(start, end + 1):
            tire_age = lap - start
            lap_t = lap_time(tire, tire_age)

            if lap == end and end != total_laps:
                lap_t += pit_loss

            total += lap_t

            lap_records.append({
                "strategy": name,
                "lap": lap,
                "tire": tire,
                "lap_time": lap_t
            })

    return total, lap_records


# ------------------------------------------------------------
# 5. STRATEGY GENERATOR
# ------------------------------------------------------------
def generate_strategies(total_laps, max_stints=3):
    for num_stints in range(2, max_stints + 1):
        for tire_seq in itertools.product(TIRES, repeat=num_stints):

            if len(set(tire_seq)) < 2:
                continue

            for lap_splits in itertools.product(range(1, total_laps), repeat=num_stints - 1):

                if sum(lap_splits) >= total_laps:
                    continue

                strategy = []
                for i in range(num_stints):
                    if i < num_stints - 1:
                        strategy.append({"tire": tire_seq[i], "laps": lap_splits[i]})
                    else:
                        strategy.append({"tire": tire_seq[i], "laps": None})

                yield strategy


# ------------------------------------------------------------
# 6. BEST STRATEGY PER COMPOUND GROUP
# ------------------------------------------------------------
def best_by_compound_group(total_laps):
    groups = {}

    for strategy in generate_strategies(total_laps):
        compounds = frozenset(stint["tire"] for stint in strategy)
        t = total_race_time(strategy, total_laps)

        if compounds not in groups or t < groups[compounds][1]:
            groups[compounds] = (strategy, t)

    return groups


# ------------------------------------------------------------
# 7. SIMULATE GROUP STRATEGIES
# ------------------------------------------------------------
def simulate_group_strategies(groups, total_laps):
    all_laps = []

    for compounds, (strategy, _) in groups.items():
        name = f"{''.join(sorted(compounds))} best"
        _, laps = simulate_with_lap_data(name, strategy, total_laps)
        all_laps.extend(laps)

    return all_laps


# ------------------------------------------------------------
# 8. ACTUAL RACE DATA (FASTF1)
# ------------------------------------------------------------
def load_actual_laps(year, gp, session_name, driver):
    session = fastf1.get_session(year, gp, session_name)
    session.load()

    laps = session.laps.pick_drivers(driver)
    laps = laps[["LapNumber", "LapTime", "Compound"]].copy()
    laps["LapTime"] = laps["LapTime"].dt.total_seconds()

    return laps


# ------------------------------------------------------------
# 9. COMPARISON PLOT: ACTUAL vs SIMULATOR
# ------------------------------------------------------------
def compare_scatter(actual_df, sim_df, driver):
    COMPOUND_COLORS = {
        "SOFT": "#FF3333",
        "MEDIUM": "#FFCC33",
        "HARD": "#FFFFFF",
        "INTERMEDIATE": "#39B54A",
        "WET": "#00AEEF",
        "S": "#FF3333",
        "M": "#FFCC33",
        "H": "#FFFFFF"
    }

    plt.figure(figsize=(14, 6))

    # --- Actual ---
    for comp, grp in actual_df.groupby("Compound"):
        plt.scatter(
            grp["LapNumber"],
            grp["LapTime"],
            s=60,
            color=COMPOUND_COLORS.get(comp.upper(), "gray"),
            edgecolor="black",
            marker="o",
            alpha=0.85,
            label=f"Actual {driver} – {comp}"
        )

    # --- Simulator ---
    for comp, grp in sim_df.groupby("tire"):
        plt.scatter(
            grp["lap"],
            grp["lap_time"],
            s=60,
            color=COMPOUND_COLORS.get(comp.upper(), "gray"),
            edgecolor="blue",
            marker="s",
            alpha=0.85,
            label=f"Sim – {comp}"
        )

    plt.xlabel("Lap Number")
    plt.ylabel("Lap Time (seconds)")
    plt.title(f"Actual vs Simulator Lap Times — {driver}")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


# ------------------------------------------------------------
# 10. MAIN EXECUTION
# ------------------------------------------------------------
if __name__ == "__main__":
    # --- Load actual race data ---
    driver = "VER"
    actual = load_actual_laps(2025, "Qatar", "R", driver)

    # --- Run simulator ---
    groups = best_by_compound_group(TOTAL_LAPS)
    sim_laps = simulate_group_strategies(groups, TOTAL_LAPS)
    sim_df = pd.DataFrame(sim_laps)

    # --- Compare ---
    compare_scatter(actual, sim_df, driver)

# %% [markdown]
# # New Baseline

# %% [markdown]
# ## New baseline for starting the work of actual vs simulation

# %% [markdown]
# **the following 1 block of code plots actual lap time sim output, and a cumulative time comparison form the basis of how sims and actuals will be compared**

# %%
# ============================================================
#  FASTF1 ACTUAL DATA vs SIMULATOR (USER-PROVIDED STINTS)
#  + SCATTER COMPARISON
#  + CUMULATIVE RACE TIME COMPARISON
# ============================================================

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import fastf1

# Force black background for ALL plots
plt.style.use("dark_background")

# ------------------------------------------------------------
# FASTF1 SETUP
# ------------------------------------------------------------
os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")

# ------------------------------------------------------------
# SIMULATOR CONSTANTS
# ------------------------------------------------------------
TOTAL_LAPS = 56
PIT_LOSS = 24.0
BASE_LAP_TIME = 100.0

TIRE_COMPOUND_OFFSETS = {"S": -0.8, "M": 0.0, "H": +0.7}
TIRE_DEGRADATION_RATES = {"S": 0.06, "M": 0.04, "H": 0.03}


# ------------------------------------------------------------
# 1. LAP TIME MODEL
# ------------------------------------------------------------
def lap_time(tire, tire_age):
    return (
            BASE_LAP_TIME
            + TIRE_COMPOUND_OFFSETS[tire]
            + TIRE_DEGRADATION_RATES[tire] * tire_age
    )


# ------------------------------------------------------------
# 2. EXPAND USER-PROVIDED STINTS
# ------------------------------------------------------------
def expand_stints(stints, total_laps):
    expanded = []
    current_lap = 1

    for stint in stints:
        tire = stint["tire"]
        laps = stint["laps"]

        end_lap = total_laps if laps is None else current_lap + laps - 1

        expanded.append({
            "tire": tire,
            "start": current_lap,
            "end": end_lap
        })

        current_lap = end_lap + 1

    return expanded


# ------------------------------------------------------------
# 3. SIMULATE LAP-BY-LAP
# ------------------------------------------------------------
def simulate_laps(stints, total_laps, pit_loss=PIT_LOSS):
    expanded = expand_stints(stints, total_laps)
    total = 0.0
    lap_records = []

    for stint in expanded:
        tire = stint["tire"]
        start, end = stint["start"], stint["end"]

        for lap in range(start, end + 1):
            tire_age = lap - start
            lap_t = lap_time(tire, tire_age)

            if lap == end and end != total_laps:
                lap_t += pit_loss

            total += lap_t

            lap_records.append({
                "lap": lap,
                "tire": tire,
                "lap_time": lap_t
            })

    return pd.DataFrame(lap_records)


# ------------------------------------------------------------
# 4. LOAD ACTUAL FASTF1 LAPS
# ------------------------------------------------------------
def load_actual_laps(year, gp, session_name, driver):
    session = fastf1.get_session(year, gp, session_name)
    session.load()

    laps = session.laps.pick_drivers(driver)
    laps = laps[["LapNumber", "LapTime", "Compound"]].copy()
    laps["LapTime"] = laps["LapTime"].dt.total_seconds()

    return laps


# ------------------------------------------------------------
# 5. SCATTER COMPARISON
# ------------------------------------------------------------
def compare_scatter(actual_df, sim_df, driver):
    COMPOUND_COLORS = {
        "SOFT": "#FF3333",
        "MEDIUM": "#FFCC33",
        "HARD": "#FFFFFF",
        "S": "#FF3333",
        "M": "#FFCC33",
        "H": "#FFFFFF"
    }

    plt.figure(figsize=(14, 6))

    # --- Actual (circles, black outline) ---
    for comp, grp in actual_df.groupby("Compound"):
        plt.scatter(
            grp["LapNumber"],
            grp["LapTime"],
            s=60,
            color=COMPOUND_COLORS.get(comp.upper(), "gray"),
            edgecolor="black",
            marker="o",
            alpha=0.85,
            label=f"Actual {driver} – {comp}"
        )

    # --- Simulator (squares, NO outline) ---
    for comp, grp in sim_df.groupby("tire"):
        plt.scatter(
            grp["lap"],
            grp["lap_time"],
            s=60,
            color=COMPOUND_COLORS.get(comp.upper(), "gray"),
            edgecolor="none",  # <-- no outline
            marker="s",
            alpha=0.85,
            label=f"Sim – {comp}"
        )

    plt.xlabel("Lap Number")
    plt.ylabel("Lap Time (seconds)")
    plt.title(f"Actual vs Simulator Lap Times — {driver}")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


# ------------------------------------------------------------
# 6. CUMULATIVE TIME HELPERS
# ------------------------------------------------------------
def build_actual_cumulative(actual_df):
    df = actual_df.copy()
    df = df.sort_values("LapNumber")
    df["cumulative_time"] = df["LapTime"].cumsum()
    return df


def build_sim_cumulative(sim_df):
    df = sim_df.copy()
    df = df.sort_values("lap")
    df["cumulative_time"] = df["lap_time"].cumsum()
    return df


# ------------------------------------------------------------
# 7. CUMULATIVE COMPARISON PLOT
# ------------------------------------------------------------
def compare_cumulative(actual_df, sim_df, driver):
    plt.figure(figsize=(14, 6))

    # --- Actual (bright yellow) ---
    plt.plot(
        actual_df["LapNumber"],
        actual_df["cumulative_time"],
        label=f"Actual {driver}",
        color="#C77DFF",
        linewidth=3.5,
        marker="o",
        markersize=5,
        alpha=1.0
    )

    # --- Simulator (cyan dashed) ---
    plt.plot(
        sim_df["lap"],
        sim_df["cumulative_time"],
        label="Simulator",
        color="#00FFFF",
        linewidth=2.5,
        linestyle="--",
        marker="s",
        markersize=5,
        alpha=0.9
    )

    # Final times
    actual_final = actual_df["cumulative_time"].iloc[-1]
    sim_final = sim_df["cumulative_time"].iloc[-1]
    delta = sim_final - actual_final

    # Text box inside plot
    text = (
        f"Final Times:\n"
        f"Actual {driver}: {actual_final:.3f} s\n"
        f"Simulator: {sim_final:.3f} s\n"
        f"Delta: {delta:+.3f} s"
    )

    plt.text(
        0.02, 0.98, text,
        transform=plt.gca().transAxes,
        fontsize=12,
        verticalalignment="top",
        color="white",
        bbox=dict(facecolor="black", alpha=0.6, edgecolor="white")
    )

    plt.xlabel("Lap Number")
    plt.ylabel("Cumulative Race Time (seconds)")
    plt.title(f"Cumulative Race Time Comparison — {driver}")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


# ------------------------------------------------------------
# 8. MAIN EXECUTION
# ------------------------------------------------------------
if __name__ == "__main__":
    stints = [
        {"tire": "M", "laps": 7},
        {"tire": "M", "laps": 25},
        {"tire": "H", "laps": None}
    ]

    driver = "VER"

    actual = load_actual_laps(2025, "Qatar", "R", driver)
    sim_df = simulate_laps(stints, TOTAL_LAPS)

    compare_scatter(actual, sim_df, driver)

    actual_cum = build_actual_cumulative(actual)
    sim_cum = build_sim_cumulative(sim_df)

    compare_cumulative(actual_cum, sim_cum, driver)

# %% [markdown]
# Now let's do a quick compare with Max Verstappen for this race,

# %%
# ============================================================
#  CUMULATIVE RACE TIME COMPARISON — HIGH VISIBILITY VERSION
#  Requires: actual, sim_df, driver
# ============================================================

import matplotlib.pyplot as plt


# ------------------------------------------------------------
# Build cumulative time for actual laps
# ------------------------------------------------------------
def build_actual_cumulative(actual_df):
    df = actual_df.copy()
    df = df.sort_values("LapNumber")
    df["cumulative_time"] = df["LapTime"].cumsum()
    return df


# ------------------------------------------------------------
# Build cumulative time for simulated laps
# ------------------------------------------------------------
def build_sim_cumulative(sim_df):
    df = sim_df.copy()
    df = df.sort_values("lap")
    df["cumulative_time"] = df["lap_time"].cumsum()
    return df


# ------------------------------------------------------------
# Plot cumulative comparison
# ------------------------------------------------------------
def compare_cumulative(actual_df, sim_df, driver):
    plt.figure(figsize=(14, 6))
    plt.style.use("dark_background")  # ensure black background

    # --- Actual (bright yellow, thick, visible) ---
    plt.plot(
        actual_df["LapNumber"],
        actual_df["cumulative_time"],
        label=f"Actual {driver}",
        color="#FFFF00",  # bright yellow
        linewidth=3.5,
        marker="o",
        markersize=5,
        alpha=1.0
    )

    # --- Simulator (cyan, dashed, distinct) ---
    plt.plot(
        sim_df["lap"],
        sim_df["cumulative_time"],
        label="Simulator",
        color="#00FFFF",  # bright cyan
        linewidth=2.5,
        linestyle="--",
        marker="s",
        markersize=5,
        alpha=0.9
    )

    # Compute final times
    actual_final = actual_df["cumulative_time"].iloc[-1]
    sim_final = sim_df["cumulative_time"].iloc[-1]
    delta = sim_final - actual_final

    # --- Add text box inside plot ---
    text = (
        f"Final Times:\n"
        f"Actual {driver}: {actual_final:.3f} s\n"
        f"Simulator: {sim_final:.3f} s\n"
        f"Delta: {delta:+.3f} s"
    )

    plt.text(
        0.02, 0.98, text,
        transform=plt.gca().transAxes,
        fontsize=12,
        verticalalignment="top",
        color="white",
        bbox=dict(facecolor="black", alpha=0.6, edgecolor="white")
    )

    plt.xlabel("Lap Number")
    plt.ylabel("Cumulative Race Time (seconds)")
    plt.title(f"Cumulative Race Time Comparison — {driver}")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


# ------------------------------------------------------------
# EXECUTE THE COMPARISON
# ------------------------------------------------------------
actual_cum = build_actual_cumulative(actual)
sim_cum = build_sim_cumulative(sim_df)

compare_cumulative(actual_cum, sim_cum, driver)

# %%
import fastf1
import os

os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")

session = fastf1.get_session(2025, "United States Grand Prix", "R")
session.load()

laps = session.laps.pick_drivers("VER")

# Build stints manually
stints = (
    laps.groupby("Stint")
        .agg(
            Compound=("Compound", "first"),
            StartLap=("LapNumber", "min"),
            EndLap=("LapNumber", "max"),
            StintLength=("LapNumber", lambda x: x.max() - x.min() + 1)
        )
)

print(stints)

# %% [markdown]
# Now, let's compare our simulator best strategy versus Max actual AUS grand prix

# %%
import fastf1
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# -------------------------------
# 1. Load Max Verstappen's laps
# -------------------------------

# Ensure cache exists
os.makedirs("fastf1_cache", exist_ok=True)
fastf1.Cache.enable_cache("fastf1_cache")

# Load 2025 Austin Race
session = fastf1.get_session(2025, "United States", "R")
session.load()

# Extract Max's laps
laps_ver = session.laps.pick_drivers("VER")

# Build clean DataFrame
df_max = laps_ver[["LapNumber", "LapTime", "Compound"]].copy()

# Convert LapTime (timedelta) → seconds
df_max["lap_time"] = df_max["LapTime"].dt.total_seconds()

# Rename for consistency
df_max.rename(columns={"LapNumber": "lap", "Compound": "tire"}, inplace=True)

# Remove invalid laps (out-laps, in-laps, SC laps)
df_max = df_max[df_max["lap_time"] > 0]

# Label strategy
df_max["strategy"] = "Max Verstappen"


# -----------------------------------------
# 2. Run your simulator's best strategy
# -----------------------------------------

best_strategy, best_time, count = brute_force_optimize(TOTAL_LAPS)

_, sim_laps = simulate_with_lap_data("Simulator Best", best_strategy, TOTAL_LAPS)

df_sim = pd.DataFrame(sim_laps)[["lap", "lap_time", "tire", "strategy"]]


# -----------------------------------------
# 3. Combine both datasets
# -----------------------------------------

df_compare = pd.concat([df_sim, df_max], ignore_index=True)


# -----------------------------------------
# 4. Plot lap-time comparison
# -----------------------------------------

plt.figure(figsize=(14, 7))
sns.lineplot(
    data=df_compare,
    x="lap",
    y="lap_time",
    hue="strategy",
    style="tire",
    linewidth=2
)

plt.title("Lap Time Comparison: Simulator Best Strategy vs Max Verstappen (Austin 2025)")
plt.xlabel("Lap")
plt.ylabel("Lap Time (seconds)")
plt.grid(alpha=0.3)
plt.show()

"""

# -----------------------------------------
# 5. Plot tire compound timeline
# -----------------------------------------

plt.figure(figsize=(14, 3))
sns.scatterplot(
    data=df_compare,
    x="lap",
    y="strategy",
    hue="tire",
    palette={"S": "red", "M": "yellow", "H": "white"},
    s=80,
    edgecolor="black"
)

plt.title("Tire Compound Usage: Simulator vs Max Verstappen")
plt.xlabel("Lap")
plt.ylabel("")
plt.grid(alpha=0.2)
plt.show()

"""

# %%
laps_ver["PitOut"] = laps_ver["PitOutTime"].notna()
laps_ver["PitIn"] = laps_ver["PitInTime"].notna()

print(laps_ver[laps_ver["PitIn"] | laps_ver["PitOut"]][["LapNumber", "PitIn", "PitOut"]])

# %%
def simulate_stint(start_lap, end_lap, model):
    laps = np.arange(start_lap, end_lap+1)
    X_sim = pd.DataFrame({"lap_number": laps, "lap_number_sq": laps**2})
    return model.predict(X_sim).sum()

race_length = df["lap_number"].max()

def simulate_strategy(pit_laps, model):
    total = 0
    stints = [1] + pit_laps + [race_length + 1]
    for i in range(len(stints)-1):
        total += simulate_stint(stints[i], stints[i+1]-1, model)
    return total

# %% [markdown]
# ## 6.3 Results
#
# Compute race times for all strategies and identify the optimal one.

# %%
strategies = {
    "1-stop": [20],
    "2-stop": [15, 35],
    "3-stop": [12, 25, 38]
}

results = {name: simulate_strategy(stops, rf) for name, stops in strategies.items()}
results

# %%
plt.bar(results.keys(), results.values())
plt.ylabel("Total Race Time (s)")
plt.title("Strategy Comparison")
plt.show()

# %% [markdown]
# # 7. Final Results & Insights
#
# Summarize:
# - Best-performing tire model
# - Optimal pit strategy
# - Key findings from the data

# %% [markdown]
# # 8. Limitations & Future Work
#
# Discuss:
# - Data limitations
# - Model assumptions
# - Potential improvements

# %% [markdown]
# # 9. Appendix
#
# Additional plots, helper functions, raw tables, etc.

# %% [markdown]
# **Notes on Methodology**
#
# In preparing this notebook, I used Microsoft Copilot as a writing and coding assistant.
# Copilot was used for tightening narrative language, improving clarity of explanations,
# and assisting with Python syntax or plotting details that are not the focus of this course.
#
# All project design decisions, data exploration, modeling choices, interpretations,
# and conclusions are my own and reflect my understanding of the course material.
